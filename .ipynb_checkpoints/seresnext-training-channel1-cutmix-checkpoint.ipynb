# %% [markdown]
# # Bengali.AI SEResNeXt training with pytorch
#
# I will introduce following contents
#
#  - **Fast data loading** with feather format
#  - **Data augmentation** technic with affine transformation
#  - **CNN SoTA models**: Use pytorch `pretrainedmodels` library, especially I use **`SEResNeXt`** in this notebook
#  - **Training code abstraction**: Use `pytorch-ignite` module for the trainining abstraction
#
# ### Update history
#
#  - 2020/1/4 v2: Added albumentations augmentations introduced in [Bengali: albumentations data augmentation tutorial](https://www.kaggle.com/corochann/bengali-albumentations-data-augmentation-tutorial)

# %% [markdown]
# # Table of Contents:
# **[Fast data loading with feather](#load)**<br>
# **[Dataset](#dataset)**<br>
# **[Data augmentation/processing](#processing)**<br>
# **[pytorch model & define classifier](#model)**<br>
# **[Training code](#train)**<br>
# **[Prediction](#pred)**<br>
# **[Reference and further reading](#ref)**<br>

# %% [markdown]
# To install https://github.com/Cadene/pretrained-models.pytorch without internet connection, we can install library as "dataset".
#
# It is uploaded by @rishabhiitbhu : https://www.kaggle.com/rishabhiitbhu/pretrainedmodels

# %%
#!pip install ../input/pretrainedmodels/pretrainedmodels-0.7.4/ > /dev/null # no output
# !python -m pip install ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/ > /dev/null --user

# %%
import gc
import os
from pathlib import Path
import random
import sys

from tqdm.notebook import tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display import display, HTML

# --- plotly ---
from plotly import tools, subplots
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff

# --- models ---
from sklearn import preprocessing
from sklearn.model_selection import KFold
# import lightgbm as lgb
# import xgboost as xgb
# import catboost as cb

# --- setup ---
pd.set_option('max_columns', 50)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# ../input/bengaliaicv19feather/train_image_data_0.feather
# ../input/bengaliaicv19feather/train_image_data_3.feather
# ../input/bengaliaicv19feather/test_image_data_2.feather
# ../input/bengaliaicv19feather/train_image_data_2.feather
# ../input/bengaliaicv19feather/train_image_data_1.feather
# ../input/bengaliaicv19feather/test_image_data_0.feather
# ../input/bengaliaicv19feather/test_image_data_1.feather
# ../input/bengaliaicv19feather/test_image_data_3.feather
# ../input/bengaliai-cv19/train.csv
# ../input/bengaliai-cv19/train_image_data_0.parquet
# ../input/bengaliai-cv19/train_image_data_2.parquet
# ../input/bengaliai-cv19/train_image_data_1.parquet
# ../input/bengaliai-cv19/sample_submission.csv
# ../input/bengaliai-cv19/class_map.csv
# ../input/bengaliai-cv19/test_image_data_1.parquet
# ../input/bengaliai-cv19/train_image_data_3.parquet
# ../input/bengaliai-cv19/test_image_data_0.parquet
# ../input/bengaliai-cv19/test.csv
# ../input/bengaliai-cv19/test_image_data_3.parquet
# ../input/bengaliai-cv19/test_image_data_2.parquet
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/README.md
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/setup.cfg
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/setup.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/PKG-INFO
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/README.md
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/setup.cfg
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/setup.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/PKG-INFO
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/version.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/utils.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/senet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/nasnet_mobile.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/fbresnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/wideresnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/xception.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/inceptionv4.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/dpn.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/utils.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/pnasnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/inceptionresnetv2.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/bninception.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/nasnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/polynet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/vggm.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/torchvision_models.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/cafferesnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext_features/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext_features/resnext101_32x4d_features.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext_features/resnext101_64x4d_features.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/datasets/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/datasets/utils.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/datasets/voc.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/requires.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/SOURCES.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/PKG-INFO
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/dependency_links.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/top_level.txt

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
debug=False
submission=False
batch_size=32*8
device='cuda:0'
out='.'
image_size=64
arch='pretrained'
model_name='se_resnext50_32x4d'

# %%
datadir = Path('../input/bengaliai-cv19')
featherdir = Path('../input/bengaliaicv19feather')
outdir = Path('./save')

# %%
# Read in the data CSV files
# train = pd.read_csv(datadir/'train.csv')
# test = pd.read_csv(datadir/'test.csv')
# sample_submission = pd.read_csv(datadir/'sample_submission.csv')
# class_map = pd.read_csv(datadir/'class_map.csv')

# %% [markdown]
# # Fast data loading with feather
#
# Refer [Bengali.AI super fast data loading with feather](https://www.kaggle.com/corochann/bengali-ai-super-fast-data-loading-with-feather) and [dataset](https://www.kaggle.com/corochann/bengaliaicv19feather) for detail.<br/>
# Original `parquet` format takes about 60 sec to load 1 data, while `feather` format takes about **2 sec to load 1 data!!!**
#
# ### How to add dataset
#
# When you write kernel, click "+ Add Data" botton on right top.<br/>
# Then inside window pop-up, you can see "Search Datasets" text box on right top.<br/>
# You can type "bengaliai-cv19-feather" to find this dataset and press "Add" botton to add the data.

# %%
import numpy as np
import pandas as pd
import gc


def prepare_image(datadir, featherdir, data_type='train',
                  submission=False, indices=[0, 1, 2, 3]):
    assert data_type in ['train', 'test']
    if submission:
        image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
                         for i in indices]
    else:
        image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
                         for i in indices]

    print('image_df_list', len(image_df_list))
    HEIGHT = 137
    WIDTH = 236
    images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
    del image_df_list
    gc.collect()
    images = np.concatenate(images, axis=0)
    return images

# %%
os.listdir(r"../input")
# Out:
# ['bengaliaicv19feather', 'bengaliai-cv19', 'pretrainedmodels']

# %%
# %%time

train = pd.read_csv(datadir/'train.csv')
train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
indices = [0] if debug else [0, 1, 2, 3]
train_images = prepare_image(
    datadir, featherdir, data_type='train', submission=False, indices=indices)
# Out:
# image_df_list 4
# CPU times: user 12.1 s, sys: 20.8 s, total: 32.9 s
# Wall time: 1min 17s

# %%
os.listdir("../input/bengaliaicv19feather/")
# Out:
# ['train_image_data_0.feather',
#  'train_image_data_3.feather',
#  'test_image_data_2.feather',
#  'train_image_data_2.feather',
#  'train_image_data_1.feather',
#  'test_image_data_0.feather',
#  'test_image_data_1.feather',
#  'test_image_data_3.feather']

# %% [markdown]
# <a id="dataset"></a>
# # Dataset

# %%
"""
Referenced `chainer.dataset.DatasetMixin` to work with pytorch Dataset.
"""
import numpy
import six
import torch
from torch.utils.data.dataset import Dataset


class DatasetMixin(Dataset):

    def __init__(self, transform=None):
        self.transform = transform

    def __getitem__(self, index):
        """Returns an example or a sequence of examples."""
        if torch.is_tensor(index):
            index = index.tolist()
        if isinstance(index, slice):
            current, stop, step = index.indices(len(self))
            return [self.get_example_wrapper(i) for i in
                    six.moves.range(current, stop, step)]
        elif isinstance(index, list) or isinstance(index, numpy.ndarray):
            return [self.get_example_wrapper(i) for i in index]
        else:
            return self.get_example_wrapper(index)

    def __len__(self):
        """Returns the number of data points."""
        raise NotImplementedError

    def get_example_wrapper(self, i):
        """Wrapper of `get_example`, to apply `transform` if necessary"""
        example = self.get_example(i)
        if self.transform:
            example = self.transform(example)
        return example

    def get_example(self, i):
        """Returns the i-th example.

        Implementations should override it. It should raise :class:`IndexError`
        if the index is invalid.

        Args:
            i (int): The index of the example.

        Returns:
            The i-th example.

        """
        raise NotImplementedError

# %% [markdown]
# This `DatasetMixin` class can be used to define any custom dataset class in pytorch. We can implement `get_example(self, i)` method to return `i`-th data.
#
# Here I return i-th image `x` and `label`, with scaling image to be value ranges between 0~1.

# %%
import numpy as np


class BengaliAIDataset(DatasetMixin):
    def __init__(self, images, labels=None, transform=None, indices=None):
        super(BengaliAIDataset, self).__init__(transform=transform)
        self.images = images
        self.labels = labels
        if indices is None:
            indices = np.arange(len(images))
        self.indices = indices
        self.train = labels is not None

    def __len__(self):
        """return length of this dataset"""
        return len(self.indices)

    def get_example(self, i):
        """Return i-th data"""
        i = self.indices[i]
        x = self.images[i]
        # Opposite white and black: background will be white and
        # for future Affine transformation
        x = (255 - x).astype(np.float32) / 255.
        x = x.astype(np.double)
        if self.train:
            y = self.labels[i]
            return x, y
        else:
            return x

# %% [markdown]
# Let's see how this `BengaliAIDataset` work

# %% [markdown]
# `train_dataset[i]` returns i-th image array and 3 target labels (graphme_root, vowel_diacritic and consonant_diacritic).

# %%
train_dataset = BengaliAIDataset(train_images, train_labels)

image, label = train_dataset[0]
print('image', image.shape, 'label', label)
# Out:
# image (137, 236) label [15  9  5]

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    ax.set_title(f'label: {label}')
plt.tight_layout()
plt.show()
plt.savefig('bengaliai.png')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# <a id="processing"></a>
# # Data augmentation/processing

# %% [markdown]
# For CNN training, data augmentation is important to improve test accuracy (generalization performance). I will show some image preprocessing to increase the data variety.

# %%
"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image


from scipy.ndimage.measurements import label

def connected_comp(array):
    
    structure = np.ones((3, 3), dtype=np.int)  # this defines the connection filter
    labeled, ncomponents = label(array, structure)
    
    valid = []
    for i in range(1,ncomponents+1):
        if np.sum(labeled == i)>10:
            valid.append(i)

    new_array = np.zeros(array.shape)
    for i in valid:
        new_array += labeled==i
    return new_array

def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold
    is_black[:2,:] = 0
    is_black[-2:,:] = 0
    is_black[:,:2] = 0
    is_black[:,-2:] = 0
    is_black = connected_comp(is_black)

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    
    left = np.argmax(is_black_horizontal)-2
    right = np.argmax(is_black_horizontal[::-1])+2
    top = np.argmax(is_black_vertical)+2
    bottom = np.argmax(is_black_vertical[::-1])-2
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image

def resize(image, size=(128, 128)):
    return cv2.resize(image, size)

# %% [markdown]
# ## Affine transformation for data augmentation
#
# To increase validation score, the number of training data is important. When we can use more number of training data, we can reduce overfitting and validation score becomes high.
#
# "Data augmentation" is a technic to virtually create extra training data, based on the given training data. For this MNIST task, data augmentation can be achieved by utilizing affine transformation.
#
# 1. Rotation AffineTransformation
# 2. Translation
# 3. Scale
# 4. Shear

# %%
# nrow, ncol = 1, 6

# fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
# axes = axes.flatten()
# for i, ax in tqdm(enumerate(axes)):
#     image, label = train_dataset[0]
#     ax.imshow(affine_image(image), cmap='Greys')
#     ax.set_title(f'label: {label}')
# plt.tight_layout()

# %% [markdown]
# When the image is slightly rotated, shifted (transformed) or scaled, the image looks like the same label. We can virtually create another image data from one image in such a way.

# %% [markdown]
# ## crop image
#
# Here I crop image

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label2 = train_dataset[i]
    ax.imshow(crop_char_image(image, threshold=20./255.), cmap='Greys')
    ax.set_title(f'label: {label2}')
plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ## resize image
#
# We need to resize image after crop, to align image size for CNN batch training.

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label2 = train_dataset[i]
    ax.imshow(resize(crop_char_image(image, threshold=20./255.)), cmap='Greys')
    ax.set_title(f'label: {label2}')
plt.tight_layout()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# Put everything together with `Transform` class. <br>
# [Update] I added **albumentations augmentations** introduced in [Bengali: albumentations data augmentation tutorial](https://www.kaggle.com/corochann/bengali-albumentations-data-augmentation-tutorial).

# %%
import albumentations as A
import numpy as np


def add_gaussian_noise(x, sigma):
    x += np.random.randn(*x.shape) * sigma
    x = np.clip(x, 0., 1.)
    return x


def _evaluate_ratio(ratio):
    if ratio <= 0.:
        return False
    return np.random.uniform() < ratio


def apply_aug(aug, image):
    return aug(image=image)['image']


class Transform:
    def __init__(self, affine=True, crop=True, size=(64, 64),
                 normalize=True, train=True, threshold=40.,
                 sigma=-1., blur_ratio=0., noise_ratio=0., cutout_ratio=0.,
                 grid_distortion_ratio=0., elastic_distortion_ratio=0., random_brightness_ratio=0.,
                 piece_affine_ratio=0., ssr_ratio=0.):
        self.affine = affine
        self.crop = crop
        self.size = size
        self.normalize = normalize
        self.train = train
        self.threshold = threshold / 255.
        self.sigma = sigma / 255.

        self.blur_ratio = blur_ratio
        self.noise_ratio = noise_ratio
        self.cutout_ratio = cutout_ratio
        self.grid_distortion_ratio = grid_distortion_ratio
        self.elastic_distortion_ratio = elastic_distortion_ratio
        self.random_brightness_ratio = random_brightness_ratio
        self.piece_affine_ratio = piece_affine_ratio
        self.ssr_ratio = ssr_ratio

    def __call__(self, example):
        if self.train:
            x, y = example
        else:
            x = example
        # --- Augmentation ---
        if self.affine:
            x = affine_image(x)

        # --- Train/Test common preprocessing ---
        if self.crop:
            x = crop_char_image(x, threshold=self.threshold)
        if self.size is not None:
            x = resize(x, size=self.size)
        if self.sigma > 0.:
            x = add_gaussian_noise(x, sigma=self.sigma)

        # albumentations...
        x = x.astype(np.double)
        assert x.ndim == 2
        # 1. blur
        if _evaluate_ratio(self.blur_ratio):
            r = np.random.uniform()
            if r < 0.25:
                x = apply_aug(A.Blur(p=1.0), x)
            elif r < 0.5:
                x = apply_aug(A.MedianBlur(blur_limit=5, p=1.0), x)
            elif r < 0.75:
                x = apply_aug(A.GaussianBlur(p=1.0), x)
            else:
                x = apply_aug(A.MotionBlur(p=1.0), x)

        if _evaluate_ratio(self.noise_ratio):
            r = np.random.uniform()
            if r < 0.50:
                x = apply_aug(A.GaussNoise(var_limit=5. / 255., p=1.0), x)
            else:
                x = apply_aug(A.MultiplicativeNoise(p=1.0), x)

        if _evaluate_ratio(self.cutout_ratio):
            # A.Cutout(num_holes=2,  max_h_size=2, max_w_size=2, p=1.0)  # Deprecated...
            x = apply_aug(A.CoarseDropout(max_holes=8, max_height=8, max_width=8, p=1.0), x)

        if _evaluate_ratio(self.grid_distortion_ratio):
            x = apply_aug(A.GridDistortion(p=1.0), x)

        if _evaluate_ratio(self.elastic_distortion_ratio):
            x = apply_aug(A.ElasticTransform(
                sigma=50, alpha=1, alpha_affine=10, p=1.0), x)

        if _evaluate_ratio(self.random_brightness_ratio):
            # A.RandomBrightness(p=1.0)  # Deprecated...
            # A.RandomContrast(p=1.0)    # Deprecated...
            x = apply_aug(A.RandomBrightnessContrast(p=1.0), x)

        if _evaluate_ratio(self.piece_affine_ratio):
            x = apply_aug(A.IAAPiecewiseAffine(p=1.0), x)

        if _evaluate_ratio(self.ssr_ratio):
            x = apply_aug(A.ShiftScaleRotate(
                shift_limit=0.0625,
                scale_limit=0.1,
                rotate_limit=30,
                p=1.0), x)

        if self.normalize:
            x = (x.astype(np.double) - 0.0692) / 0.2051
        if x.ndim == 2:
            x = x[None, :, :]
        x = x.astype(np.double)
        if self.train:
            y = y.astype(np.int64)
            return x, y
        else:
            return x
        
# class Transform:
#     def __init__(self, affine=True, crop=True, size=(64, 64),
#                  normalize=True, train=True, threshold=40.,
#                  sigma=-1., blur_ratio=0., noise_ratio=0., cutout_ratio=0.,
#                  grid_distortion_ratio=0., elastic_distortion_ratio=0., random_brightness_ratio=0.,
#                  piece_affine_ratio=0., ssr_ratio=0.):
#         self.affine = affine
#         self.crop = crop
#         self.size = size
#         self.normalize = normalize
#         self.train = train
#         self.threshold = threshold / 255.
#         self.sigma = sigma / 255.

#         self.blur_ratio = blur_ratio
#         self.noise_ratio = noise_ratio
#         self.cutout_ratio = cutout_ratio
#         self.grid_distortion_ratio = grid_distortion_ratio
#         self.elastic_distortion_ratio = elastic_distortion_ratio
#         self.random_brightness_ratio = random_brightness_ratio
#         self.piece_affine_ratio = piece_affine_ratio
#         self.ssr_ratio = ssr_ratio

#     def __call__(self, example):
#         if self.train:
#             x, y = example
#         else:
#             x = example
#         # --- Augmentation ---
#         if self.affine:
#             x = affine_image(x)

#         # --- Train/Test common preprocessing ---
#         if self.crop:
#             x = crop_char_image(x, threshold=self.threshold)
#         if self.size is not None:
#             x = resize(x, size=self.size)
#         if self.sigma > 0.:
#             x = add_gaussian_noise(x, sigma=self.sigma)

#         # albumentations...
#         x = x.astype(np.float32)
#         assert x.ndim == 2
#         # 1. blur
#         if _evaluate_ratio(self.blur_ratio):
#             r = np.random.uniform()
#             if r < 0.25:
#                 x = apply_aug(A.Blur(p=1.0), x)
#             elif r < 0.5:
#                 x = apply_aug(A.MedianBlur(blur_limit=5, p=1.0), x)
#             elif r < 0.75:
#                 x = apply_aug(A.GaussianBlur(p=1.0), x)
#             else:
#                 x = apply_aug(A.MotionBlur(p=1.0), x)

#         if _evaluate_ratio(self.noise_ratio):
#             r = np.random.uniform()
#             if r < 0.50:
#                 x = apply_aug(A.GaussNoise(var_limit=5. / 255., p=1.0), x)
#             else:
#                 x = apply_aug(A.MultiplicativeNoise(p=1.0), x)

#         if _evaluate_ratio(self.cutout_ratio):
#             # A.Cutout(num_holes=2,  max_h_size=2, max_w_size=2, p=1.0)  # Deprecated...
#             x = apply_aug(A.CoarseDropout(max_holes=8, max_height=8, max_width=8, p=1.0), x)

#         if _evaluate_ratio(self.grid_distortion_ratio):
#             x = apply_aug(A.GridDistortion(p=1.0), x)

#         if _evaluate_ratio(self.elastic_distortion_ratio):
#             x = apply_aug(A.ElasticTransform(
#                 sigma=50, alpha=1, alpha_affine=10, p=1.0), x)

#         if _evaluate_ratio(self.random_brightness_ratio):
#             # A.RandomBrightness(p=1.0)  # Deprecated...
#             # A.RandomContrast(p=1.0)    # Deprecated...
#             x = apply_aug(A.RandomBrightnessContrast(p=1.0), x)

#         if _evaluate_ratio(self.piece_affine_ratio):
#             x = apply_aug(A.IAAPiecewiseAffine(p=1.0), x)

#         if _evaluate_ratio(self.ssr_ratio):
#             x = apply_aug(A.ShiftScaleRotate(
#                 shift_limit=0.0625,
#                 scale_limit=0.1,
#                 rotate_limit=30,
#                 p=1.0), x)

#         if self.normalize:
#             x = (x.astype(np.float32) - 0.0692) / 0.2051
#         if x.ndim == 2:
#             x = x[None, :, :]
#         x = x.astype(np.float32)
#         if self.train:
#             y = y.astype(np.int64)
#             return x, y
#         else:
#             return x

# %%
train_transform = Transform(
    size=(image_size, image_size), threshold=20.,
    sigma=-1., blur_ratio=0.2, noise_ratio=0.2, cutout_ratio=0.2,
    grid_distortion_ratio=0.2, random_brightness_ratio=0.2,
    piece_affine_ratio=0.2, ssr_ratio=0.2)
# transform = Transform(size=(image_size, image_size)
train_dataset = BengaliAIDataset(train_images, train_labels,
                                 transform=train_transform)

# %% [markdown]
# By setting `transform`, its function is called **every time** when we access to the index. Dataset returns different `image` every time! which is useful for training with data augmentation.

# %%
# nrow, ncol = 1, 6

# fig, axes = plt.subplots(nrow, ncol, figsize=(20, 2))
# axes = axes.flatten()
# for i, ax in tqdm(enumerate(axes)):
#     image, label = train_dataset[0]
#     ax.imshow(image[0], cmap='Greys')
#     ax.set_title(f'label: {label}')
# plt.tight_layout()

# %% [markdown]
# Let's final check the processed images, which will be trained by the model.

# %%
# nrow, ncol = 5, 6

# fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
# axes = axes.flatten()
# for i, ax in tqdm(enumerate(axes)):
#     image, label = train_dataset[i]
#     ax.imshow(image[0], cmap='Greys')
#     ax.set_title(f'label: {label}')
# plt.tight_layout()

# %% [markdown]
# <a id="model"></a>
# # pytorch model & define classifier

# %%
import torch


def residual_add(lhs, rhs):
    lhs_ch, rhs_ch = lhs.shape[1], rhs.shape[1]
    if lhs_ch < rhs_ch:
        out = lhs + rhs[:, :lhs_ch]
    elif lhs_ch > rhs_ch:
        out = torch.cat([lhs[:, :rhs_ch] + rhs, lhs[:, rhs_ch:]], dim=1)
    else:
        out = lhs + rhs
    return out

# %%
from typing import List

import torch
from torch import nn
from torch.nn.parameter import Parameter


class LazyLoadModule(nn.Module):
    """Lazy buffer/parameter loading using load_state_dict_pre_hook

    Define all buffer/parameter in `_lazy_buffer_keys`/`_lazy_parameter_keys` and
    save buffer with `register_buffer`/`register_parameter`
    method, which can be outside of __init__ method.
    Then this module can load any shape of Tensor during de-serializing.

    Note that default value of lazy buffer is torch.Tensor([]), while lazy parameter is None.
    """
    _lazy_buffer_keys: List[str] = []     # It needs to be override to register lazy buffer
    _lazy_parameter_keys: List[str] = []  # It needs to be override to register lazy parameter

    def __init__(self):
        super(LazyLoadModule, self).__init__()
        for k in self._lazy_buffer_keys:
            self.register_buffer(k, torch.tensor([]))
        for k in self._lazy_parameter_keys:
            self.register_parameter(k, None)
        self._register_load_state_dict_pre_hook(self._hook)

    def _hook(self, state_dict, prefix, local_metadata, strict, missing_keys,
             unexpected_keys, error_msgs):
        for key in self._lazy_buffer_keys:
            self.register_buffer(key, state_dict[prefix + key])

        for key in self._lazy_parameter_keys:
            self.register_parameter(key, Parameter(state_dict[prefix + key]))

# %%
import math
import torch
from torch.nn import init
from torch.nn.parameter import Parameter
import torch.nn.functional as F


class LazyLinear(LazyLoadModule):
    """Linear module with lazy input inference

    `in_features` can be `None`, and it is determined at the first time of forward step dynamically.
    """

    __constants__ = ['bias', 'in_features', 'out_features']
    _lazy_parameter_keys = ['weight']

    def __init__(self, in_features, out_features, bias=True):
        super(LazyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        if bias:
            self.bias = Parameter(torch.Tensor(out_features))
        else:
            self.register_parameter('bias', None)

        if in_features is not None:
            self.weight = Parameter(torch.Tensor(out_features, in_features))
            self.reset_parameters()

    def reset_parameters(self):
        init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        if self.bias is not None:
            fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / math.sqrt(fan_in)
            init.uniform_(self.bias, -bound, bound)

    def forward(self, input):
        if self.weight is None:
            self.in_features = input.shape[-1]
            self.weight = Parameter(torch.Tensor(self.out_features, self.in_features))
            self.reset_parameters()

            # Need to send lazy defined parameter to device...
            self.to(input.device)
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )

# %%
from torch import nn
import torch.nn.functional as F


class LinearBlock(nn.Module):

    def __init__(self, in_features, out_features, bias=True,
                 use_bn=True, activation=F.relu, dropout_ratio=-1, residual=False,):
        super(LinearBlock, self).__init__()
        if in_features is None:
            self.linear = LazyLinear(in_features, out_features, bias=bias)
        else:
            self.linear = nn.Linear(in_features, out_features, bias=bias)
        if use_bn:
            self.bn = nn.BatchNorm1d(out_features)
        if dropout_ratio > 0.:
            self.dropout = nn.Dropout(p=dropout_ratio)
        else:
            self.dropout = None
        self.activation = activation
        self.use_bn = use_bn
        self.dropout_ratio = dropout_ratio
        self.residual = residual

    def __call__(self, x):
        h = self.linear(x)
        if self.use_bn:
            h = self.bn(h)
        if self.activation is not None:
            h = self.activation(h)
        if self.residual:
            h = residual_add(h, x)
        if self.dropout_ratio > 0:
            h = self.dropout(h)
        return h

# %%
import pretrainedmodels
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Sequential


class PretrainedCNN(nn.Module):
    def __init__(self, model_name='se_resnext101_32x4d',
                 in_channels=1, out_dim=10, use_bn=True,
                 pretrained='imagenet'):
        super(PretrainedCNN, self).__init__()
        self.conv0 = nn.Conv2d(
            in_channels, 3, kernel_size=3, stride=1, padding=1, bias=True)
        self.base_model = pretrainedmodels.__dict__[model_name](pretrained=pretrained)
        activation = F.leaky_relu
        self.do_pooling = True
        if self.do_pooling:
            inch = self.base_model.last_linear.in_features
        else:
            inch = None
        hdim = 512
        lin1 = LinearBlock(inch, hdim, use_bn=use_bn, activation=activation, residual=False)
        lin2 = LinearBlock(hdim, out_dim, use_bn=use_bn, activation=None, residual=False)
        self.lin_layers = Sequential(lin1, lin2)

    def forward(self, x):
        
        h = self.conv0(x)
        h = self.base_model.features(h)
        
        if self.do_pooling:
            h = torch.sum(h, dim=(-1, -2))
        else:
            # [128, 2048, 4, 4] when input is (128, 128)
            bs, ch, height, width = h.shape
            h = h.view(bs, ch*height*width)
        for layer in self.lin_layers:
            h = layer(h)
            
        return h

# %% [markdown]
# ## Classifier

# %%
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2
def cutmix(data, targets1, targets2, targets3, alpha):
    indices = torch.randperm(data.size(0))
    shuffled_data = data[indices]
    shuffled_targets1 = targets1[indices]
    shuffled_targets2 = targets2[indices]
    shuffled_targets3 = targets3[indices]

    lam = np.random.beta(alpha, alpha)
    while lam > 0.9997:
        lam = np.random.beta(alpha, alpha)
    bbx1, bby1, bbx2, bby2 = rand_bbox(data.size(), lam)
    
    
#     print(lam)
#     print(data.shape)
#     print(indices)
#     print(bbx1, bbx2, bby1, bby2)
    
    data[:, :, bbx1:bbx2, bby1:bby2] = data[indices, :, bbx1:bbx2, bby1:bby2]
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (data.size()[-1] * data.size()[-2]))

    targets = [targets1, shuffled_targets1, targets2, shuffled_targets2, targets3, shuffled_targets3, lam]
    return data, targets

def mixup(data, targets1, targets2, targets3, alpha):
    indices = torch.randperm(data.size(0))
    shuffled_data = data[indices]
    shuffled_targets1 = targets1[indices]
    shuffled_targets2 = targets2[indices]
    shuffled_targets3 = targets3[indices]

    lam = np.random.beta(alpha, alpha)
    data = data * lam + shuffled_data * (1 - lam)
    targets = [targets1, shuffled_targets1, targets2, shuffled_targets2, targets3, shuffled_targets3, lam]

    return data, targets


def cutmix_criterion(preds1,preds2,preds3, targets):
    targets1, targets2,targets3, targets4,targets5, targets6, lam = targets[0], targets[1], targets[2], targets[3], targets[4], targets[5], targets[6]
    criterion = nn.CrossEntropyLoss(reduction='mean')
    return lam * criterion(preds1, targets1) + (1 - lam) * criterion(preds1, targets2) + lam * criterion(preds2, targets3) + (1 - lam) * criterion(preds2, targets4) + lam * criterion(preds3, targets5) + (1 - lam) * criterion(preds3, targets6)

def mixup_criterion(preds1,preds2,preds3, targets):
    targets1, targets2,targets3, targets4,targets5, targets6, lam = targets[0], targets[1], targets[2], targets[3], targets[4], targets[5], targets[6]
    criterion = nn.CrossEntropyLoss(reduction='mean')
    return lam * criterion(preds1, targets1) + (1 - lam) * criterion(preds1, targets2) + lam * criterion(preds2, targets3) + (1 - lam) * criterion(preds2, targets4) + lam * criterion(preds3, targets5) + (1 - lam) * criterion(preds3, targets6)

# %%
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm


def accuracy(y, t):
    pred_label = torch.argmax(y, dim=1)
    count = pred_label.shape[0]
    correct = (pred_label == t).sum().type(torch.double)
    acc = correct / count
    return acc


class BengaliClassifier(nn.Module):
    def __init__(self, predictor, n_grapheme=168, n_vowel=11, n_consonant=7):
        super(BengaliClassifier, self).__init__()
        self.n_grapheme = n_grapheme
        self.n_vowel = n_vowel
        self.n_consonant = n_consonant
        self.n_total_class = self.n_grapheme + self.n_vowel + self.n_consonant
        self.predictor = predictor.float()
        
        self.metrics_keys = [
            'loss', 'loss_grapheme', 'loss_vowel', 'loss_consonant',
            'acc_grapheme', 'acc_vowel', 'acc_consonant']
        
    def forward(self, x, y=None):
        
        const = np.random.randint(6)
        
        if const<2:        
            # mixup
            data, targets = mixup(x, y[:,0], y[:,1], y[:,2], 0.4)
            x = data

        elif const<4:        
            # cutmix
            data, targets = cutmix(x, y[:,0], y[:,1], y[:,2], 0.4)
            x = data

            
            
        pred = self.predictor(x)
        
        if isinstance(pred, tuple):
            assert len(pred) == 3
            preds = pred
        else:
            assert pred.shape[1] == self.n_total_class
            preds = torch.split(pred, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
            
        if const<4:
            # cutmix or mixup
            targets1, targets2, targets3, targets4,targets5, targets6, lam = targets[0], targets[1], targets[2], targets[3], targets[4], targets[5], targets[6]        
            preds1, preds2, preds3 = preds[0], preds[1], preds[2]
            lam = float(lam)
            loss_grapheme = lam * F.cross_entropy(preds1, targets1) + (1 - lam) * F.cross_entropy(preds1, targets2) 
            loss_vowel = lam * F.cross_entropy(preds2, targets3) + (1 - lam) * F.cross_entropy(preds2, targets4)
            loss_consonant = lam * F.cross_entropy(preds3, targets5) + (1 - lam) * F.cross_entropy(preds3, targets6)
            loss = loss_grapheme + loss_vowel + loss_consonant  
        else:
            loss_grapheme = F.cross_entropy(preds[0], y[:, 0])
            loss_vowel = F.cross_entropy(preds[1], y[:, 1])
            loss_consonant = F.cross_entropy(preds[2], y[:, 2])
            loss = loss_grapheme + loss_vowel + loss_consonant
            
        metrics = {
            'loss': loss.item(),
            'loss_grapheme': loss_grapheme.item(),
            'loss_vowel': loss_vowel.item(),
            'loss_consonant': loss_consonant.item(),
            'acc_grapheme': accuracy(preds[0], y[:, 0]),
            'acc_vowel': accuracy(preds[1], y[:, 1]),
            'acc_consonant': accuracy(preds[2], y[:, 2]),
        }
        
        return loss, metrics, pred
    
    
    
    def forward_val(self, x, y=None):

        pred = self.predictor(x)
        
        if isinstance(pred, tuple):
            assert len(pred) == 3
            preds = pred
        else:
            assert pred.shape[1] == self.n_total_class
            preds = torch.split(pred, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        
        loss_grapheme = F.cross_entropy(preds[0], y[:, 0])
        loss_vowel = F.cross_entropy(preds[1], y[:, 1])
        loss_consonant = F.cross_entropy(preds[2], y[:, 2])
        loss = loss_grapheme + loss_vowel + loss_consonant
        metrics = {
            'loss': loss.item(),
            'loss_grapheme': loss_grapheme.item(),
            'loss_vowel': loss_vowel.item(),
            'loss_consonant': loss_consonant.item(),
            'acc_grapheme': accuracy(preds[0], y[:, 0]),
            'acc_vowel': accuracy(preds[1], y[:, 1]),
            'acc_consonant': accuracy(preds[2], y[:, 2]),
        }
        
        return loss, metrics, pred
    

    def calc(self, data_loader):
        device: torch.device = next(self.parameters()).device
        self.eval()
        output_list = []
        with torch.no_grad():
            for batch in tqdm(data_loader):
                # TODO: support general preprocessing.
                # If `data` is not `Data` instance, `to` method is not supported!
                batch = batch.to(device)
                
                
                
                pred = self.predictor(batch)
                
                
                output_list.append(pred)
        output = torch.cat(output_list, dim=0)
        preds = torch.split(output, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        return preds

    def predict_proba(self, data_loader):
        preds = self.calc(data_loader)
        return [F.softmax(p, dim=1) for p in preds]

    def predict(self, data_loader):
        preds = self.calc(data_loader)
        pred_labels = [torch.argmax(p, dim=1) for p in preds]
        return pred_labels

# %% [markdown]
# <a id="train"></a>
# # Training code

# %% [markdown]
# ## prepare data

# %%
n_dataset = len(train_images)
train_data_size = 200 if debug else int(n_dataset * 0.9)
valid_data_size = 100 if debug else int(n_dataset - train_data_size)

perm = np.random.RandomState(777).permutation(n_dataset)
print('perm', perm)
train_dataset = BengaliAIDataset(
    train_images, train_labels, transform=Transform(size=(image_size, image_size)),
    indices=perm[:train_data_size])
valid_dataset = BengaliAIDataset(
    train_images, train_labels, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
    indices=perm[train_data_size:train_data_size+valid_data_size])
print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))

# --- Model ---
device = torch.device(device)
n_grapheme = 168
n_vowel = 11
n_consonant = 7
n_total = n_grapheme + n_vowel + n_consonant
print('n_total', n_total)
# Set pretrained='imagenet' to download imagenet pretrained model...
predictor = PretrainedCNN(in_channels=1, out_dim=n_total, model_name=model_name, pretrained=None)
print('predictor', type(predictor))
# Out:
# perm [ 95762  34576  11800 ... 183206 113455  63591]
# train_dataset 180756 valid_dataset 20084
# n_total 186
# predictor <class '__main__.PretrainedCNN'>

# %%
#load weights
predictor.load_state_dict(torch.load(r"/home/dohee/Documents/Bengali/code/save/model_000030.pt"))
predictor.train()

classifier = BengaliClassifier(predictor).to(device)

# %% [markdown]
# ## Ignite utility
#
# pytorch-ignite utility class for training

# %%
import json
from logging import getLogger
import numpy

def save_json(filepath, params):
    with open(filepath, 'w') as f:
        json.dump(params, f, indent=4)

import os
from logging import getLogger
from time import perf_counter

import pandas as pd
import torch
# from chainer_chemistry.utils import save_json

from ignite.engine.engine import Engine, Events
from ignite.metrics import Average


class DictOutputTransform:
    def __init__(self, key, index=0):
        self.key = key
        self.index = index

    def __call__(self, x):
        if self.index >= 0:
            x = x[self.index]
        return x[self.key]


def create_trainer(classifier, optimizer, device):
    classifier.to(device)    
    def update_fn(engine, batch):
        classifier.train()
        optimizer.zero_grad()

        # batch = [elem.to(device) for elem in batch]
        x, y = [elem.to(device) for elem in batch]
        x = x.float()
        
#         # mixup
#         data, targets = mixup(x, y[:,0], y[:,1], y[:,2], 0.4)
#         #print(data.shape)
#         print(len(targets))
#         print(targets[0].shape)
#         print(y.shape)
        
#         print(targets)
#         print(y)

        
        loss, metrics, pred_y = classifier(x, y)
        
#         print(pred_y.shape)
#         print(pred_y)
#         print("---------------")
        
        loss.backward()
        optimizer.step()
        return metrics, pred_y, y
    
    
    trainer = Engine(update_fn)
    
    for key in classifier.metrics_keys:
        Average(output_transform=DictOutputTransform(key)).attach(trainer, key)
        
    return trainer


def create_evaluator(classifier, device):
    classifier.to(device)
    def update_fn(engine, batch):
        classifier.eval()
        with torch.no_grad():
            # batch = [elem.to(device) for elem in batch]
            x, y = [elem.to(device) for elem in batch]
            x = x.float()
            _, metrics, pred_y = classifier.forward_val(x, y)
            return metrics, pred_y, y
    evaluator = Engine(update_fn)
    for key in classifier.metrics_keys:
        Average(output_transform=DictOutputTransform(key)).attach(evaluator, key)
    return evaluator


class LogReport:
    def __init__(self, evaluator=None, dirpath=None, logger=None):
        self.evaluator = evaluator
        self.dirpath = str(dirpath) if dirpath is not None else None
        self.logger = logger or getLogger(__name__)

        self.reported_dict = {}  # To handle additional parameter to monitor
        self.history = []
        self.start_time = perf_counter()

    def report(self, key, value):
        self.reported_dict[key] = value

    def __call__(self, engine):
        elapsed_time = perf_counter() - self.start_time
        elem = {'epoch': engine.state.epoch,
                'iteration': engine.state.iteration}
        elem.update({f'train/{key}': value
                     for key, value in engine.state.metrics.items()})
        if self.evaluator is not None:
            elem.update({f'valid/{key}': value
                         for key, value in self.evaluator.state.metrics.items()})
        elem.update(self.reported_dict)
        elem['elapsed_time'] = elapsed_time
        self.history.append(elem)
        if self.dirpath:
            save_json(os.path.join(self.dirpath, 'log.json'), self.history)
            self.get_dataframe().to_csv(os.path.join(self.dirpath, 'log.csv'), index=False)

        # --- print ---
        msg = ''
        for key, value in elem.items():
            if key in ['iteration']:
                # skip printing some parameters...
                continue
            elif isinstance(value, int):
                msg += f'{key} {value: >6d} '
            else:
                msg += f'{key} {value: 8f} '
#         self.logger.warning(msg)
        print(msg)

        # --- Reset ---
        self.reported_dict = {}

    def get_dataframe(self):
        df = pd.DataFrame(self.history)
        return df


class SpeedCheckHandler:
    def __init__(self, iteration_interval=10, logger=None):
        self.iteration_interval = iteration_interval
        self.logger = logger or getLogger(__name__)
        self.prev_time = perf_counter()

    def __call__(self, engine: Engine):
        if engine.state.iteration % self.iteration_interval == 0:
            cur_time = perf_counter()
            spd = self.iteration_interval / (cur_time - self.prev_time)
            self.logger.warning(f'{spd} iter/sec')
            # reset
            self.prev_time = cur_time

    def attach(self, engine: Engine):
        engine.add_event_handler(Events.ITERATION_COMPLETED, self)


class ModelSnapshotHandler:
    def __init__(self, model, filepath=r'./save/model_{count:06}.pt',
                 interval=10, logger=None):
        self.model = model
        self.filepath: str = str(filepath)
        self.interval = interval
        self.logger = logger or getLogger(__name__)
        self.count = 0

    def __call__(self, engine: Engine):
        self.count += 1
        if self.count % self.interval == 0:
            filepath = self.filepath.format(count=self.count)
            torch.save(self.model.state_dict(), filepath)
            print("saving model epoch:", self.count)
            
            #self.logger.warning(f'save model to {filepath}...')


import warnings

import torch

from ignite.metrics.metric import Metric


class EpochMetric(Metric):
    """Class for metrics that should be computed on the entire output history of a model.
    Model's output and targets are restricted to be of shape `(batch_size, n_classes)`. Output
    datatype should be `float32`. Target datatype should be `long`.

    .. warning::

        Current implementation stores all input data (output and target) in as tensors before computing a metric.
        This can potentially lead to a memory error if the input data is larger than available RAM.


    - `update` must receive output of the form `(y_pred, y)`.

    If target shape is `(batch_size, n_classes)` and `n_classes > 1` than it should be binary: e.g. `[[0, 1, 0, 1], ]`.

    Args:
        compute_fn (callable): a callable with the signature (`torch.tensor`, `torch.tensor`) takes as the input
            `predictions` and `targets` and returns a scalar.
        output_transform (callable, optional): a callable that is used to transform the
            :class:`~ignite.engine.Engine`'s `process_function`'s output into the
            form expected by the metric. This can be useful if, for example, you have a multi-output model and
            you want to compute the metric with respect to one of the outputs.

    """

    def __init__(self, compute_fn, output_transform=lambda x: x):

        if not callable(compute_fn):
            raise TypeError("Argument compute_fn should be callable.")

        super(EpochMetric, self).__init__(output_transform=output_transform)
        self.compute_fn = compute_fn

    def reset(self):
        self._predictions = torch.tensor([], dtype=torch.float)
        self._targets = torch.tensor([], dtype=torch.long)

    def update(self, output):
        y_pred, y = output
        self._predictions = torch.cat([self._predictions, y_pred], dim=0)
        self._targets = torch.cat([self._targets, y], dim=0)

        # Check once the signature and execution of compute_fn
        if self._predictions.shape == y_pred.shape:
            try:
                self.compute_fn(self._predictions, self._targets)
            except Exception as e:
                warnings.warn("Probably, there can be a problem with `compute_fn`:\n {}.".format(e),
                              RuntimeWarning)

    def compute(self):
        return self.compute_fn(self._predictions, self._targets)


import numpy as np
import sklearn.metrics
import torch


def macro_recall(pred_y, y, n_grapheme=168, n_vowel=11, n_consonant=7):
    pred_y = torch.split(pred_y, [n_grapheme, n_vowel, n_consonant], dim=1)
    pred_labels = [torch.argmax(py, dim=1).cpu().numpy() for py in pred_y]

    y = y.cpu().numpy()
    # pred_y = [p.cpu().numpy() for p in pred_y]

    recall_grapheme = sklearn.metrics.recall_score(pred_labels[0], y[:, 0], average='macro')
    recall_vowel = sklearn.metrics.recall_score(pred_labels[1], y[:, 1], average='macro')
    recall_consonant = sklearn.metrics.recall_score(pred_labels[2], y[:, 2], average='macro')
    scores = [recall_grapheme, recall_vowel, recall_consonant]
    final_score = np.average(scores, weights=[2, 1, 1])
    # print(f'recall: grapheme {recall_grapheme}, vowel {recall_vowel}, consonant {recall_consonant}, '
    #       f'total {final_score}, y {y.shape}')
    return final_score


def calc_macro_recall(solution, submission):
    # solution df, submission df
    scores = []
    for component in ['grapheme_root', 'consonant_diacritic', 'vowel_diacritic']:
        y_true_subset = solution[solution[component] == component]['target'].values
        y_pred_subset = submission[submission[component] == component]['target'].values
        scores.append(sklearn.metrics.recall_score(
            y_true_subset, y_pred_subset, average='macro'))
    final_score = np.average(scores, weights=[2, 1, 1])
    return final_score

# %%
# def create_trainer(classifier, optimizer, device):
#     classifier.to(device)    
#     def update_fn(engine, batch):
#         classifier.train()
#         optimizer.zero_grad()

#         # batch = [elem.to(device) for elem in batch]
#         x, y = [elem.to(device) for elem in batch]        
#         x = x.float()
        
#         print(x.shape)
#         print(y.shape)
        
#         loss, metrics, pred_y = classifier(x, y)

# %%
# from ignite.handlers import ModelCheckpoint

# checkpoint_every = 10

# dirname = r"./save"
# engine_checkpoint = ModelCheckpoint(
#     dirname=dirname,
#     'my_model',
#     save_interval=checkpoint_every,
#     create_dir = True)

# %%
import argparse
from distutils.util import strtobool
import os

import torch
from ignite.contrib.handlers import ProgressBar
from ignite.engine import Events
from numpy.random.mtrand import RandomState
from torch.utils.data.dataloader import DataLoader

# --- Training setting ---

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

optimizer = torch.optim.Adam(classifier.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=4, min_lr=1e-10)

trainer = create_trainer(classifier, optimizer, device)
def output_transform(output):
    metric, pred_y, y = output
    return pred_y.cpu(), y.cpu()
EpochMetric(
    compute_fn=macro_recall,
    output_transform=output_transform
).attach(trainer, 'recall')

pbar = ProgressBar()
pbar.attach(trainer, metric_names='all')

evaluator = create_evaluator(classifier, device)
EpochMetric(
    compute_fn=macro_recall,
    output_transform=output_transform
).attach(evaluator, 'recall')

def run_evaluator(engine):
    evaluator.run(valid_loader)

def schedule_lr(engine):
    # metrics = evaluator.state.metrics
    metrics = engine.state.metrics
    avg_mae = metrics['loss']

    # --- update lr ---
    lr = scheduler.optimizer.param_groups[0]['lr']
    scheduler.step(avg_mae)
    log_report.report('lr', lr)

trainer.add_event_handler(Events.EPOCH_COMPLETED, run_evaluator)
trainer.add_event_handler(Events.EPOCH_COMPLETED, schedule_lr)
log_report = LogReport(evaluator, outdir)
trainer.add_event_handler(Events.EPOCH_COMPLETED, log_report)
trainer.add_event_handler(
    Events.EPOCH_COMPLETED,
    ModelSnapshotHandler(predictor))
    #ModelSnapshotHandler(predictor, filepath=outdir / 'predictor.pt'))

#trainer.add_event_handler(Events.EPOCH_COMPLETED, engine_checkpoint, {'mymodel':classifier})
# Out:
# /home/dohee/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/contrib/handlers/tqdm_logger.py:106: TqdmExperimentalWarning:
#
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
trainer.run(train_loader, max_epochs=70)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# /home/dohee/anaconda3/envs/Bengali/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# epoch      1 train/loss  1.536609 train/loss_grapheme  0.837371 train/loss_vowel  0.417455 train/loss_consonant  0.281784 train/acc_grapheme  0.680130 train/acc_vowel  0.763220 train/acc_consonant  0.838359 train/recall  0.725049 valid/loss  0.241021 valid/loss_grapheme  0.136838 valid/loss_vowel  0.053237 valid/loss_consonant  0.050946 valid/acc_grapheme  0.965963 valid/acc_vowel  0.991093 valid/acc_consonant  0.989600 valid/recall  0.972800 lr  0.001000 elapsed_time  968.021750
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      2 train/loss  1.502409 train/loss_grapheme  0.818108 train/loss_vowel  0.409500 train/loss_consonant  0.274801 train/acc_grapheme  0.695013 train/acc_vowel  0.775881 train/acc_consonant  0.845193 train/recall  0.738432 valid/loss  0.252595 valid/loss_grapheme  0.146295 valid/loss_vowel  0.054571 valid/loss_consonant  0.051729 valid/acc_grapheme  0.965361 valid/acc_vowel  0.990297 valid/acc_consonant  0.989401 valid/recall  0.974532 lr  0.001000 elapsed_time  1931.971979
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      3 train/loss  1.458575 train/loss_grapheme  0.792680 train/loss_vowel  0.398687 train/loss_consonant  0.267209 train/acc_grapheme  0.697644 train/acc_vowel  0.775540 train/acc_consonant  0.846440 train/recall  0.739211 valid/loss  0.254719 valid/loss_grapheme  0.146566 valid/loss_vowel  0.056040 valid/loss_consonant  0.052114 valid/acc_grapheme  0.963177 valid/acc_vowel  0.991043 valid/acc_consonant  0.988854 valid/recall  0.972208 lr  0.001000 elapsed_time  2895.190992
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      4 train/loss  1.458214 train/loss_grapheme  0.789239 train/loss_vowel  0.401417 train/loss_consonant  0.267557 train/acc_grapheme  0.703103 train/acc_vowel  0.779342 train/acc_consonant  0.849426 train/recall  0.741756 valid/loss  0.257695 valid/loss_grapheme  0.145806 valid/loss_vowel  0.055621 valid/loss_consonant  0.056268 valid/acc_grapheme  0.965416 valid/acc_vowel  0.990784 valid/acc_consonant  0.989650 valid/recall  0.974434 lr  0.001000 elapsed_time  3857.000694
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      5 train/loss  1.500807 train/loss_grapheme  0.813341 train/loss_vowel  0.411764 train/loss_consonant  0.275701 train/acc_grapheme  0.692520 train/acc_vowel  0.772834 train/acc_consonant  0.845331 train/recall  0.735615 valid/loss  0.244947 valid/loss_grapheme  0.144240 valid/loss_vowel  0.053729 valid/loss_consonant  0.046978 valid/acc_grapheme  0.964958 valid/acc_vowel  0.990894 valid/acc_consonant  0.989893 valid/recall  0.974451 lr  0.001000 elapsed_time  4818.722992
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      6 train/loss  1.460354 train/loss_grapheme  0.790687 train/loss_vowel  0.400053 train/loss_consonant  0.269613 train/acc_grapheme  0.702661 train/acc_vowel  0.777656 train/acc_consonant  0.847944 train/recall  0.744014 valid/loss  0.238843 valid/loss_grapheme  0.141538 valid/loss_vowel  0.051498 valid/loss_consonant  0.045808 valid/acc_grapheme  0.965411 valid/acc_vowel  0.990048 valid/acc_consonant  0.990092 valid/recall  0.974627 lr  0.001000 elapsed_time  5781.377203
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      7 train/loss  1.484044 train/loss_grapheme  0.801656 train/loss_vowel  0.409290 train/loss_consonant  0.273098 train/acc_grapheme  0.696163 train/acc_vowel  0.769413 train/acc_consonant  0.843732 train/recall  0.735929 valid/loss  0.248444 valid/loss_grapheme  0.148270 valid/loss_vowel  0.052623 valid/loss_consonant  0.047551 valid/acc_grapheme  0.961231 valid/acc_vowel  0.989645 valid/acc_consonant  0.989301 valid/recall  0.971674 lr  0.001000 elapsed_time  6742.795879
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      8 train/loss  1.470148 train/loss_grapheme  0.792807 train/loss_vowel  0.405510 train/loss_consonant  0.271831 train/acc_grapheme  0.687169 train/acc_vowel  0.765983 train/acc_consonant  0.841127 train/recall  0.728991 valid/loss  0.244535 valid/loss_grapheme  0.143554 valid/loss_vowel  0.052435 valid/loss_consonant  0.048546 valid/acc_grapheme  0.964371 valid/acc_vowel  0.989943 valid/acc_consonant  0.989401 valid/recall  0.972674 lr  0.001000 elapsed_time  7705.631207
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      9 train/loss  1.451226 train/loss_grapheme  0.784066 train/loss_vowel  0.399985 train/loss_consonant  0.267175 train/acc_grapheme  0.706260 train/acc_vowel  0.781635 train/acc_consonant  0.850462 train/recall  0.747448 valid/loss  0.237352 valid/loss_grapheme  0.149817 valid/loss_vowel  0.044375 valid/loss_consonant  0.043159 valid/acc_grapheme  0.963674 valid/acc_vowel  0.990396 valid/acc_consonant  0.989749 valid/recall  0.973390 lr  0.001000 elapsed_time  8667.306274
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     10 train/loss  1.442610 train/loss_grapheme  0.776661 train/loss_vowel  0.398449 train/loss_consonant  0.267499 train/acc_grapheme  0.692869 train/acc_vowel  0.769230 train/acc_consonant  0.842948 train/recall  0.734295 valid/loss  0.240561 valid/loss_grapheme  0.141677 valid/loss_vowel  0.050343 valid/loss_consonant  0.048540 valid/acc_grapheme  0.965560 valid/acc_vowel  0.991043 valid/acc_consonant  0.989744 valid/recall  0.974448 lr  0.001000 elapsed_time  9629.986445
# saving model epoch: 10
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     11 train/loss  1.419052 train/loss_grapheme  0.765079 train/loss_vowel  0.391589 train/loss_consonant  0.262384 train/acc_grapheme  0.705302 train/acc_vowel  0.781417 train/acc_consonant  0.850986 train/recall  0.748067 valid/loss  0.243866 valid/loss_grapheme  0.142060 valid/loss_vowel  0.053590 valid/loss_consonant  0.048216 valid/acc_grapheme  0.966013 valid/acc_vowel  0.990496 valid/acc_consonant  0.990048 valid/recall  0.972606 lr  0.001000 elapsed_time  10593.452261
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     12 train/loss  1.445353 train/loss_grapheme  0.777988 train/loss_vowel  0.399084 train/loss_consonant  0.268281 train/acc_grapheme  0.693136 train/acc_vowel  0.769196 train/acc_consonant  0.844068 train/recall  0.733492 valid/loss  0.235329 valid/loss_grapheme  0.142656 valid/loss_vowel  0.048035 valid/loss_consonant  0.044637 valid/acc_grapheme  0.965655 valid/acc_vowel  0.989003 valid/acc_consonant  0.989500 valid/recall  0.973567 lr  0.001000 elapsed_time  11556.229135
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     13 train/loss  1.430426 train/loss_grapheme  0.768420 train/loss_vowel  0.396441 train/loss_consonant  0.265565 train/acc_grapheme  0.709791 train/acc_vowel  0.781073 train/acc_consonant  0.850012 train/recall  0.748363 valid/loss  0.237332 valid/loss_grapheme  0.144574 valid/loss_vowel  0.047539 valid/loss_consonant  0.045219 valid/acc_grapheme  0.964067 valid/acc_vowel  0.990844 valid/acc_consonant  0.989246 valid/recall  0.972383 lr  0.001000 elapsed_time  12520.157281
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     14 train/loss  1.446182 train/loss_grapheme  0.775662 train/loss_vowel  0.402406 train/loss_consonant  0.268114 train/acc_grapheme  0.697353 train/acc_vowel  0.771088 train/acc_consonant  0.843938 train/recall  0.736904 valid/loss  0.249918 valid/loss_grapheme  0.151413 valid/loss_vowel  0.047064 valid/loss_consonant  0.051441 valid/acc_grapheme  0.963774 valid/acc_vowel  0.989152 valid/acc_consonant  0.987654 valid/recall  0.972520 lr  0.001000 elapsed_time  13482.889404
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     15 train/loss  1.425181 train/loss_grapheme  0.764170 train/loss_vowel  0.395483 train/loss_consonant  0.265528 train/acc_grapheme  0.702304 train/acc_vowel  0.777886 train/acc_consonant  0.847432 train/recall  0.740680 valid/loss  0.232245 valid/loss_grapheme  0.139978 valid/loss_vowel  0.046967 valid/loss_consonant  0.045299 valid/acc_grapheme  0.965764 valid/acc_vowel  0.990744 valid/acc_consonant  0.990048 valid/recall  0.974238 lr  0.001000 elapsed_time  14444.989169
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     16 train/loss  1.494733 train/loss_grapheme  0.803325 train/loss_vowel  0.414445 train/loss_consonant  0.276963 train/acc_grapheme  0.678460 train/acc_vowel  0.757421 train/acc_consonant  0.833922 train/recall  0.720547 valid/loss  0.235058 valid/loss_grapheme  0.140764 valid/loss_vowel  0.048296 valid/loss_consonant  0.045997 valid/acc_grapheme  0.966710 valid/acc_vowel  0.989943 valid/acc_consonant  0.990087 valid/recall  0.973986 lr  0.001000 elapsed_time  15406.342991
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     17 train/loss  1.408813 train/loss_grapheme  0.751120 train/loss_vowel  0.394056 train/loss_consonant  0.263636 train/acc_grapheme  0.709094 train/acc_vowel  0.783974 train/acc_consonant  0.850462 train/recall  0.748596 valid/loss  0.215149 valid/loss_grapheme  0.126830 valid/loss_vowel  0.044641 valid/loss_consonant  0.043677 valid/acc_grapheme  0.969695 valid/acc_vowel  0.992138 valid/acc_consonant  0.990839 valid/recall  0.976174 lr  0.000500 elapsed_time  16367.601541
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     18 train/loss  1.384366 train/loss_grapheme  0.735079 train/loss_vowel  0.388343 train/loss_consonant  0.260944 train/acc_grapheme  0.704452 train/acc_vowel  0.776097 train/acc_consonant  0.848118 train/recall  0.743411 valid/loss  0.227896 valid/loss_grapheme  0.134208 valid/loss_vowel  0.046360 valid/loss_consonant  0.047328 valid/acc_grapheme  0.968745 valid/acc_vowel  0.991839 valid/acc_consonant  0.989844 valid/recall  0.976122 lr  0.000500 elapsed_time  17330.396614
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     19 train/loss  1.329846 train/loss_grapheme  0.705625 train/loss_vowel  0.374628 train/loss_consonant  0.249593 train/acc_grapheme  0.694357 train/acc_vowel  0.766429 train/acc_consonant  0.841158 train/recall  0.731749 valid/loss  0.215657 valid/loss_grapheme  0.135486 valid/loss_vowel  0.038449 valid/loss_consonant  0.041722 valid/acc_grapheme  0.967108 valid/acc_vowel  0.991541 valid/acc_consonant  0.990446 valid/recall  0.976312 lr  0.000500 elapsed_time  18291.745132
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     20 train/loss  1.353498 train/loss_grapheme  0.716115 train/loss_vowel  0.382010 train/loss_consonant  0.255374 train/acc_grapheme  0.695954 train/acc_vowel  0.765365 train/acc_consonant  0.840941 train/recall  0.731460 valid/loss  0.215191 valid/loss_grapheme  0.132294 valid/loss_vowel  0.041544 valid/loss_consonant  0.041353 valid/acc_grapheme  0.968894 valid/acc_vowel  0.992237 valid/acc_consonant  0.990839 valid/recall  0.976724 lr  0.000500 elapsed_time  19253.655550
# saving model epoch: 20
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     21 train/loss  1.341291 train/loss_grapheme  0.711511 train/loss_vowel  0.378195 train/loss_consonant  0.251584 train/acc_grapheme  0.686018 train/acc_vowel  0.759162 train/acc_consonant  0.835456 train/recall  0.723957 valid/loss  0.220524 valid/loss_grapheme  0.140195 valid/loss_vowel  0.037344 valid/loss_consonant  0.042985 valid/acc_grapheme  0.967750 valid/acc_vowel  0.991690 valid/acc_consonant  0.991137 valid/recall  0.977159 lr  0.000500 elapsed_time  20215.278268
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     22 train/loss  1.340748 train/loss_grapheme  0.708289 train/loss_vowel  0.378500 train/loss_consonant  0.253960 train/acc_grapheme  0.710296 train/acc_vowel  0.776169 train/acc_consonant  0.847344 train/recall  0.744663 valid/loss  0.212274 valid/loss_grapheme  0.133566 valid/loss_vowel  0.037563 valid/loss_consonant  0.041146 valid/acc_grapheme  0.968302 valid/acc_vowel  0.992237 valid/acc_consonant  0.991093 valid/recall  0.977113 lr  0.000500 elapsed_time  21173.990305
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     23 train/loss  1.336454 train/loss_grapheme  0.706288 train/loss_vowel  0.378410 train/loss_consonant  0.251755 train/acc_grapheme  0.701078 train/acc_vowel  0.771584 train/acc_consonant  0.844954 train/recall  0.737591 valid/loss  0.223554 valid/loss_grapheme  0.133650 valid/loss_vowel  0.044000 valid/loss_consonant  0.045903 valid/acc_grapheme  0.968446 valid/acc_vowel  0.992337 valid/acc_consonant  0.990247 valid/recall  0.976396 lr  0.000500 elapsed_time  22136.661624
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     24 train/loss  1.282254 train/loss_grapheme  0.675672 train/loss_vowel  0.363690 train/loss_consonant  0.242892 train/acc_grapheme  0.718181 train/acc_vowel  0.784403 train/acc_consonant  0.853457 train/recall  0.751768 valid/loss  0.222580 valid/loss_grapheme  0.131875 valid/loss_vowel  0.045558 valid/loss_consonant  0.045147 valid/acc_grapheme  0.969442 valid/acc_vowel  0.992635 valid/acc_consonant  0.991287 valid/recall  0.977179 lr  0.000500 elapsed_time  23095.729925
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     25 train/loss  1.348557 train/loss_grapheme  0.711783 train/loss_vowel  0.382460 train/loss_consonant  0.254314 train/acc_grapheme  0.697482 train/acc_vowel  0.769582 train/acc_consonant  0.843501 train/recall  0.733276 valid/loss  0.218540 valid/loss_grapheme  0.138074 valid/loss_vowel  0.039447 valid/loss_consonant  0.041019 valid/acc_grapheme  0.968048 valid/acc_vowel  0.991640 valid/acc_consonant  0.991336 valid/recall  0.976386 lr  0.000500 elapsed_time  24055.394627
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     26 train/loss  1.320902 train/loss_grapheme  0.696425 train/loss_vowel  0.374839 train/loss_consonant  0.249639 train/acc_grapheme  0.708000 train/acc_vowel  0.775901 train/acc_consonant  0.847041 train/recall  0.745008 valid/loss  0.212647 valid/loss_grapheme  0.135621 valid/loss_vowel  0.037355 valid/loss_consonant  0.039672 valid/acc_grapheme  0.968795 valid/acc_vowel  0.992536 valid/acc_consonant  0.991292 valid/recall  0.977965 lr  0.000500 elapsed_time  25013.773412
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     27 train/loss  1.308631 train/loss_grapheme  0.690611 train/loss_vowel  0.370681 train/loss_consonant  0.247339 train/acc_grapheme  0.713584 train/acc_vowel  0.783987 train/acc_consonant  0.852093 train/recall  0.749497 valid/loss  0.215863 valid/loss_grapheme  0.135825 valid/loss_vowel  0.038851 valid/loss_consonant  0.041188 valid/acc_grapheme  0.969292 valid/acc_vowel  0.992387 valid/acc_consonant  0.991441 valid/recall  0.978251 lr  0.000500 elapsed_time  25969.533812
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     28 train/loss  1.338852 train/loss_grapheme  0.705261 train/loss_vowel  0.380200 train/loss_consonant  0.253391 train/acc_grapheme  0.705569 train/acc_vowel  0.778403 train/acc_consonant  0.850335 train/recall  0.745197 valid/loss  0.218008 valid/loss_grapheme  0.136340 valid/loss_vowel  0.038985 valid/loss_consonant  0.042683 valid/acc_grapheme  0.969248 valid/acc_vowel  0.991690 valid/acc_consonant  0.990993 valid/recall  0.976906 lr  0.000500 elapsed_time  26924.810233
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     29 train/loss  1.335774 train/loss_grapheme  0.702304 train/loss_vowel  0.380585 train/loss_consonant  0.252884 train/acc_grapheme  0.709002 train/acc_vowel  0.780020 train/acc_consonant  0.850788 train/recall  0.745267 valid/loss  0.219721 valid/loss_grapheme  0.137212 valid/loss_vowel  0.039523 valid/loss_consonant  0.042986 valid/acc_grapheme  0.968894 valid/acc_vowel  0.992138 valid/acc_consonant  0.990386 valid/recall  0.976433 lr  0.000500 elapsed_time  27879.894770
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     30 train/loss  1.292245 train/loss_grapheme  0.677404 train/loss_vowel  0.368389 train/loss_consonant  0.246452 train/acc_grapheme  0.719837 train/acc_vowel  0.785349 train/acc_consonant  0.854279 train/recall  0.754095 valid/loss  0.210232 valid/loss_grapheme  0.131257 valid/loss_vowel  0.038413 valid/loss_consonant  0.040562 valid/acc_grapheme  0.970039 valid/acc_vowel  0.992337 valid/acc_consonant  0.991331 valid/recall  0.977706 lr  0.000250 elapsed_time  28835.401182
# saving model epoch: 30
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     31 train/loss  1.319736 train/loss_grapheme  0.697022 train/loss_vowel  0.374099 train/loss_consonant  0.248614 train/acc_grapheme  0.713738 train/acc_vowel  0.785668 train/acc_consonant  0.854709 train/recall  0.750634 valid/loss  0.213174 valid/loss_grapheme  0.131680 valid/loss_vowel  0.039418 valid/loss_consonant  0.042075 valid/acc_grapheme  0.970039 valid/acc_vowel  0.992586 valid/acc_consonant  0.991983 valid/recall  0.977008 lr  0.000250 elapsed_time  29790.121829
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     32 train/loss  1.285254 train/loss_grapheme  0.674591 train/loss_vowel  0.364824 train/loss_consonant  0.245839 train/acc_grapheme  0.728531 train/acc_vowel  0.794945 train/acc_consonant  0.859845 train/recall  0.764525 valid/loss  0.212755 valid/loss_grapheme  0.132910 valid/loss_vowel  0.039852 valid/loss_consonant  0.039994 valid/acc_grapheme  0.970287 valid/acc_vowel  0.991784 valid/acc_consonant  0.991287 valid/recall  0.977324 lr  0.000250 elapsed_time  30744.517096
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     33 train/loss  1.265002 train/loss_grapheme  0.664407 train/loss_vowel  0.359903 train/loss_consonant  0.240693 train/acc_grapheme  0.718087 train/acc_vowel  0.784473 train/acc_consonant  0.853155 train/recall  0.751563 valid/loss  0.210229 valid/loss_grapheme  0.129352 valid/loss_vowel  0.039314 valid/loss_consonant  0.041564 valid/acc_grapheme  0.970238 valid/acc_vowel  0.992884 valid/acc_consonant  0.991535 valid/recall  0.978670 lr  0.000250 elapsed_time  31693.268990
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     34 train/loss  1.255432 train/loss_grapheme  0.660459 train/loss_vowel  0.357549 train/loss_consonant  0.237424 train/acc_grapheme  0.709483 train/acc_vowel  0.778325 train/acc_consonant  0.849633 train/recall  0.743617 valid/loss  0.213104 valid/loss_grapheme  0.133262 valid/loss_vowel  0.038544 valid/loss_consonant  0.041298 valid/acc_grapheme  0.970536 valid/acc_vowel  0.992138 valid/acc_consonant  0.991486 valid/recall  0.978456 lr  0.000250 elapsed_time  32640.567225
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     35 train/loss  1.218720 train/loss_grapheme  0.637382 train/loss_vowel  0.350211 train/loss_consonant  0.231127 train/acc_grapheme  0.702040 train/acc_vowel  0.767384 train/acc_consonant  0.843920 train/recall  0.734804 valid/loss  0.215069 valid/loss_grapheme  0.132366 valid/loss_vowel  0.041076 valid/loss_consonant  0.041627 valid/acc_grapheme  0.970586 valid/acc_vowel  0.992635 valid/acc_consonant  0.991884 valid/recall  0.978367 lr  0.000250 elapsed_time  33589.104113
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     36 train/loss  1.282368 train/loss_grapheme  0.672857 train/loss_vowel  0.367273 train/loss_consonant  0.242237 train/acc_grapheme  0.713066 train/acc_vowel  0.777872 train/acc_consonant  0.849937 train/recall  0.747530 valid/loss  0.211180 valid/loss_grapheme  0.132970 valid/loss_vowel  0.037090 valid/loss_consonant  0.041120 valid/acc_grapheme  0.970282 valid/acc_vowel  0.992536 valid/acc_consonant  0.991934 valid/recall  0.978124 lr  0.000250 elapsed_time  34538.104064
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     37 train/loss  1.243013 train/loss_grapheme  0.649156 train/loss_vowel  0.355149 train/loss_consonant  0.238708 train/acc_grapheme  0.723350 train/acc_vowel  0.785236 train/acc_consonant  0.852967 train/recall  0.755107 valid/loss  0.214834 valid/loss_grapheme  0.133304 valid/loss_vowel  0.039949 valid/loss_consonant  0.041580 valid/acc_grapheme  0.970536 valid/acc_vowel  0.992038 valid/acc_consonant  0.991237 valid/recall  0.977982 lr  0.000250 elapsed_time  35487.305729
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     38 train/loss  1.278877 train/loss_grapheme  0.671688 train/loss_vowel  0.364252 train/loss_consonant  0.242938 train/acc_grapheme  0.704669 train/acc_vowel  0.774066 train/acc_consonant  0.847050 train/recall  0.740053 valid/loss  0.211556 valid/loss_grapheme  0.130753 valid/loss_vowel  0.039526 valid/loss_consonant  0.041276 valid/acc_grapheme  0.970586 valid/acc_vowel  0.992536 valid/acc_consonant  0.991884 valid/recall  0.977203 lr  0.000250 elapsed_time  36435.463239
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     39 train/loss  1.286351 train/loss_grapheme  0.674562 train/loss_vowel  0.366508 train/loss_consonant  0.245280 train/acc_grapheme  0.725621 train/acc_vowel  0.792933 train/acc_consonant  0.859385 train/recall  0.761396 valid/loss  0.209378 valid/loss_grapheme  0.131989 valid/loss_vowel  0.037217 valid/loss_consonant  0.040171 valid/acc_grapheme  0.970387 valid/acc_vowel  0.992586 valid/acc_consonant  0.991735 valid/recall  0.977193 lr  0.000250 elapsed_time  37383.523508
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     40 train/loss  1.228896 train/loss_grapheme  0.640330 train/loss_vowel  0.352364 train/loss_consonant  0.236203 train/acc_grapheme  0.722125 train/acc_vowel  0.784640 train/acc_consonant  0.854459 train/recall  0.754457 valid/loss  0.218362 valid/loss_grapheme  0.139075 valid/loss_vowel  0.037002 valid/loss_consonant  0.042285 valid/acc_grapheme  0.970188 valid/acc_vowel  0.992486 valid/acc_consonant  0.991137 valid/recall  0.978415 lr  0.000250 elapsed_time  38331.988005
# saving model epoch: 40
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     41 train/loss  1.193528 train/loss_grapheme  0.623054 train/loss_vowel  0.342898 train/loss_consonant  0.227576 train/acc_grapheme  0.727905 train/acc_vowel  0.789093 train/acc_consonant  0.857909 train/recall  0.758257 valid/loss  0.209379 valid/loss_grapheme  0.132401 valid/loss_vowel  0.036847 valid/loss_consonant  0.040131 valid/acc_grapheme  0.970885 valid/acc_vowel  0.992436 valid/acc_consonant  0.991436 valid/recall  0.979038 lr  0.000125 elapsed_time  39280.311856
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     42 train/loss  1.251823 train/loss_grapheme  0.653358 train/loss_vowel  0.359092 train/loss_consonant  0.239373 train/acc_grapheme  0.725020 train/acc_vowel  0.791164 train/acc_consonant  0.857429 train/recall  0.757733 valid/loss  0.215097 valid/loss_grapheme  0.135629 valid/loss_vowel  0.038055 valid/loss_consonant  0.041413 valid/acc_grapheme  0.970885 valid/acc_vowel  0.992586 valid/acc_consonant  0.991386 valid/recall  0.977780 lr  0.000125 elapsed_time  40226.847755
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     43 train/loss  1.273642 train/loss_grapheme  0.667826 train/loss_vowel  0.364107 train/loss_consonant  0.241709 train/acc_grapheme  0.712298 train/acc_vowel  0.781759 train/acc_consonant  0.853409 train/recall  0.749433 valid/loss  0.215295 valid/loss_grapheme  0.136351 valid/loss_vowel  0.036894 valid/loss_consonant  0.042049 valid/acc_grapheme  0.971283 valid/acc_vowel  0.992486 valid/acc_consonant  0.991232 valid/recall  0.978699 lr  0.000125 elapsed_time  41173.697574
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     44 train/loss  1.217671 train/loss_grapheme  0.632696 train/loss_vowel  0.350661 train/loss_consonant  0.234314 train/acc_grapheme  0.696998 train/acc_vowel  0.760975 train/acc_consonant  0.837862 train/recall  0.728787 valid/loss  0.216756 valid/loss_grapheme  0.138390 valid/loss_vowel  0.036572 valid/loss_consonant  0.041795 valid/acc_grapheme  0.971283 valid/acc_vowel  0.992536 valid/acc_consonant  0.991535 valid/recall  0.978380 lr  0.000125 elapsed_time  42120.691576
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     45 train/loss  1.233790 train/loss_grapheme  0.643730 train/loss_vowel  0.353567 train/loss_consonant  0.236493 train/acc_grapheme  0.708604 train/acc_vowel  0.773985 train/acc_consonant  0.847150 train/recall  0.741246 valid/loss  0.215139 valid/loss_grapheme  0.136468 valid/loss_vowel  0.036424 valid/loss_consonant  0.042248 valid/acc_grapheme  0.970536 valid/acc_vowel  0.992337 valid/acc_consonant  0.991431 valid/recall  0.977452 lr  0.000125 elapsed_time  43068.769931
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     46 train/loss  1.314085 train/loss_grapheme  0.688363 train/loss_vowel  0.375743 train/loss_consonant  0.249979 train/acc_grapheme  0.702882 train/acc_vowel  0.772971 train/acc_consonant  0.846157 train/recall  0.740674 valid/loss  0.211497 valid/loss_grapheme  0.134109 valid/loss_vowel  0.037174 valid/loss_consonant  0.040214 valid/acc_grapheme  0.971432 valid/acc_vowel  0.992486 valid/acc_consonant  0.991381 valid/recall  0.977686 lr  0.000125 elapsed_time  44016.679778
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     47 train/loss  1.255925 train/loss_grapheme  0.655303 train/loss_vowel  0.361104 train/loss_consonant  0.239519 train/acc_grapheme  0.702909 train/acc_vowel  0.767704 train/acc_consonant  0.844823 train/recall  0.735030 valid/loss  0.216671 valid/loss_grapheme  0.139464 valid/loss_vowel  0.036298 valid/loss_consonant  0.040909 valid/acc_grapheme  0.970238 valid/acc_vowel  0.992934 valid/acc_consonant  0.991287 valid/recall  0.978454 lr  0.000063 elapsed_time  44962.879983
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     48 train/loss  1.227017 train/loss_grapheme  0.638327 train/loss_vowel  0.352033 train/loss_consonant  0.236657 train/acc_grapheme  0.717422 train/acc_vowel  0.781223 train/acc_consonant  0.851104 train/recall  0.747775 valid/loss  0.214224 valid/loss_grapheme  0.135055 valid/loss_vowel  0.037042 valid/loss_consonant  0.042127 valid/acc_grapheme  0.971731 valid/acc_vowel  0.992387 valid/acc_consonant  0.991237 valid/recall  0.977764 lr  0.000063 elapsed_time  45911.145979
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     49 train/loss  1.213000 train/loss_grapheme  0.630152 train/loss_vowel  0.348527 train/loss_consonant  0.234321 train/acc_grapheme  0.711820 train/acc_vowel  0.775686 train/acc_consonant  0.848794 train/recall  0.744534 valid/loss  0.211543 valid/loss_grapheme  0.133871 valid/loss_vowel  0.036503 valid/loss_consonant  0.041169 valid/acc_grapheme  0.971382 valid/acc_vowel  0.992436 valid/acc_consonant  0.991535 valid/recall  0.978063 lr  0.000063 elapsed_time  46859.475028
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     50 train/loss  1.255587 train/loss_grapheme  0.653569 train/loss_vowel  0.360883 train/loss_consonant  0.241135 train/acc_grapheme  0.701693 train/acc_vowel  0.770585 train/acc_consonant  0.845348 train/recall  0.738090 valid/loss  0.209399 valid/loss_grapheme  0.131392 valid/loss_vowel  0.036794 valid/loss_consonant  0.041213 valid/acc_grapheme  0.971731 valid/acc_vowel  0.993033 valid/acc_consonant  0.991585 valid/recall  0.978472 lr  0.000063 elapsed_time  47805.361625
# saving model epoch: 50
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     51 train/loss  1.231011 train/loss_grapheme  0.641392 train/loss_vowel  0.354035 train/loss_consonant  0.235585 train/acc_grapheme  0.716776 train/acc_vowel  0.783008 train/acc_consonant  0.853470 train/recall  0.750640 valid/loss  0.215833 valid/loss_grapheme  0.138112 valid/loss_vowel  0.036165 valid/loss_consonant  0.041556 valid/acc_grapheme  0.971482 valid/acc_vowel  0.992984 valid/acc_consonant  0.991287 valid/recall  0.978296 lr  0.000063 elapsed_time  48752.156265
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     52 train/loss  1.231421 train/loss_grapheme  0.643253 train/loss_vowel  0.352332 train/loss_consonant  0.235835 train/acc_grapheme  0.720695 train/acc_vowel  0.788535 train/acc_consonant  0.856543 train/recall  0.756226 valid/loss  0.218348 valid/loss_grapheme  0.139882 valid/loss_vowel  0.036301 valid/loss_consonant  0.042165 valid/acc_grapheme  0.971133 valid/acc_vowel  0.992536 valid/acc_consonant  0.991635 valid/recall  0.978671 lr  0.000031 elapsed_time  49699.200464
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     53 train/loss  1.220027 train/loss_grapheme  0.634701 train/loss_vowel  0.351243 train/loss_consonant  0.234083 train/acc_grapheme  0.710997 train/acc_vowel  0.777740 train/acc_consonant  0.849653 train/recall  0.743221 valid/loss  0.212226 valid/loss_grapheme  0.135409 valid/loss_vowel  0.036245 valid/loss_consonant  0.040572 valid/acc_grapheme  0.970785 valid/acc_vowel  0.992586 valid/acc_consonant  0.991187 valid/recall  0.977558 lr  0.000031 elapsed_time  50647.417576
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     54 train/loss  1.214688 train/loss_grapheme  0.629366 train/loss_vowel  0.350260 train/loss_consonant  0.235062 train/acc_grapheme  0.723405 train/acc_vowel  0.786395 train/acc_consonant  0.855873 train/recall  0.753956 valid/loss  0.216950 valid/loss_grapheme  0.138196 valid/loss_vowel  0.036964 valid/loss_consonant  0.041789 valid/acc_grapheme  0.971880 valid/acc_vowel  0.992586 valid/acc_consonant  0.991535 valid/recall  0.979110 lr  0.000031 elapsed_time  51594.205257
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     55 train/loss  1.271647 train/loss_grapheme  0.663324 train/loss_vowel  0.365493 train/loss_consonant  0.242831 train/acc_grapheme  0.731721 train/acc_vowel  0.798091 train/acc_consonant  0.863184 train/recall  0.763749 valid/loss  0.210501 valid/loss_grapheme  0.133882 valid/loss_vowel  0.035597 valid/loss_consonant  0.041023 valid/acc_grapheme  0.972178 valid/acc_vowel  0.992486 valid/acc_consonant  0.991535 valid/recall  0.978510 lr  0.000031 elapsed_time  52546.739416
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     56 train/loss  1.264905 train/loss_grapheme  0.657882 train/loss_vowel  0.364031 train/loss_consonant  0.242992 train/acc_grapheme  0.708093 train/acc_vowel  0.776567 train/acc_consonant  0.848892 train/recall  0.742661 valid/loss  0.214931 valid/loss_grapheme  0.138697 valid/loss_vowel  0.035381 valid/loss_consonant  0.040853 valid/acc_grapheme  0.971780 valid/acc_vowel  0.992735 valid/acc_consonant  0.991535 valid/recall  0.978820 lr  0.000031 elapsed_time  53512.222728
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     57 train/loss  1.237689 train/loss_grapheme  0.643513 train/loss_vowel  0.357678 train/loss_consonant  0.236497 train/acc_grapheme  0.703661 train/acc_vowel  0.768926 train/acc_consonant  0.844920 train/recall  0.737167 valid/loss  0.215267 valid/loss_grapheme  0.139152 valid/loss_vowel  0.035617 valid/loss_consonant  0.040498 valid/acc_grapheme  0.971034 valid/acc_vowel  0.992785 valid/acc_consonant  0.991535 valid/recall  0.978169 lr  0.000016 elapsed_time  54523.163038
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))

# %%
trainer.run(train_loader, max_epochs=100)
# Out:
# /home/dohee/anaconda3/envs/Bengali/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      1 train/loss  4.827845 train/loss_grapheme  2.828597 train/loss_vowel  1.070026 train/loss_consonant  0.929223 train/acc_grapheme  0.377914 train/acc_vowel  0.649865 train/acc_consonant  0.741892 train/recall  0.502938 valid/loss  1.326741 valid/loss_grapheme  0.712581 valid/loss_vowel  0.316736 valid/loss_consonant  0.297424 valid/acc_grapheme  0.854287 valid/acc_vowel  0.952730 valid/acc_consonant  0.948969 valid/recall  0.904968 lr  0.001000 elapsed_time  956.746390
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      2 train/loss  2.905535 train/loss_grapheme  1.646367 train/loss_vowel  0.731884 train/loss_consonant  0.527283 train/acc_grapheme  0.581521 train/acc_vowel  0.721927 train/acc_consonant  0.809906 train/recall  0.656298 valid/loss  0.736257 valid/loss_grapheme  0.382563 valid/loss_vowel  0.179415 valid/loss_consonant  0.174279 valid/acc_grapheme  0.918678 valid/acc_vowel  0.976403 valid/acc_consonant  0.973328 valid/recall  0.945799 lr  0.001000 elapsed_time  1915.131610
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      3 train/loss  2.541691 train/loss_grapheme  1.450130 train/loss_vowel  0.655054 train/loss_consonant  0.436506 train/acc_grapheme  0.605488 train/acc_vowel  0.731819 train/acc_consonant  0.818496 train/recall  0.673429 valid/loss  0.593013 valid/loss_grapheme  0.296028 valid/loss_vowel  0.160901 valid/loss_consonant  0.136083 valid/acc_grapheme  0.933255 valid/acc_vowel  0.979250 valid/acc_consonant  0.980638 valid/recall  0.951590 lr  0.001000 elapsed_time  2872.689658
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      4 train/loss  2.345762 train/loss_grapheme  1.341540 train/loss_vowel  0.608113 train/loss_consonant  0.396109 train/acc_grapheme  0.626299 train/acc_vowel  0.741596 train/acc_consonant  0.825859 train/recall  0.693575 valid/loss  0.463415 valid/loss_grapheme  0.247179 valid/loss_vowel  0.119047 valid/loss_consonant  0.097189 valid/acc_grapheme  0.942461 valid/acc_vowel  0.983315 valid/acc_consonant  0.982175 valid/recall  0.957202 lr  0.001000 elapsed_time  3831.974139
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      5 train/loss  2.283225 train/loss_grapheme  1.304484 train/loss_vowel  0.594029 train/loss_consonant  0.384712 train/acc_grapheme  0.626100 train/acc_vowel  0.739005 train/acc_consonant  0.823677 train/recall  0.693577 valid/loss  0.506266 valid/loss_grapheme  0.256920 valid/loss_vowel  0.141007 valid/loss_consonant  0.108339 valid/acc_grapheme  0.944312 valid/acc_vowel  0.981290 valid/acc_consonant  0.982285 valid/recall  0.959213 lr  0.001000 elapsed_time  4789.468900
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      6 train/loss  2.156046 train/loss_grapheme  1.230087 train/loss_vowel  0.560784 train/loss_consonant  0.365175 train/acc_grapheme  0.642614 train/acc_vowel  0.750086 train/acc_consonant  0.829651 train/recall  0.707828 valid/loss  0.407494 valid/loss_grapheme  0.220048 valid/loss_vowel  0.102316 valid/loss_consonant  0.085130 valid/acc_grapheme  0.945590 valid/acc_vowel  0.983972 valid/acc_consonant  0.982021 valid/recall  0.960819 lr  0.001000 elapsed_time  5744.869780
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      7 train/loss  2.103014 train/loss_grapheme  1.195579 train/loss_vowel  0.551758 train/loss_consonant  0.355676 train/acc_grapheme  0.643388 train/acc_vowel  0.744143 train/acc_consonant  0.827002 train/recall  0.704365 valid/loss  0.466503 valid/loss_grapheme  0.237859 valid/loss_vowel  0.128401 valid/loss_consonant  0.100242 valid/acc_grapheme  0.948830 valid/acc_vowel  0.984862 valid/acc_consonant  0.985514 valid/recall  0.963110 lr  0.001000 elapsed_time  6693.419512
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      8 train/loss  2.039855 train/loss_grapheme  1.160092 train/loss_vowel  0.532901 train/loss_consonant  0.346862 train/acc_grapheme  0.638133 train/acc_vowel  0.741995 train/acc_consonant  0.824892 train/recall  0.698413 valid/loss  0.429286 valid/loss_grapheme  0.216225 valid/loss_vowel  0.120423 valid/loss_consonant  0.092638 valid/acc_grapheme  0.952468 valid/acc_vowel  0.985116 valid/acc_consonant  0.986067 valid/recall  0.963145 lr  0.001000 elapsed_time  7641.824182
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch      9 train/loss  1.964028 train/loss_grapheme  1.114267 train/loss_vowel  0.514010 train/loss_consonant  0.335751 train/acc_grapheme  0.663170 train/acc_vowel  0.759665 train/acc_consonant  0.835971 train/recall  0.721509 valid/loss  0.374592 valid/loss_grapheme  0.200529 valid/loss_vowel  0.087592 valid/loss_consonant  0.086471 valid/acc_grapheme  0.954608 valid/acc_vowel  0.985564 valid/acc_consonant  0.985012 valid/recall  0.965685 lr  0.001000 elapsed_time  8592.552860
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     10 train/loss  1.918401 train/loss_grapheme  1.084344 train/loss_vowel  0.503756 train/loss_consonant  0.330302 train/acc_grapheme  0.652650 train/acc_vowel  0.750387 train/acc_consonant  0.831149 train/recall  0.712589 valid/loss  0.336670 valid/loss_grapheme  0.191155 valid/loss_vowel  0.076201 valid/loss_consonant  0.069314 valid/acc_grapheme  0.953463 valid/acc_vowel  0.987609 valid/acc_consonant  0.987301 valid/recall  0.965696 lr  0.001000 elapsed_time  9541.208231
# saving model epoch: 10
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     11 train/loss  1.858885 train/loss_grapheme  1.050593 train/loss_vowel  0.487666 train/loss_consonant  0.320626 train/acc_grapheme  0.667113 train/acc_vowel  0.763327 train/acc_consonant  0.839489 train/recall  0.726023 valid/loss  0.357929 valid/loss_grapheme  0.192725 valid/loss_vowel  0.084365 valid/loss_consonant  0.080838 valid/acc_grapheme  0.953667 valid/acc_vowel  0.987803 valid/acc_consonant  0.986166 valid/recall  0.967105 lr  0.001000 elapsed_time  10493.242533
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     12 train/loss  1.860842 train/loss_grapheme  1.047982 train/loss_vowel  0.489881 train/loss_consonant  0.322979 train/acc_grapheme  0.658989 train/acc_vowel  0.753593 train/acc_consonant  0.833287 train/recall  0.714277 valid/loss  0.350055 valid/loss_grapheme  0.184233 valid/loss_vowel  0.085797 valid/loss_consonant  0.080025 valid/acc_grapheme  0.958096 valid/acc_vowel  0.988057 valid/acc_consonant  0.986952 valid/recall  0.969558 lr  0.001000 elapsed_time  11448.120928
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     13 train/loss  1.819988 train/loss_grapheme  1.022991 train/loss_vowel  0.479953 train/loss_consonant  0.317044 train/acc_grapheme  0.674259 train/acc_vowel  0.765537 train/acc_consonant  0.838186 train/recall  0.726285 valid/loss  0.356794 valid/loss_grapheme  0.185556 valid/loss_vowel  0.092200 valid/loss_consonant  0.079038 valid/acc_grapheme  0.957399 valid/acc_vowel  0.988102 valid/acc_consonant  0.987405 valid/recall  0.969123 lr  0.001000 elapsed_time  12402.241593
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     14 train/loss  1.814237 train/loss_grapheme  1.015087 train/loss_vowel  0.481998 train/loss_consonant  0.317152 train/acc_grapheme  0.666565 train/acc_vowel  0.757680 train/acc_consonant  0.834699 train/recall  0.718333 valid/loss  0.368309 valid/loss_grapheme  0.181885 valid/loss_vowel  0.100678 valid/loss_consonant  0.085746 valid/acc_grapheme  0.959330 valid/acc_vowel  0.987455 valid/acc_consonant  0.987052 valid/recall  0.967665 lr  0.001000 elapsed_time  13356.207743
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     15 train/loss  1.770179 train/loss_grapheme  0.989038 train/loss_vowel  0.469762 train/loss_consonant  0.311379 train/acc_grapheme  0.671886 train/acc_vowel  0.764486 train/acc_consonant  0.837143 train/recall  0.722756 valid/loss  0.303353 valid/loss_grapheme  0.163789 valid/loss_vowel  0.071838 valid/loss_consonant  0.067726 valid/acc_grapheme  0.960435 valid/acc_vowel  0.988744 valid/acc_consonant  0.988196 valid/recall  0.969188 lr  0.001000 elapsed_time  14311.354443
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     16 train/loss  1.832128 train/loss_grapheme  1.023228 train/loss_vowel  0.487012 train/loss_consonant  0.321888 train/acc_grapheme  0.650478 train/acc_vowel  0.744815 train/acc_consonant  0.826159 train/recall  0.705151 valid/loss  0.305489 valid/loss_grapheme  0.168745 valid/loss_vowel  0.071773 valid/loss_consonant  0.064971 valid/acc_grapheme  0.959280 valid/acc_vowel  0.988644 valid/acc_consonant  0.987958 valid/recall  0.970117 lr  0.001000 elapsed_time  15263.443975
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     17 train/loss  1.769010 train/loss_grapheme  0.985974 train/loss_vowel  0.470910 train/loss_consonant  0.312126 train/acc_grapheme  0.677857 train/acc_vowel  0.769885 train/acc_consonant  0.840917 train/recall  0.730702 valid/loss  0.285065 valid/loss_grapheme  0.161013 valid/loss_vowel  0.065525 valid/loss_consonant  0.058527 valid/acc_grapheme  0.959639 valid/acc_vowel  0.989197 valid/acc_consonant  0.988555 valid/recall  0.969513 lr  0.001000 elapsed_time  16214.430100
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     18 train/loss  1.740437 train/loss_grapheme  0.966589 train/loss_vowel  0.464675 train/loss_consonant  0.309174 train/acc_grapheme  0.674599 train/acc_vowel  0.761628 train/acc_consonant  0.838321 train/recall  0.726193 valid/loss  0.279020 valid/loss_grapheme  0.159033 valid/loss_vowel  0.062162 valid/loss_consonant  0.057825 valid/acc_grapheme  0.960485 valid/acc_vowel  0.988854 valid/acc_consonant  0.988052 valid/recall  0.971531 lr  0.001000 elapsed_time  17168.818703
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     19 train/loss  1.672509 train/loss_grapheme  0.928393 train/loss_vowel  0.447388 train/loss_consonant  0.296729 train/acc_grapheme  0.664359 train/acc_vowel  0.753472 train/acc_consonant  0.831356 train/recall  0.713626 valid/loss  0.280198 valid/loss_grapheme  0.163352 valid/loss_vowel  0.063903 valid/loss_consonant  0.052943 valid/acc_grapheme  0.956797 valid/acc_vowel  0.987803 valid/acc_consonant  0.988406 valid/recall  0.968102 lr  0.001000 elapsed_time  18143.359347
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     20 train/loss  1.690495 train/loss_grapheme  0.935611 train/loss_vowel  0.453466 train/loss_consonant  0.301419 train/acc_grapheme  0.666449 train/acc_vowel  0.753177 train/acc_consonant  0.831822 train/recall  0.712941 valid/loss  0.273542 valid/loss_grapheme  0.156077 valid/loss_vowel  0.060745 valid/loss_consonant  0.056720 valid/acc_grapheme  0.960938 valid/acc_vowel  0.989993 valid/acc_consonant  0.989252 valid/recall  0.972096 lr  0.001000 elapsed_time  19153.071557
# saving model epoch: 20
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     21 train/loss  1.665728 train/loss_grapheme  0.922225 train/loss_vowel  0.447183 train/loss_consonant  0.296320 train/acc_grapheme  0.658451 train/acc_vowel  0.748292 train/acc_consonant  0.827721 train/recall  0.707464 valid/loss  0.289019 valid/loss_grapheme  0.162091 valid/loss_vowel  0.066136 valid/loss_consonant  0.060793 valid/acc_grapheme  0.960136 valid/acc_vowel  0.989645 valid/acc_consonant  0.988102 valid/recall  0.969464 lr  0.001000 elapsed_time  20161.699919
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     22 train/loss  1.657438 train/loss_grapheme  0.914199 train/loss_vowel  0.444918 train/loss_consonant  0.298321 train/acc_grapheme  0.681869 train/acc_vowel  0.765695 train/acc_consonant  0.839117 train/recall  0.729262 valid/loss  0.276041 valid/loss_grapheme  0.154255 valid/loss_vowel  0.066677 valid/loss_consonant  0.055109 valid/acc_grapheme  0.962629 valid/acc_vowel  0.989844 valid/acc_consonant  0.988854 valid/recall  0.970773 lr  0.001000 elapsed_time  21152.455219
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     23 train/loss  1.644703 train/loss_grapheme  0.908210 train/loss_vowel  0.442326 train/loss_consonant  0.294167 train/acc_grapheme  0.673826 train/acc_vowel  0.760661 train/acc_consonant  0.836556 train/recall  0.722509 valid/loss  0.266099 valid/loss_grapheme  0.152395 valid/loss_vowel  0.061210 valid/loss_consonant  0.052494 valid/acc_grapheme  0.961629 valid/acc_vowel  0.989650 valid/acc_consonant  0.989500 valid/recall  0.969773 lr  0.001000 elapsed_time  22108.879823
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     24 train/loss  1.579351 train/loss_grapheme  0.868736 train/loss_vowel  0.425475 train/loss_consonant  0.285139 train/acc_grapheme  0.691985 train/acc_vowel  0.772692 train/acc_consonant  0.844484 train/recall  0.735945 valid/loss  0.254284 valid/loss_grapheme  0.145136 valid/loss_vowel  0.055687 valid/loss_consonant  0.053461 valid/acc_grapheme  0.964266 valid/acc_vowel  0.989799 valid/acc_consonant  0.989197 valid/recall  0.971822 lr  0.001000 elapsed_time  23083.206412
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     25 train/loss  1.643042 train/loss_grapheme  0.902470 train/loss_vowel  0.444446 train/loss_consonant  0.296125 train/acc_grapheme  0.671935 train/acc_vowel  0.758087 train/acc_consonant  0.835644 train/recall  0.718279 valid/loss  0.258978 valid/loss_grapheme  0.150454 valid/loss_vowel  0.055105 valid/loss_consonant  0.053419 valid/acc_grapheme  0.962530 valid/acc_vowel  0.990048 valid/acc_consonant  0.989998 valid/recall  0.972598 lr  0.001000 elapsed_time  24069.483329
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     26 train/loss  1.600549 train/loss_grapheme  0.878765 train/loss_vowel  0.433750 train/loss_consonant  0.288034 train/acc_grapheme  0.683075 train/acc_vowel  0.765594 train/acc_consonant  0.840078 train/recall  0.730782 valid/loss  0.241235 valid/loss_grapheme  0.141901 valid/loss_vowel  0.050792 valid/loss_consonant  0.048542 valid/acc_grapheme  0.964018 valid/acc_vowel  0.991043 valid/acc_consonant  0.990092 valid/recall  0.973669 lr  0.001000 elapsed_time  25040.248863
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     27 train/loss  1.585255 train/loss_grapheme  0.869920 train/loss_vowel  0.428939 train/loss_consonant  0.286396 train/acc_grapheme  0.688323 train/acc_vowel  0.773648 train/acc_consonant  0.843773 train/recall  0.734474 valid/loss  0.258386 valid/loss_grapheme  0.150866 valid/loss_vowel  0.055547 valid/loss_consonant  0.051973 valid/acc_grapheme  0.962381 valid/acc_vowel  0.989998 valid/acc_consonant  0.990247 valid/recall  0.969190 lr  0.001000 elapsed_time  26044.928030
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     28 train/loss  1.610166 train/loss_grapheme  0.881173 train/loss_vowel  0.437296 train/loss_consonant  0.291697 train/acc_grapheme  0.681114 train/acc_vowel  0.768119 train/acc_consonant  0.843684 train/recall  0.731211 valid/loss  0.258346 valid/loss_grapheme  0.149556 valid/loss_vowel  0.058802 valid/loss_consonant  0.049988 valid/acc_grapheme  0.963027 valid/acc_vowel  0.988749 valid/acc_consonant  0.989252 valid/recall  0.969790 lr  0.001000 elapsed_time  27009.494478
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     29 train/loss  1.606715 train/loss_grapheme  0.878396 train/loss_vowel  0.437340 train/loss_consonant  0.290979 train/acc_grapheme  0.685148 train/acc_vowel  0.770154 train/acc_consonant  0.843756 train/recall  0.732619 valid/loss  0.245412 valid/loss_grapheme  0.148184 valid/loss_vowel  0.048139 valid/loss_consonant  0.049090 valid/acc_grapheme  0.961529 valid/acc_vowel  0.989451 valid/acc_consonant  0.987798 valid/recall  0.968568 lr  0.001000 elapsed_time  27983.937433
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     30 train/loss  1.500173 train/loss_grapheme  0.813423 train/loss_vowel  0.411362 train/loss_consonant  0.275387 train/acc_grapheme  0.702071 train/acc_vowel  0.777731 train/acc_consonant  0.849057 train/recall  0.743686 valid/loss  0.220178 valid/loss_grapheme  0.131445 valid/loss_vowel  0.044040 valid/loss_consonant  0.044693 valid/acc_grapheme  0.966058 valid/acc_vowel  0.991441 valid/acc_consonant  0.990734 valid/recall  0.972922 lr  0.000500 elapsed_time  28950.837346
# saving model epoch: 30
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# epoch     31 train/loss  1.494575 train/loss_grapheme  0.811626 train/loss_vowel  0.409753 train/loss_consonant  0.273196 train/acc_grapheme  0.699109 train/acc_vowel  0.779442 train/acc_consonant  0.849478 train/recall  0.742936 valid/loss  0.226267 valid/loss_grapheme  0.133049 valid/loss_vowel  0.047209 valid/loss_consonant  0.046009 valid/acc_grapheme  0.966610 valid/acc_vowel  0.991934 valid/acc_consonant  0.990943 valid/recall  0.974135 lr  0.000500 elapsed_time  29928.406086
# HBox(children=(FloatProgress(value=0.0, max=1413.0), HTML(value='')))
# Current run is terminating due to exception: .
# Engine run is terminating due to exception: .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-7ec8a5fb9654> in <module>
# ----> 1 trainer.run(train_loader, max_epochs=100)
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in run(self, data, max_epochs, epoch_length, seed)
#     848
#     849         self.state.dataloader = data
# --> 850         return self._internal_run()
#     851
#     852     def _setup_engine(self):
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in _internal_run(self)
#     950             self._dataloader_iter = self._dataloader_len = None
#     951             self.logger.error("Engine run is terminating due to exception: %s.", str(e))
# --> 952             self._handle_exception(e)
#     953
#     954         self._dataloader_iter = self._dataloader_len = None
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in _handle_exception(self, e)
#     714             self._fire_event(Events.EXCEPTION_RAISED, e)
#     715         else:
# --> 716             raise e
#     717
#     718     def state_dict(self):
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in _internal_run(self)
#     935                     self._setup_engine()
#     936
# --> 937                 hours, mins, secs = self._run_once_on_dataset()
#     938
#     939                 self.logger.info("Epoch[%s] Complete. Time taken: %02d:%02d:%02d", self.state.epoch, hours, mins, secs)
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in _run_once_on_dataset(self)
#     703         except BaseException as e:
#     704             self.logger.error("Current run is terminating due to exception: %s.", str(e))
# --> 705             self._handle_exception(e)
#     706
#     707         time_taken = time.time() - start_time
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in _handle_exception(self, e)
#     714             self._fire_event(Events.EXCEPTION_RAISED, e)
#     715         else:
# --> 716             raise e
#     717
#     718     def state_dict(self):
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/ignite/engine/engine.py in _run_once_on_dataset(self)
#     686                 self.state.iteration += 1
#     687                 self._fire_event(Events.ITERATION_STARTED)
# --> 688                 self.state.output = self._process_function(self, self.state.batch)
#     689                 self._fire_event(Events.ITERATION_COMPLETED)
#     690
#
# <ipython-input-33-fc7d5dc4f990> in update_fn(engine, batch)
#      58
#      59         loss.backward()
# ---> 60         optimizer.step()
#      61         return metrics, pred_y, y
#      62
#
# ~/anaconda3/envs/Bengali/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      98                     denom = max_exp_avg_sq.sqrt().add_(group['eps'])
#      99                 else:
# --> 100                     denom = exp_avg_sq.sqrt().add_(group['eps'])
#     101
#     102                 bias_correction1 = 1 - beta1 ** state['step']
#
# KeyboardInterrupt:

# %%
train_history = log_report.get_dataframe()
train_history.to_csv(outdir / 'log.csv', index=False)

train_history
# Out:
#     epoch  iteration  train/loss  train/loss_grapheme  train/loss_vowel  \
# 0       1       1413    4.827845             2.828597          1.070026
# 1       2       2826    2.905535             1.646367          0.731884
# 2       3       4239    2.541691             1.450130          0.655054
# 3       4       5652    2.345762             1.341540          0.608113
# 4       5       7065    2.283225             1.304484          0.594029
# 5       6       8478    2.156046             1.230087          0.560784
# 6       7       9891    2.103014             1.195579          0.551758
# 7       8      11304    2.039855             1.160092          0.532901
# 8       9      12717    1.964028             1.114267          0.514010
# 9      10      14130    1.918401             1.084344          0.503756
# 10     11      15543    1.858885             1.050593          0.487666
# 11     12      16956    1.860842             1.047982          0.489881
# 12     13      18369    1.819988             1.022991          0.479953
# 13     14      19782    1.814237             1.015087          0.481998
# 14     15      21195    1.770179             0.989038          0.469762
# 15     16      22608    1.832128             1.023228          0.487012
# 16     17      24021    1.769010             0.985974          0.470910
# 17     18      25434    1.740437             0.966589          0.464675
# 18     19      26847    1.672509             0.928393          0.447388
# 19     20      28260    1.690495             0.935611          0.453466
# 20     21      29673    1.665728             0.922225          0.447183
# 21     22      31086    1.657438             0.914199          0.444918
# 22     23      32499    1.644703             0.908210          0.442326
# 23     24      33912    1.579351             0.868736          0.425475
# 24     25      35325    1.643042             0.902470          0.444446
# 25     26      36738    1.600549             0.878765          0.433750
# 26     27      38151    1.585255             0.869920          0.428939
# 27     28      39564    1.610166             0.881173          0.437296
# 28     29      40977    1.606715             0.878396          0.437340
# 29     30      42390    1.500173             0.813423          0.411362
# 30     31      43803    1.494575             0.811626          0.409753
#
#     train/loss_consonant  train/acc_grapheme  train/acc_vowel  \
# 0               0.929223            0.377914         0.649865
# 1               0.527283            0.581521         0.721927
# 2               0.436506            0.605488         0.731819
# 3               0.396109            0.626299         0.741596
# 4               0.384712            0.626100         0.739005
# 5               0.365175            0.642614         0.750086
# 6               0.355676            0.643388         0.744143
# 7               0.346862            0.638133         0.741995
# 8               0.335751            0.663170         0.759665
# 9               0.330302            0.652650         0.750387
# 10              0.320626            0.667113         0.763327
# 11              0.322979            0.658989         0.753593
# 12              0.317044            0.674259         0.765537
# 13              0.317152            0.666565         0.757680
# 14              0.311379            0.671886         0.764486
# 15              0.321888            0.650478         0.744815
# 16              0.312126            0.677857         0.769885
# 17              0.309174            0.674599         0.761628
# 18              0.296729            0.664359         0.753472
# 19              0.301419            0.666449         0.753177
# 20              0.296320            0.658451         0.748292
# 21              0.298321            0.681869         0.765695
# 22              0.294167            0.673826         0.760661
# 23              0.285139            0.691985         0.772692
# 24              0.296125            0.671935         0.758087
# 25              0.288034            0.683075         0.765594
# 26              0.286396            0.688323         0.773648
# 27              0.291697            0.681114         0.768119
# 28              0.290979            0.685148         0.770154
# 29              0.275387            0.702071         0.777731
# 30              0.273196            0.699109         0.779442
#
#     train/acc_consonant  train/recall  valid/loss  valid/loss_grapheme  \
# 0              0.741892      0.502938    1.326741             0.712581
# 1              0.809906      0.656298    0.736257             0.382563
# 2              0.818496      0.673429    0.593013             0.296028
# 3              0.825859      0.693575    0.463415             0.247179
# 4              0.823677      0.693577    0.506266             0.256920
# 5              0.829651      0.707828    0.407494             0.220048
# 6              0.827002      0.704365    0.466503             0.237859
# 7              0.824892      0.698413    0.429286             0.216225
# 8              0.835971      0.721509    0.374592             0.200529
# 9              0.831149      0.712589    0.336670             0.191155
# 10             0.839489      0.726023    0.357929             0.192725
# 11             0.833287      0.714277    0.350055             0.184233
# 12             0.838186      0.726285    0.356794             0.185556
# 13             0.834699      0.718333    0.368309             0.181885
# 14             0.837143      0.722756    0.303353             0.163789
# 15             0.826159      0.705151    0.305489             0.168745
# 16             0.840917      0.730702    0.285065             0.161013
# 17             0.838321      0.726193    0.279020             0.159033
# 18             0.831356      0.713626    0.280198             0.163352
# 19             0.831822      0.712941    0.273542             0.156077
# 20             0.827721      0.707464    0.289019             0.162091
# 21             0.839117      0.729262    0.276041             0.154255
# 22             0.836556      0.722509    0.266099             0.152395
# 23             0.844484      0.735945    0.254284             0.145136
# 24             0.835644      0.718279    0.258978             0.150454
# 25             0.840078      0.730782    0.241235             0.141901
# 26             0.843773      0.734474    0.258386             0.150866
# 27             0.843684      0.731211    0.258346             0.149556
# 28             0.843756      0.732619    0.245412             0.148184
# 29             0.849057      0.743686    0.220178             0.131445
# 30             0.849478      0.742936    0.226267             0.133049
#
#     valid/loss_vowel  valid/loss_consonant  valid/acc_grapheme  \
# 0           0.316736              0.297424            0.854287
# 1           0.179415              0.174279            0.918678
# 2           0.160901              0.136083            0.933255
# 3           0.119047              0.097189            0.942461
# 4           0.141007              0.108339            0.944312
# 5           0.102316              0.085130            0.945590
# 6           0.128401              0.100242            0.948830
# 7           0.120423              0.092638            0.952468
# 8           0.087592              0.086471            0.954608
# 9           0.076201              0.069314            0.953463
# 10          0.084365              0.080838            0.953667
# 11          0.085797              0.080025            0.958096
# 12          0.092200              0.079038            0.957399
# 13          0.100678              0.085746            0.959330
# 14          0.071838              0.067726            0.960435
# 15          0.071773              0.064971            0.959280
# 16          0.065525              0.058527            0.959639
# 17          0.062162              0.057825            0.960485
# 18          0.063903              0.052943            0.956797
# 19          0.060745              0.056720            0.960938
# 20          0.066136              0.060793            0.960136
# 21          0.066677              0.055109            0.962629
# 22          0.061210              0.052494            0.961629
# 23          0.055687              0.053461            0.964266
# 24          0.055105              0.053419            0.962530
# 25          0.050792              0.048542            0.964018
# 26          0.055547              0.051973            0.962381
# 27          0.058802              0.049988            0.963027
# 28          0.048139              0.049090            0.961529
# 29          0.044040              0.044693            0.966058
# 30          0.047209              0.046009            0.966610
#
#     valid/acc_vowel  valid/acc_consonant  valid/recall      lr  elapsed_time
# 0          0.952730             0.948969      0.904968  0.0010    956.746390
# 1          0.976403             0.973328      0.945799  0.0010   1915.131610
# 2          0.979250             0.980638      0.951590  0.0010   2872.689658
# 3          0.983315             0.982175      0.957202  0.0010   3831.974139
# 4          0.981290             0.982285      0.959213  0.0010   4789.468900
# 5          0.983972             0.982021      0.960819  0.0010   5744.869780
# 6          0.984862             0.985514      0.963110  0.0010   6693.419512
# 7          0.985116             0.986067      0.963145  0.0010   7641.824182
# 8          0.985564             0.985012      0.965685  0.0010   8592.552860
# 9          0.987609             0.987301      0.965696  0.0010   9541.208231
# 10         0.987803             0.986166      0.967105  0.0010  10493.242533
# 11         0.988057             0.986952      0.969558  0.0010  11448.120928
# 12         0.988102             0.987405      0.969123  0.0010  12402.241593
# 13         0.987455             0.987052      0.967665  0.0010  13356.207743
# 14         0.988744             0.988196      0.969188  0.0010  14311.354443
# 15         0.988644             0.987958      0.970117  0.0010  15263.443975
# 16         0.989197             0.988555      0.969513  0.0010  16214.430100
# 17         0.988854             0.988052      0.971531  0.0010  17168.818703
# 18         0.987803             0.988406      0.968102  0.0010  18143.359347
# 19         0.989993             0.989252      0.972096  0.0010  19153.071557
# 20         0.989645             0.988102      0.969464  0.0010  20161.699919
# 21         0.989844             0.988854      0.970773  0.0010  21152.455219
# 22         0.989650             0.989500      0.969773  0.0010  22108.879823
# 23         0.989799             0.989197      0.971822  0.0010  23083.206412
# 24         0.990048             0.989998      0.972598  0.0010  24069.483329
# 25         0.991043             0.990092      0.973669  0.0010  25040.248863
# 26         0.989998             0.990247      0.969190  0.0010  26044.928030
# 27         0.988749             0.989252      0.969790  0.0010  27009.494478
# 28         0.989451             0.987798      0.968568  0.0010  27983.937433
# 29         0.991441             0.990734      0.972922  0.0005  28950.837346
# 30         0.991934             0.990943      0.974135  0.0005  29928.406086

# %% [markdown]
# <a id="pred"></a>
# # Prediction
#
# Please refer **[Bengali: SEResNeXt prediction with pytorch](https://www.kaggle.com/corochann/bengali-seresnext-prediction-with-pytorch)** for the prediction with trained model and submission for this competition!!!

# %%
# --- Model ---
device = torch.device(device)
n_grapheme = 168
n_vowel = 11
n_consonant = 7
n_total = n_grapheme + n_vowel + n_consonant
print('n_total', n_total)

# %%
def build_predictor(arch, out_dim, model_name=None):
    if arch == 'pretrained':
        predictor = PretrainedCNN(in_channels=1, out_dim=out_dim, model_name=model_name)
    else:
        raise ValueError("[ERROR] Unexpected value arch={}".format(arch))
    return predictor


def build_classifier(arch, load_model_path, n_total, model_name='', device='cuda:0'):
    if isinstance(device, str):
        device = torch.device(device)
    predictor = build_predictor(arch, out_dim=n_total, model_name=model_name)
    print('predictor', type(predictor))
    classifier = BengaliClassifier(predictor)
    if load_model_path:
        predictor.load_state_dict(torch.load(load_model_path))
    else:
        print("[WARNING] Unexpected value load_model_path={}"
              .format(load_model_path))
    classifier.to(device)
    return classifier

# %%
def predict_core(test_images, image_size, threshold,
                 arch, n_total, model_name, load_model_path, batch_size=512, device='cuda:0', **kwargs):
    classifier = build_classifier(arch, load_model_path, n_total, model_name, device=device)
    

    r"""
    ###############
    n_dataset = len(test_images)
    train_data_size = 200 if debug else int(n_dataset * 0.9)
    valid_data_size = 100 if debug else int(n_dataset - train_data_size)
    
    perm = np.random.RandomState(777).permutation(n_dataset)
    print('perm', perm)
    train_dataset = BengaliAIDataset(
        train_images, train_labels, transform=Transform(size=(image_size, image_size)),
        indices=perm[:train_data_size])
    valid_dataset = BengaliAIDataset(
        train_images, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
        )
    print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))
    test_dataset = valid_dataset
    """
    
    test_dataset = BengaliAIDataset(
       test_images, None,
       transform=Transform(affine=False, crop=True, size=(image_size, image_size),
                           threshold=threshold, train=False))
    print('test_dataset', len(test_dataset))
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    test_pred_proba = classifier.predict_proba(test_loader)
    return test_pred_proba

# %%
from torch import nn
import torch.nn.functional as F


class LinearBlock(nn.Module):

    def __init__(self, in_features, out_features, bias=True,
                 use_bn=True, activation=F.relu, dropout_ratio=-1, residual=False,):
        super(LinearBlock, self).__init__()
        if in_features is None:
            self.linear = LazyLinear(in_features, out_features, bias=bias)
        else:
            self.linear = nn.Linear(in_features, out_features, bias=bias)
        if use_bn:
            self.bn = nn.BatchNorm1d(out_features)
        if dropout_ratio > 0.:
            self.dropout = nn.Dropout(p=dropout_ratio)
        else:
            self.dropout = None
        self.activation = activation
        self.use_bn = use_bn
        self.dropout_ratio = dropout_ratio
        self.residual = residual

    def __call__(self, x):
        h = self.linear(x)
        if self.use_bn:
            h = self.bn(h)
        if self.activation is not None:
            h = self.activation(h)
        if self.residual:
            h = residual_add(h, x)
        if self.dropout_ratio > 0:
            h = self.dropout(h)
        return h

# %%
import pretrainedmodels
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Sequential

class PretrainedCNN(nn.Module):
    def __init__(self, model_name='se_resnext101_32x4d',
                 in_channels=1, out_dim=10, use_bn=True,
                 pretrained=None):
        super(PretrainedCNN, self).__init__()
        self.conv0 = nn.Conv2d(
            in_channels, 3, kernel_size=3, stride=1, padding=1, bias=True)
        self.base_model = pretrainedmodels.__dict__[model_name](pretrained=pretrained)
        activation = F.leaky_relu
        self.do_pooling = True
        if self.do_pooling:
            inch = self.base_model.last_linear.in_features
        else:
            inch = None
        hdim = 512
        lin1 = LinearBlock(inch, hdim, use_bn=use_bn, activation=activation, residual=False)
        lin2 = LinearBlock(hdim, out_dim, use_bn=use_bn, activation=None, residual=False)
        self.lin_layers = Sequential(lin1, lin2)

    def forward(self, x):
        h = self.conv0(x)
        h = self.base_model.features(h)

        if self.do_pooling:
            h = torch.sum(h, dim=(-1, -2))
        else:
            # [128, 2048, 4, 4] when input is (128, 128)
            bs, ch, height, width = h.shape
            h = h.view(bs, ch*height*width)
        for layer in self.lin_layers:
            h = layer(h)
        return h

# %%
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm


def accuracy(y, t):
    pred_label = torch.argmax(y, dim=1)
    count = pred_label.shape[0]
    correct = (pred_label == t).sum().type(torch.float32)
    acc = correct / count
    return acc


class BengaliClassifier(nn.Module):
    def __init__(self, predictor, n_grapheme=168, n_vowel=11, n_consonant=7):
        super(BengaliClassifier, self).__init__()
        self.n_grapheme = n_grapheme
        self.n_vowel = n_vowel
        self.n_consonant = n_consonant
        self.n_total_class = self.n_grapheme + self.n_vowel + self.n_consonant
        self.predictor = predictor

        self.metrics_keys = [
            'loss', 'loss_grapheme', 'loss_vowel', 'loss_consonant',
            'acc_grapheme', 'acc_vowel', 'acc_consonant']

    def forward(self, x, y=None):
        
        pred = self.predictor(x)
        if isinstance(pred, tuple):
            assert len(pred) == 3
            preds = pred
        else:
            assert pred.shape[1] == self.n_total_class
            preds = torch.split(pred, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        loss_grapheme = F.cross_entropy(preds[0], y[:, 0])
        loss_vowel = F.cross_entropy(preds[1], y[:, 1])
        loss_consonant = F.cross_entropy(preds[2], y[:, 2])
        loss = loss_grapheme + loss_vowel + loss_consonant
        metrics = {
            'loss': loss.item(),
            'loss_grapheme': loss_grapheme.item(),
            'loss_vowel': loss_vowel.item(),
            'loss_consonant': loss_consonant.item(),
            'acc_grapheme': accuracy(preds[0], y[:, 0]),
            'acc_vowel': accuracy(preds[1], y[:, 1]),
            'acc_consonant': accuracy(preds[2], y[:, 2]),
        }
        return loss, metrics, pred

    def calc(self, data_loader):
        device: torch.device = next(self.parameters()).device
        self.eval()
        output_list = []
        with torch.no_grad():
            for batch in tqdm(data_loader):
                # TODO: support general preprocessing.
                # If `data` is not `Data` instance, `to` method is not supported!
                batch = batch.to(device)
                pred = self.predictor(batch)
                output_list.append(pred)
        output = torch.cat(output_list, dim=0)
        preds = torch.split(output, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        return preds

    def predict_proba(self, data_loader):
        preds = self.calc(data_loader)
        return [F.softmax(p, dim=1) for p in preds]

    def predict(self, data_loader):
        preds = self.calc(data_loader)
        pred_labels = [torch.argmax(p, dim=1) for p in preds]
        return pred_labels

# %%
import numpy as np


class BengaliAIDataset(DatasetMixin):
    def __init__(self, images, labels=None, transform=None, indices=None):
        super(BengaliAIDataset, self).__init__(transform=transform)
        self.images = images
        self.labels = labels
        if indices is None:
            indices = np.arange(len(images))
        self.indices = indices
        self.train = labels is not None

    def __len__(self):
        """return length of this dataset"""
        return len(self.indices)

    def get_example(self, i):
        """Return i-th data"""
        i = self.indices[i]
        x = self.images[i]
        # Opposite white and black: background will be white (1.0) and
        # for future Affine transformation
        x = (255 - x).astype(np.float32) / 255.
        if self.train:
            y = self.labels[i]
            return x, y
        else:
            return x

# %%
import numpy as np


def add_gaussian_noise(x, sigma):
    x += np.random.randn(*x.shape) * sigma
    x = np.clip(x, 0., 1.)
    return x


class Transform:
    def __init__(self, affine=True, crop=True, size=(64, 64),
                 normalize=True, train=True, threshold=40.,
                 sigma=-1.):
        self.affine = affine
        self.crop = crop
        self.size = size
        self.normalize = normalize
        self.train = train
        self.threshold = threshold / 255.
        self.sigma = sigma / 255.

    def __call__(self, example):
        if self.train:
            x, y = example
        else:
            x = example
        # --- Augmentation ---
        if self.affine:
            x = affine_image(x)

        # --- Train/Test common preprocessing ---
        if self.crop:
            x = crop_char_image(x, threshold=self.threshold)
        if self.size is not None:
            x = resize(x, size=self.size)
        if self.sigma > 0.:
            x = add_gaussian_noise(x, sigma=self.sigma)
        if self.normalize:
            x = (x.astype(np.float32) - 0.0692) / 0.2051
        if x.ndim == 2:
            x = x[None, :, :]
        x = x.astype(np.float32)
        if self.train:
            y = y.astype(np.int64)
            return x, y
        else:
            return x

# %%
"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image


from scipy.ndimage.measurements import label

def connected_comp(array):
    
    structure = np.ones((3, 3), dtype=np.int)  # this defines the connection filter
    labeled, ncomponents = label(array, structure)
    
    valid = []
    for i in range(1,ncomponents+1):
        if np.sum(labeled == i)>10:
            valid.append(i)

    new_array = np.zeros(array.shape)
    for i in valid:
        new_array += labeled==i
    return new_array

def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold
    is_black[:2,:] = 0
    is_black[-2:,:] = 0
    is_black[:,:2] = 0
    is_black[:,-2:] = 0
    is_black = connected_comp(is_black)

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    
    left = np.argmax(is_black_horizontal)-2
    right = np.argmax(is_black_horizontal[::-1])+2
    top = np.argmax(is_black_vertical)+2
    bottom = np.argmax(is_black_vertical[::-1])-2
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image


def resize(image, size=(128, 128)):
    return cv2.resize(image, size)

# %%
# perm = np.random.RandomState(777).permutation(n_dataset)
# print('perm', perm)
# train_dataset = BengaliAIDataset(
#     train_images, train_labels, transform=Transform(size=(image_size, image_size)),
#     indices=perm[:train_data_size])
# valid_dataset = BengaliAIDataset(
#     train_images, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
#     )
# print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))

# %%
# n_dataset = len(train_images)
# train_data_size = 200 if debug else int(n_dataset * 0.9)
# valid_data_size = 100 if debug else int(n_dataset - train_data_size)

# perm = np.random.RandomState(777).permutation(n_dataset)
# print('perm', perm)
# train_dataset = BengaliAIDataset(
#     train_images, train_labels, transform=Transform(size=(image_size, image_size)),
#     indices=perm[:train_data_size])
# valid_dataset = BengaliAIDataset(
#     train_images, train_labels, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
#     indices=perm[train_data_size:train_data_size+valid_data_size])
# print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))

# # --- Model ---
# device = torch.device(device)
# n_grapheme = 168
# n_vowel = 11
# n_consonant = 7
# n_total = n_grapheme + n_vowel + n_consonant
# print('n_total', n_total)
# # Set pretrained='imagenet' to download imagenet pretrained model...
# predictor = PretrainedCNN(in_channels=1, out_dim=n_total, model_name=model_name, pretrained=None)
# print('predictor', type(predictor))

# classifier = BengaliClassifier(predictor).to(device)

# %%
perm_dict = {}
perm_dict[1] = perm[train_data_size:train_data_size+valid_data_size][perm[train_data_size:train_data_size+valid_data_size]<50210]
perm_dict[2] = perm[train_data_size:train_data_size+valid_data_size][np.logical_and(50210<=perm[train_data_size:train_data_size+valid_data_size], perm[train_data_size:train_data_size+valid_data_size]<50210*2)]-50210
perm_dict[3] = perm[train_data_size:train_data_size+valid_data_size][np.logical_and(50210*2<=perm[train_data_size:train_data_size+valid_data_size], perm[train_data_size:train_data_size+valid_data_size]<50210*3)]-50210*2
perm_dict[4] = perm[train_data_size:train_data_size+valid_data_size][np.logical_and(50210*3<=perm[train_data_size:train_data_size+valid_data_size], perm[train_data_size:train_data_size+valid_data_size]<50210*4)]-50210*3

# %%
from torch.utils.data.dataloader import DataLoader
from chainer_chemistry.utils import save_json, load_json


# --- Prediction ---
traindir = '../input/bengaliaicv19-trainedmodels/'
data_type = 'train'
test_preds_list = []

for i in range(4):
    # --- prepare data ---
    indices = [i]
    test_images = prepare_image(
        datadir, featherdir, data_type=data_type, submission=submission, indices=indices)
    
    test_images = test_images[perm_dict[i+1]]
    n_dataset = len(test_images)
    print(f'n_dataset={n_dataset}')
    # print(f'i={i}, n_dataset={n_dataset}')
    # test_data_size = 200 if debug else int(n_dataset * 0.9)

    model_preds_list = []
    for j in range(1):
        # --- Depends on train configuration ---
        train_args_dict = load_json(os.path.join('./', f'args_{j}.json'))
        train_args_dict.update({
            'load_model_path': os.path.join('./', f'predictor_{j}.pt'),
            'device': device,
            'batch_size': batch_size,
            'debug': debug,
        })
        print(f'j {j} updated train_args_dict {train_args_dict}')
        test_preds = predict_core(
                test_images=test_images, n_total=n_total,
                **train_args_dict)

        model_preds_list.append(test_preds)

    # --- ensemble ---
    proba0 = torch.mean(torch.stack([test_preds[0] for test_preds in model_preds_list], dim=0), dim=0)
    proba1 = torch.mean(torch.stack([test_preds[1] for test_preds in model_preds_list], dim=0), dim=0)
    proba2 = torch.mean(torch.stack([test_preds[2] for test_preds in model_preds_list], dim=0), dim=0)
    p0 = torch.argmax(proba0, dim=1).cpu().numpy()
    p1 = torch.argmax(proba1, dim=1).cpu().numpy()
    p2 = torch.argmax(proba2, dim=1).cpu().numpy()
    print('p0', p0.shape, 'p1', p1.shape, 'p2', p2.shape)

    test_preds_list.append([p0, p1, p2])
    if debug:
        break
    #del test_images
    gc.collect()

# %%
# Validation Prediction

# %%
p0 = np.concatenate([test_preds[0] for test_preds in test_preds_list], axis=0)
p1 = np.concatenate([test_preds[1] for test_preds in test_preds_list], axis=0)
p2 = np.concatenate([test_preds[2] for test_preds in test_preds_list], axis=0)
print('concat:', 'p0', p0.shape, 'p1', p1.shape, 'p2', p2.shape)

row_id = []
target = []
for i in tqdm(range(len(p0))):
    
    j=np.copy(i)
    target += [p0[i], p1[i], p2[i]]
    
    if i<5066:
        i = perm_dict[1][i]
    elif i<5066+4990:
        i = perm_dict[2][i-5066]+50210
    elif i<5066+4990+5033:
        i = perm_dict[3][i-(5066+4990)]+50210*2
    elif i<5066+4990+5033+4995:
        i = perm_dict[4][i-(5066+4990+5033)]+50210*3
    else:
        print("index error")
        
    row_id += [f'Train_{i}_grapheme_root', f'Train_{i}_vowel_diacritic',
               f'Train_{i}_consonant_diacritic']
    
#submission_df = pd.DataFrame({'row_id': row_id, 'target': target})
#submission_df.to_csv('submission.csv', index=False)

# %%
pd.DataFrame({'row_id': row_id, 'target': target})
predict_df = pd.DataFrame({'row_id': row_id, 'target': target})
predict_label = np.array(predict_df['target'])
predict_label

# %%
true_df = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].iloc[np.concatenate([perm_dict[1],perm_dict[2]+50210,perm_dict[3]+2*50210,perm_dict[4]+3*50210],axis=0),:]
true_label = true_df.values.reshape(1,-1)[0]
true_label

# %%
(predict_label==true_label).sum()/true_label.shape[0]

# %%
predict_df['row_id']

# %% [markdown]
# # grapheme

# %%
# 한 종류만 보기
combined_df = predict_df[predict_df['row_id'].map(lambda x: x.split('_')[-2]=='grapheme')]
# 인덱스 초기화
combined_df = combined_df.reset_index(drop=True)
# 'true_label' 추가
combined_df['true_label']=pd.Series(true_df.values.reshape(1,-1)[0][list(predict_df['row_id'].map(lambda x: x.split('_')[-2]=='grapheme'))])
combined_df.rename(columns = {'target': 'prediction'}, inplace = True)
print("정답률:", np.sum(combined_df['prediction']==combined_df['true_label'])/combined_df.shape[0])

# %% [markdown]
# # vowel

# %%
# 한 종류만 보기
combined_df = predict_df[predict_df['row_id'].map(lambda x: x.split('_')[-2]=='vowel')]
# 인덱스 초기화
combined_df = combined_df.reset_index(drop=True)
# 'true_label' 추가
combined_df['true_label']=pd.Series(true_df.values.reshape(1,-1)[0][list(predict_df['row_id'].map(lambda x: x.split('_')[-2]=='vowel'))])
combined_df.rename(columns = {'target': 'prediction'}, inplace = True)
print("정답률:", np.sum(combined_df['prediction']==combined_df['true_label'])/combined_df.shape[0])

# %% [markdown]
# # consonant

# %%
# 한 종류만 보기
combined_df = predict_df[predict_df['row_id'].map(lambda x: x.split('_')[-2]=='consonant')]
# 인덱스 초기화
combined_df = combined_df.reset_index(drop=True)
# 'true_label' 추가
combined_df['true_label']=pd.Series(true_df.values.reshape(1,-1)[0][list(predict_df['row_id'].map(lambda x: x.split('_')[-2]=='consonant'))])
combined_df.rename(columns = {'target': 'prediction'}, inplace = True)
print("정답률:", np.sum(combined_df['prediction']==combined_df['true_label'])/combined_df.shape[0])

# %% [markdown]
# # 예측, 정답 데이터프레임

# %%
combined_df['correct']= combined_df['prediction']==combined_df['true_label']
# 인덱스 바꿔주기
#combined_df.index = pd.Index(combined_df['row_id'].map(lambda x:x.split('_')[-3]).astype(np.int64))
combined_df.index = list(combined_df['row_id'].map(lambda x:x.split('_')[-3]).astype(np.int64))

# %% [markdown]
# # 라벨별 정확도

# %%
allcount_dict = dict(combined_df['true_label'].value_counts())
tcount_dict = dict(combined_df[combined_df['correct']==True]['true_label'].value_counts())

acc_dict = {}
for i in allcount_dict.keys():
    acc_dict[i] = tcount_dict[i]/allcount_dict[i]
acc_dict = {k: v for k, v in sorted(acc_dict.items(), key=lambda item: item[1])}
acc_dict

# %% [markdown]
# # 라벨별로 참, 거짓 이미지 확인

# %%
label = 61

subset_df = combined_df[combined_df['true_label']==label]

n_fig = 10
f_index = subset_df[subset_df['correct']==False].index[:n_fig]
t_index = subset_df[subset_df['correct']==True].index[:n_fig]

nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = t_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()


nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = f_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()

# %%
label = 84

subset_df = combined_df[combined_df['true_label']==label]

n_fig = 10
f_index = subset_df[subset_df['correct']==False].index[:n_fig]
t_index = subset_df[subset_df['correct']==True].index[:n_fig]

nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = t_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()


nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = f_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(22, 6))
plt.title('Label Count')
sns.countplot(x="grapheme_root",data=train)

# %%
plt.imshow(train_dataset[0][0])

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    ax.set_title(f'label: {label}')
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="ref"></a>
# # Reference and further reading
#
# #### Kernel
#
# **[Bangali.AI super fast data loading with feather](https://www.kaggle.com/corochann/bangali-ai-super-fast-data-loading-with-feather)**<br>
# Simple example of how use feather format data to load data faster.
#
# **[Bengali: albumentations data augmentation tutorial](https://www.kaggle.com/corochann/bengali-albumentations-data-augmentation-tutorial)**<br>
# Tutorial for Data augmentations with albumentations library.
#
# **[Bengali: SEResNeXt prediction with pytorch](https://www.kaggle.com/corochann/bengali-seresnext-prediction-with-pytorch)**<br>
# **Prediction code of this kernel's trained model, please check this too!**
#
# **[Deep learning - CNN with Chainer: LB 0.99700](https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700)**<br>
# Data augmentation idea is based on this kernel, which achieves quite high accuracy on MNIST task.
#
# #### Dataset
# **[bengaliai-cv19-feather](https://www.kaggle.com/corochann/bengaliaicv19feather)**<br>
# Feather format dataset
#
# **[bengaliaicv19_seresnext101_32x4d](https://www.kaggle.com/corochann/bengaliaicv19-seresnext101-32x4d)**<br>
# **Trained model weight with this kernel(v1)**
#
# **[bengaliaicv19_trainedmodels](https://www.kaggle.com/corochann/bengaliaicv19-trainedmodels)**<br>
# **Trained model weight with this kernel(v2~)**
#
# #### Library
# **https://github.com/pytorch/ignite**
#
# Used for training code abstraction. The advantage of abstracting the code is that we can re-use implemented handler class for other training, other competition.<br>
# You don't need to write code for saving models, logging training loss/metric, show progressbar etc.
#
# **https://github.com/Cadene/pretrained-models.pytorch**
#
# Many pretrained models are supported by this library, and we can switch to use them easily.
# Other model may perform better in this competition.
#
# **https://github.com/albumentations-team/albumentations**
#
# fast image augmentation library and easy to use wrapper around other libraries https://arxiv.org/abs/1809.06839<br>
# I could not show all the methods, you can find more methods in the library, check yourself!

# %% [markdown]
# <h3 style="color:red">If this kernel helps you, please upvote to keep me motivated :)<br>Thanks!</h3>
