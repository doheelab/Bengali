# %% [markdown]
# # Bengali.AI SEResNeXt training with pytorch
#
# I will introduce following contents
#
#  - **Fast data loading** with feather format
#  - **Data augmentation** technic with affine transformation
#  - **CNN SoTA models**: Use pytorch `pretrainedmodels` library, especially I use **`SEResNeXt`** in this notebook
#  - **Training code abstraction**: Use `pytorch-ignite` module for the trainining abstraction
#
# ### Update history
#
#  - 2020/1/4 v2: Added albumentations augmentations introduced in [Bengali: albumentations data augmentation tutorial](https://www.kaggle.com/corochann/bengali-albumentations-data-augmentation-tutorial)

# %% [markdown]
# # Table of Contents:
# **[Fast data loading with feather](#load)**<br>
# **[Dataset](#dataset)**<br>
# **[Data augmentation/processing](#processing)**<br>
# **[pytorch model & define classifier](#model)**<br>
# **[Training code](#train)**<br>
# **[Prediction](#pred)**<br>
# **[Reference and further reading](#ref)**<br>

# %% [markdown]
# To install https://github.com/Cadene/pretrained-models.pytorch without internet connection, we can install library as "dataset".
#
# It is uploaded by @rishabhiitbhu : https://www.kaggle.com/rishabhiitbhu/pretrainedmodels

# %%
#!pip install ../input/pretrainedmodels/pretrainedmodels-0.7.4/ > /dev/null # no output
# !python -m pip install ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/ > /dev/null --user

# %%
import gc
import os
from pathlib import Path
import random
import sys

from tqdm.notebook import tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display import display, HTML

# --- plotly ---
from plotly import tools, subplots
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff

# --- models ---
from sklearn import preprocessing
from sklearn.model_selection import KFold
# import lightgbm as lgb
# import xgboost as xgb
# import catboost as cb

# --- setup ---
pd.set_option('max_columns', 50)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# ../input/pretrainedmodels.zip
# ../input/bengaliaicv19feather/test_image_data_2.feather
# ../input/bengaliaicv19feather/train_image_data_0.feather
# ../input/bengaliaicv19feather/test_image_data_3.feather
# ../input/bengaliaicv19feather/train_image_data_2.feather
# ../input/bengaliaicv19feather/train_image_data_3.feather
# ../input/bengaliaicv19feather/test_image_data_0.feather
# ../input/bengaliaicv19feather/test_image_data_1.feather
# ../input/bengaliaicv19feather/train_image_data_1.feather
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/setup.cfg
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/setup.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/PKG-INFO
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/README.md
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/PKG-INFO
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/SOURCES.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/requires.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/dependency_links.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels.egg-info/top_level.txt
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/setup.cfg
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/setup.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/PKG-INFO
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/README.md
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/utils.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/version.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/nasnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/polynet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/inceptionresnetv2.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/utils.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/bninception.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/cafferesnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/nasnet_mobile.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/xception.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/dpn.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/fbresnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/senet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/inceptionv4.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/pnasnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/vggm.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/wideresnet.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/torchvision_models.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext_features/resnext101_32x4d_features.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext_features/resnext101_64x4d_features.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/models/resnext_features/__init__.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/datasets/utils.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/datasets/voc.py
# ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/pretrainedmodels/datasets/__init__.py
# ../input/grapheme-imgs-128x128/Train_55593.png
# ../input/grapheme-imgs-128x128/Train_101715.png
# ../input/grapheme-imgs-128x128/Train_100837.png
# ../input/grapheme-imgs-128x128/Train_44631.png
# ../input/grapheme-imgs-128x128/Train_92571.png
# ../input/grapheme-imgs-128x128/Train_128677.png
# ../input/grapheme-imgs-128x128/Train_86533.png
# ../input/grapheme-imgs-128x128/Train_170171.png
# ../input/grapheme-imgs-128x128/Train_16142.png
# ../input/grapheme-imgs-128x128/Train_64308.png
# ../input/grapheme-imgs-128x128/Train_157561.png
# ../input/grapheme-imgs-128x128/Train_185375.png
# ../input/grapheme-imgs-128x128/Train_25092.png
# ../input/grapheme-imgs-128x128/Train_190426.png
# ../input/grapheme-imgs-128x128/Train_24305.png
# ../input/grapheme-imgs-128x128/Train_44463.png
# ../input/grapheme-imgs-128x128/Train_97283.png
# ../input/grapheme-imgs-128x128/Train_165008.png
# ../input/grapheme-imgs-128x128/Train_127273.png
# ../input/grapheme-imgs-128x128/Train_75910.png
# ../input/grapheme-imgs-128x128/Train_151630.png
# ../input/grapheme-imgs-128x128/Train_128021.png
# ../input/grapheme-imgs-128x128/Train_115377.png
# ../input/grapheme-imgs-128x128/Train_171023.png
# ../input/grapheme-imgs-128x128/Train_50731.png
# ../input/grapheme-imgs-128x128/Train_57550.png
# ../input/grapheme-imgs-128x128/Train_195944.png
# ../input/grapheme-imgs-128x128/Train_85314.png
# ../input/grapheme-imgs-128x128/Train_114674.png
# ../input/grapheme-imgs-128x128/Train_93701.png
# ../input/grapheme-imgs-128x128/Train_155442.png
# ../input/grapheme-imgs-128x128/Train_65292.png
# ../input/grapheme-imgs-128x128/Train_137279.png
# ../input/grapheme-imgs-128x128/Train_151073.png
# ../input/grapheme-imgs-128x128/Train_176984.png
# ../input/grapheme-imgs-128x128/Train_200081.png
# ../input/grapheme-imgs-128x128/Train_46296.png
# ../input/grapheme-imgs-128x128/Train_126256.png
# ../input/grapheme-imgs-128x128/Train_132399.png
# ../input/grapheme-imgs-128x128/Train_45278.png
# ../input/grapheme-imgs-128x128/Train_18775.png
# ../input/grapheme-imgs-128x128/Train_33595.png
# ../input/grapheme-imgs-128x128/Train_25461.png
# ../input/grapheme-imgs-128x128/Train_51546.png
# ../input/grapheme-imgs-128x128/Train_151654.png
# ../input/grapheme-imgs-128x128/Train_130306.png
# ../input/grapheme-imgs-128x128/Train_493.png
# ../input/grapheme-imgs-128x128/Train_125034.png
# ../input/grapheme-imgs-128x128/Train_68107.png
# ../input/grapheme-imgs-128x128/Train_123781.png
# ../input/grapheme-imgs-128x128/Train_168718.png
# ../input/grapheme-imgs-128x128/Train_126171.png
# ../input/grapheme-imgs-128x128/Train_15269.png
# ../input/grapheme-imgs-128x128/Train_162409.png
# ../input/grapheme-imgs-128x128/Train_114565.png
# ../input/grapheme-imgs-128x128/Train_93201.png
# ../input/grapheme-imgs-128x128/Train_143999.png
# ../input/grapheme-imgs-128x128/Train_58287.png
# ../input/grapheme-imgs-128x128/Train_194293.png
# ../input/grapheme-imgs-128x128/Train_2599.png
# ../input/grapheme-imgs-128x128/Train_20547.png
# ../input/grapheme-imgs-128x128/Train_28873.png
# ../input/grapheme-imgs-128x128/Train_52777.png
# ../input/grapheme-imgs-128x128/Train_64841.png
# ../input/grapheme-imgs-128x128/Train_104350.png
# ../input/grapheme-imgs-128x128/Train_15953.png
# ../input/grapheme-imgs-128x128/Train_25843.png
# ../input/grapheme-imgs-128x128/Train_81751.png
# ../input/grapheme-imgs-128x128/Train_114449.png
# ../input/grapheme-imgs-128x128/Train_56895.png
# ../input/grapheme-imgs-128x128/Train_165864.png
# ../input/grapheme-imgs-128x128/Train_153873.png
# ../input/grapheme-imgs-128x128/Train_59007.png
# ../input/grapheme-imgs-128x128/Train_108901.png
# ../input/grapheme-imgs-128x128/Train_87196.png
# ../input/grapheme-imgs-128x128/Train_145082.png
# ../input/grapheme-imgs-128x128/Train_16164.png
# ../input/grapheme-imgs-128x128/Train_184000.png
# ../input/grapheme-imgs-128x128/Train_44922.png
# ../input/grapheme-imgs-128x128/Train_123923.png
# ../input/grapheme-imgs-128x128/Train_154149.png
# ../input/grapheme-imgs-128x128/Train_113988.png
# ../input/grapheme-imgs-128x128/Train_71500.png
# ../input/grapheme-imgs-128x128/Train_154346.png
# ../input/grapheme-imgs-128x128/Train_29293.png
# ../input/grapheme-imgs-128x128/Train_152570.png
# ../input/grapheme-imgs-128x128/Train_158803.png
# ../input/grapheme-imgs-128x128/Train_8816.png
# ../input/grapheme-imgs-128x128/Train_75205.png
# ../input/grapheme-imgs-128x128/Train_87242.png
# ../input/grapheme-imgs-128x128/Train_133950.png
# ../input/grapheme-imgs-128x128/Train_162821.png
# ../input/grapheme-imgs-128x128/Train_44042.png
# ../input/grapheme-imgs-128x128/Train_22523.png
# ../input/grapheme-imgs-128x128/Train_45745.png
# ../input/grapheme-imgs-128x128/Train_79154.png
# ../input/grapheme-imgs-128x128/Train_125312.png
# ../input/grapheme-imgs-128x128/Train_48637.png
# ../input/grapheme-imgs-128x128/Train_92613.png
# ../input/grapheme-imgs-128x128/Train_197894.png
# ../input/grapheme-imgs-128x128/Train_62666.png
# ../input/grapheme-imgs-128x128/Train_153110.png
# ../input/grapheme-imgs-128x128/Train_173145.png
# ../input/grapheme-imgs-128x128/Train_73943.png
# ../input/grapheme-imgs-128x128/Train_151010.png
# ../input/grapheme-imgs-128x128/Train_122243.png
# ../input/grapheme-imgs-128x128/Train_32065.png
# ../input/grapheme-imgs-128x128/Train_52019.png
# ../input/grapheme-imgs-128x128/Train_175379.png
# ../input/grapheme-imgs-128x128/Train_157664.png
# ../input/grapheme-imgs-128x128/Train_33331.png
# ../input/grapheme-imgs-128x128/Train_146963.png
# ../input/grapheme-imgs-128x128/Train_142390.png
# ../input/grapheme-imgs-128x128/Train_54025.png
# ../input/grapheme-imgs-128x128/Train_62751.png
# ../input/grapheme-imgs-128x128/Train_59715.png
# ../input/grapheme-imgs-128x128/Train_19726.png
# ../input/grapheme-imgs-128x128/Train_1161.png
# ../input/grapheme-imgs-128x128/Train_92385.png
# ../input/grapheme-imgs-128x128/Train_184029.png
# ../input/grapheme-imgs-128x128/Train_44308.png
# ../input/grapheme-imgs-128x128/Train_109669.png
# ../input/grapheme-imgs-128x128/Train_172015.png
# ../input/grapheme-imgs-128x128/Train_149913.png
# ../input/grapheme-imgs-128x128/Train_189846.png
# ../input/grapheme-imgs-128x128/Train_163264.png
# ../input/grapheme-imgs-128x128/Train_68827.png
# ../input/grapheme-imgs-128x128/Train_13835.png
# ../input/grapheme-imgs-128x128/Train_70292.png
# ../input/grapheme-imgs-128x128/Train_193730.png
# ../input/grapheme-imgs-128x128/Train_25023.png
# ../input/grapheme-imgs-128x128/Train_180913.png
# ../input/grapheme-imgs-128x128/Train_107755.png
# ../input/grapheme-imgs-128x128/Train_131126.png
# ../input/grapheme-imgs-128x128/Train_139863.png
# ../input/grapheme-imgs-128x128/Train_86505.png
# ../input/grapheme-imgs-128x128/Train_129524.png
# ../input/grapheme-imgs-128x128/Train_57390.png
# ../input/grapheme-imgs-128x128/Train_104914.png
# ../input/grapheme-imgs-128x128/Train_193476.png
# ../input/grapheme-imgs-128x128/Train_125527.png
# ../input/grapheme-imgs-128x128/Train_23154.png
# ../input/grapheme-imgs-128x128/Train_187051.png
# ../input/grapheme-imgs-128x128/Train_153375.png
# ../input/grapheme-imgs-128x128/Train_190520.png
# ../input/grapheme-imgs-128x128/Train_13902.png
# ../input/grapheme-imgs-128x128/Train_186594.png
# ../input/grapheme-imgs-128x128/Train_25140.png
# ../input/grapheme-imgs-128x128/Train_115739.png
# ../input/grapheme-imgs-128x128/Train_169348.png
# ../input/grapheme-imgs-128x128/Train_115932.png
# ../input/grapheme-imgs-128x128/Train_26316.png
# ../input/grapheme-imgs-128x128/Train_117828.png
# ../input/grapheme-imgs-128x128/Train_133844.png
# ../input/grapheme-imgs-128x128/Train_132979.png
# ../input/grapheme-imgs-128x128/Train_90468.png
# ../input/grapheme-imgs-128x128/Train_92313.png
# ../input/grapheme-imgs-128x128/Train_126286.png
# ../input/grapheme-imgs-128x128/Train_68654.png
# ../input/grapheme-imgs-128x128/Train_109274.png
# ../input/grapheme-imgs-128x128/Train_21020.png
# ../input/grapheme-imgs-128x128/Train_47351.png
# ../input/grapheme-imgs-128x128/Train_113686.png
# ../input/grapheme-imgs-128x128/Train_83767.png
# ../input/grapheme-imgs-128x128/Train_28689.png
# ../input/grapheme-imgs-128x128/Train_156885.png
# ../input/grapheme-imgs-128x128/Train_22962.png
# ../input/grapheme-imgs-128x128/Train_193229.png
# ../input/grapheme-imgs-128x128/Train_45038.png
# ../input/grapheme-imgs-128x128/Train_29352.png
# ../input/grapheme-imgs-128x128/Train_134125.png
# ../input/grapheme-imgs-128x128/Train_90269.png
# ../input/grapheme-imgs-128x128/Train_141210.png
# ../input/grapheme-imgs-128x128/Train_28634.png
# ../input/grapheme-imgs-128x128/Train_174403.png
# ../input/grapheme-imgs-128x128/Train_117861.png
# ../input/grapheme-imgs-128x128/Train_184236.png
# ../input/grapheme-imgs-128x128/Train_150776.png
# ../input/grapheme-imgs-128x128/Train_154018.png
# ../input/grapheme-imgs-128x128/Train_77255.png
# ../input/grapheme-imgs-128x128/Train_1260.png
# ../input/grapheme-imgs-128x128/Train_117227.png
# ../input/grapheme-imgs-128x128/Train_150992.png
# ../input/grapheme-imgs-128x128/Train_27692.png
# ../input/grapheme-imgs-128x128/Train_124544.png
# ../input/grapheme-imgs-128x128/Train_65407.png
# ../input/grapheme-imgs-128x128/Train_75456.png
# ../input/grapheme-imgs-128x128/Train_31887.png
# ../input/grapheme-imgs-128x128/Train_55674.png
# ../input/grapheme-imgs-128x128/Train_126809.png
# ../input/grapheme-imgs-128x128/Train_7821.png
# ../input/grapheme-imgs-128x128/Train_68437.png
# ../input/grapheme-imgs-128x128/Train_186024.png
# ../input/grapheme-imgs-128x128/Train_102641.png
# ../input/grapheme-imgs-128x128/Train_14321.png
# ../input/grapheme-imgs-128x128/Train_37185.png
# ../input/grapheme-imgs-128x128/Train_24234.png
# ../input/grapheme-imgs-128x128/Train_117812.png
# ../input/grapheme-imgs-128x128/Train_20363.png
# ../input/grapheme-imgs-128x128/Train_90739.png
# ../input/grapheme-imgs-128x128/Train_3337.png
# ../input/grapheme-imgs-128x128/Train_78769.png
# ../input/grapheme-imgs-128x128/Train_63895.png
# ../input/grapheme-imgs-128x128/Train_168167.png
# ../input/grapheme-imgs-128x128/Train_67937.png
# ../input/grapheme-imgs-128x128/Train_58773.png
# ../input/grapheme-imgs-128x128/Train_100613.png
# ../input/grapheme-imgs-128x128/Train_127502.png
# ../input/grapheme-imgs-128x128/Train_183657.png
# ../input/grapheme-imgs-128x128/Train_18462.png
# ../input/grapheme-imgs-128x128/Train_124350.png
# ../input/grapheme-imgs-128x128/Train_114001.png
# ../input/grapheme-imgs-128x128/Train_170418.png
# ../input/grapheme-imgs-128x128/Train_121230.png
# ../input/grapheme-imgs-128x128/Train_41655.png
# ../input/grapheme-imgs-128x128/Train_81672.png
# ../input/grapheme-imgs-128x128/Train_44734.png
# ../input/grapheme-imgs-128x128/Train_43342.png
# ../input/grapheme-imgs-128x128/Train_192786.png
# ../input/grapheme-imgs-128x128/Train_174040.png
# ../input/grapheme-imgs-128x128/Train_75391.png
# ../input/grapheme-imgs-128x128/Train_146815.png
# ../input/grapheme-imgs-128x128/Train_137470.png
# ../input/grapheme-imgs-128x128/Train_195244.png
# ../input/grapheme-imgs-128x128/Train_20239.png
# ../input/grapheme-imgs-128x128/Train_109344.png
# ../input/grapheme-imgs-128x128/Train_101344.png
# ../input/grapheme-imgs-128x128/Train_25498.png
# ../input/grapheme-imgs-128x128/Train_100653.png
# ../input/grapheme-imgs-128x128/Train_34833.png
# ../input/grapheme-imgs-128x128/Train_28400.png
# ../input/grapheme-imgs-128x128/Train_149930.png
# ../input/grapheme-imgs-128x128/Train_87381.png
# ../input/grapheme-imgs-128x128/Train_149674.png
# ../input/grapheme-imgs-128x128/Train_26183.png
# ../input/grapheme-imgs-128x128/Train_196353.png
# ../input/grapheme-imgs-128x128/Train_17574.png
# ../input/grapheme-imgs-128x128/Train_108131.png
# ../input/grapheme-imgs-128x128/Train_159083.png
# ../input/grapheme-imgs-128x128/Train_107683.png
# ../input/grapheme-imgs-128x128/Train_34217.png
# ../input/grapheme-imgs-128x128/Train_95559.png
# ../input/grapheme-imgs-128x128/Train_117950.png
# ../input/grapheme-imgs-128x128/Train_34065.png
# ../input/grapheme-imgs-128x128/Train_159742.png
# ../input/grapheme-imgs-128x128/Train_136914.png
# ../input/grapheme-imgs-128x128/Train_128468.png
# ../input/grapheme-imgs-128x128/Train_4331.png
# ../input/grapheme-imgs-128x128/Train_194906.png
# ../input/grapheme-imgs-128x128/Train_47977.png
# ../input/grapheme-imgs-128x128/Train_194605.png
# ../input/grapheme-imgs-128x128/Train_149649.png
# ../input/grapheme-imgs-128x128/Train_181648.png
# ../input/grapheme-imgs-128x128/Train_32291.png
# ../input/grapheme-imgs-128x128/Train_200710.png
# ../input/grapheme-imgs-128x128/Train_146828.png
# ../input/grapheme-imgs-128x128/Train_83508.png
# ../input/grapheme-imgs-128x128/Train_149559.png
# ../input/grapheme-imgs-128x128/Train_104866.png
# ../input/grapheme-imgs-128x128/Train_192750.png
# ../input/grapheme-imgs-128x128/Train_82514.png
# ../input/grapheme-imgs-128x128/Train_28663.png
# ../input/grapheme-imgs-128x128/Train_110486.png
# ../input/grapheme-imgs-128x128/Train_76063.png
# ../input/grapheme-imgs-128x128/Train_139363.png
# ../input/grapheme-imgs-128x128/Train_190450.png
# ../input/grapheme-imgs-128x128/Train_29908.png
# ../input/grapheme-imgs-128x128/Train_199828.png
# ../input/grapheme-imgs-128x128/Train_193298.png
# ../input/grapheme-imgs-128x128/Train_40584.png
# ../input/grapheme-imgs-128x128/Train_122961.png
# ../input/grapheme-imgs-128x128/Train_172697.png
# ../input/grapheme-imgs-128x128/Train_114508.png
# ../input/grapheme-imgs-128x128/Train_89931.png
# ../input/grapheme-imgs-128x128/Train_121794.png
# ../input/grapheme-imgs-128x128/Train_189633.png
# ../input/grapheme-imgs-128x128/Train_173791.png
# ../input/grapheme-imgs-128x128/Train_51016.png
# ../input/grapheme-imgs-128x128/Train_24896.png
# ../input/grapheme-imgs-128x128/Train_99544.png
# ../input/grapheme-imgs-128x128/Train_84107.png
# ../input/grapheme-imgs-128x128/Train_73380.png
# ../input/grapheme-imgs-128x128/Train_46901.png
# ../input/grapheme-imgs-128x128/Train_103437.png
# ../input/grapheme-imgs-128x128/Train_92526.png
# ../input/grapheme-imgs-128x128/Train_185004.png
# ../input/grapheme-imgs-128x128/Train_141080.png
# ../input/grapheme-imgs-128x128/Train_153838.png
# ../input/grapheme-imgs-128x128/Train_187398.png
# ../input/grapheme-imgs-128x128/Train_31698.png
# ../input/grapheme-imgs-128x128/Train_169586.png
# ../input/grapheme-imgs-128x128/Train_114316.png
# ../input/grapheme-imgs-128x128/Train_121659.png
# ../input/grapheme-imgs-128x128/Train_40130.png
# ../input/grapheme-imgs-128x128/Train_139285.png
# ../input/grapheme-imgs-128x128/Train_178839.png
# ../input/grapheme-imgs-128x128/Train_25367.png
# ../input/grapheme-imgs-128x128/Train_84459.png
# ../input/grapheme-imgs-128x128/Train_144646.png
# ../input/grapheme-imgs-128x128/Train_42262.png
# ../input/grapheme-imgs-128x128/Train_41578.png
# ../input/grapheme-imgs-128x128/Train_44597.png
# ../input/grapheme-imgs-128x128/Train_151091.png
# ../input/grapheme-imgs-128x128/Train_168369.png
# ../input/grapheme-imgs-128x128/Train_90356.png
# ../input/grapheme-imgs-128x128/Train_61043.png
# ../input/grapheme-imgs-128x128/Train_168959.png
# ../input/grapheme-imgs-128x128/Train_72278.png
# ../input/grapheme-imgs-128x128/Train_86348.png
# ../input/grapheme-imgs-128x128/Train_170477.png
# ../input/grapheme-imgs-128x128/Train_178487.png
# ../input/grapheme-imgs-128x128/Train_161842.png
# ../input/grapheme-imgs-128x128/Train_125701.png
# ../input/grapheme-imgs-128x128/Train_28843.png
# ../input/grapheme-imgs-128x128/Train_194282.png
# ../input/grapheme-imgs-128x128/Train_30769.png
# ../input/grapheme-imgs-128x128/Train_102361.png
# ../input/grapheme-imgs-128x128/Train_17786.png
# ../input/grapheme-imgs-128x128/Train_35804.png
# ../input/grapheme-imgs-128x128/Train_126013.png
# ../input/grapheme-imgs-128x128/Train_171746.png
# ../input/grapheme-imgs-128x128/Train_177526.png
# ../input/grapheme-imgs-128x128/Train_138619.png
# ../input/grapheme-imgs-128x128/Train_90885.png
# ../input/grapheme-imgs-128x128/Train_84693.png
# ../input/grapheme-imgs-128x128/Train_27422.png
# ../input/grapheme-imgs-128x128/Train_126103.png
# ../input/grapheme-imgs-128x128/Train_171354.png
# ../input/grapheme-imgs-128x128/Train_79431.png
# ../input/grapheme-imgs-128x128/Train_166030.png
# ../input/grapheme-imgs-128x128/Train_46306.png
# ../input/grapheme-imgs-128x128/Train_67674.png
# ../input/grapheme-imgs-128x128/Train_136929.png
# ../input/grapheme-imgs-128x128/Train_11311.png
# ../input/grapheme-imgs-128x128/Train_12217.png
# ../input/grapheme-imgs-128x128/Train_23038.png
# ../input/grapheme-imgs-128x128/Train_59346.png
# ../input/grapheme-imgs-128x128/Train_125079.png
# ../input/grapheme-imgs-128x128/Train_170412.png
# ../input/grapheme-imgs-128x128/Train_193628.png
# ../input/grapheme-imgs-128x128/Train_36818.png
# ../input/grapheme-imgs-128x128/Train_62367.png
# ../input/grapheme-imgs-128x128/Train_154850.png
# ../input/grapheme-imgs-128x128/Train_85556.png
# ../input/grapheme-imgs-128x128/Train_185766.png
# ../input/grapheme-imgs-128x128/Train_148588.png
# ../input/grapheme-imgs-128x128/Train_147241.png
# ../input/grapheme-imgs-128x128/Train_43086.png
# ../input/grapheme-imgs-128x128/Train_72957.png
# ../input/grapheme-imgs-128x128/Train_78285.png
# ../input/grapheme-imgs-128x128/Train_100504.png
# ../input/grapheme-imgs-128x128/Train_77052.png
# ../input/grapheme-imgs-128x128/Train_102652.png
# ../input/grapheme-imgs-128x128/Train_129922.png
# ../input/grapheme-imgs-128x128/Train_36483.png
# ../input/grapheme-imgs-128x128/Train_119064.png
# ../input/grapheme-imgs-128x128/Train_57036.png
# ../input/grapheme-imgs-128x128/Train_116573.png
# ../input/grapheme-imgs-128x128/Train_197549.png
# ../input/grapheme-imgs-128x128/Train_17415.png
# ../input/grapheme-imgs-128x128/Train_101291.png
# ../input/grapheme-imgs-128x128/Train_193579.png
# ../input/grapheme-imgs-128x128/Train_192788.png
# ../input/grapheme-imgs-128x128/Train_29759.png
# ../input/grapheme-imgs-128x128/Train_32215.png
# ../input/grapheme-imgs-128x128/Train_79769.png
# ../input/grapheme-imgs-128x128/Train_119770.png
# ../input/grapheme-imgs-128x128/Train_157626.png
# ../input/grapheme-imgs-128x128/Train_31646.png
# ../input/grapheme-imgs-128x128/Train_30368.png
# ../input/grapheme-imgs-128x128/Train_171020.png
# ../input/grapheme-imgs-128x128/Train_177318.png
# ../input/grapheme-imgs-128x128/Train_165191.png
# ../input/grapheme-imgs-128x128/Train_58823.png
# ../input/grapheme-imgs-128x128/Train_66765.png
# ../input/grapheme-imgs-128x128/Train_179120.png
# ../input/grapheme-imgs-128x128/Train_136786.png
# ../input/grapheme-imgs-128x128/Train_100309.png
# ../input/grapheme-imgs-128x128/Train_2552.png
# ../input/grapheme-imgs-128x128/Train_81533.png
# ../input/grapheme-imgs-128x128/Train_175870.png
# ../input/grapheme-imgs-128x128/Train_9372.png
# ../input/grapheme-imgs-128x128/Train_99921.png
# ../input/grapheme-imgs-128x128/Train_43976.png
# ../input/grapheme-imgs-128x128/Train_57287.png
# ../input/grapheme-imgs-128x128/Train_178841.png
# ../input/grapheme-imgs-128x128/Train_70299.png
# ../input/grapheme-imgs-128x128/Train_143629.png
# ../input/grapheme-imgs-128x128/Train_72694.png
# ../input/grapheme-imgs-128x128/Train_129183.png
# ../input/grapheme-imgs-128x128/Train_20623.png
# ../input/grapheme-imgs-128x128/Train_16725.png
# ../input/grapheme-imgs-128x128/Train_44875.png
# ../input/grapheme-imgs-128x128/Train_51022.png
# ../input/grapheme-imgs-128x128/Train_90341.png
# ../input/grapheme-imgs-128x128/Train_179283.png
# ../input/grapheme-imgs-128x128/Train_21922.png
# ../input/grapheme-imgs-128x128/Train_1277.png
# ../input/grapheme-imgs-128x128/Train_60724.png
# ../input/grapheme-imgs-128x128/Train_55495.png
# ../input/grapheme-imgs-128x128/Train_155727.png
# ../input/grapheme-imgs-128x128/Train_193058.png
# ../input/grapheme-imgs-128x128/Train_80165.png
# ../input/grapheme-imgs-128x128/Train_72426.png
# ../input/grapheme-imgs-128x128/Train_155539.png
# ../input/grapheme-imgs-128x128/Train_143397.png
# ../input/grapheme-imgs-128x128/Train_47132.png
# ../input/grapheme-imgs-128x128/Train_150602.png
# ../input/grapheme-imgs-128x128/Train_157117.png
# ../input/grapheme-imgs-128x128/Train_97751.png
# ../input/grapheme-imgs-128x128/Train_11508.png
# ../input/grapheme-imgs-128x128/Train_153343.png
# ../input/grapheme-imgs-128x128/Train_1040.png
# ../input/grapheme-imgs-128x128/Train_115458.png
# ../input/grapheme-imgs-128x128/Train_79725.png
# ../input/grapheme-imgs-128x128/Train_25795.png
# ../input/grapheme-imgs-128x128/Train_74679.png
# ../input/grapheme-imgs-128x128/Train_178176.png
# ../input/grapheme-imgs-128x128/Train_181033.png
# ../input/grapheme-imgs-128x128/Train_115350.png
# ../input/grapheme-imgs-128x128/Train_93572.png
# ../input/grapheme-imgs-128x128/Train_129766.png
# ../input/grapheme-imgs-128x128/Train_166616.png
# ../input/grapheme-imgs-128x128/Train_128904.png
# ../input/grapheme-imgs-128x128/Train_16326.png
# ../input/grapheme-imgs-128x128/Train_164033.png
# ../input/grapheme-imgs-128x128/Train_30260.png
# ../input/grapheme-imgs-128x128/Train_16200.png
# ../input/grapheme-imgs-128x128/Train_37732.png
# ../input/grapheme-imgs-128x128/Train_149133.png
# ../input/grapheme-imgs-128x128/Train_92224.png
# ../input/grapheme-imgs-128x128/Train_25191.png
# ../input/grapheme-imgs-128x128/Train_117192.png
# ../input/grapheme-imgs-128x128/Train_156255.png
# ../input/grapheme-imgs-128x128/Train_71605.png
# ../input/grapheme-imgs-128x128/Train_157173.png
# ../input/grapheme-imgs-128x128/Train_169477.png
# ../input/grapheme-imgs-128x128/Train_106293.png
# ../input/grapheme-imgs-128x128/Train_9212.png
# ../input/grapheme-imgs-128x128/Train_8008.png
# ../input/grapheme-imgs-128x128/Train_168836.png
# ../input/grapheme-imgs-128x128/Train_188455.png
# ../input/grapheme-imgs-128x128/Train_147660.png
# ../input/grapheme-imgs-128x128/Train_144579.png
# ../input/grapheme-imgs-128x128/Train_110332.png
# ../input/grapheme-imgs-128x128/Train_14602.png
# ../input/grapheme-imgs-128x128/Train_83847.png
# ../input/grapheme-imgs-128x128/Train_170166.png
# ../input/grapheme-imgs-128x128/Train_148376.png
# ../input/grapheme-imgs-128x128/Train_144378.png
# ../input/grapheme-imgs-128x128/Train_26666.png
# ../input/grapheme-imgs-128x128/Train_169743.png
# ../input/grapheme-imgs-128x128/Train_124345.png
# ../input/grapheme-imgs-128x128/Train_181293.png
# ../input/grapheme-imgs-128x128/Train_45100.png
# ../input/grapheme-imgs-128x128/Train_194299.png
# ../input/grapheme-imgs-128x128/Train_17057.png
# ../input/grapheme-imgs-128x128/Train_82420.png
# ../input/grapheme-imgs-128x128/Train_41196.png
# ../input/grapheme-imgs-128x128/Train_158378.png
# ../input/grapheme-imgs-128x128/Train_152301.png
# ../input/grapheme-imgs-128x128/Train_149580.png
# ../input/grapheme-imgs-128x128/Train_147520.png
# ../input/grapheme-imgs-128x128/Train_187195.png
# ../input/grapheme-imgs-128x128/Train_169296.png
# ../input/grapheme-imgs-128x128/Train_116352.png
# ../input/grapheme-imgs-128x128/Train_130019.png
# ../input/grapheme-imgs-128x128/Train_152970.png
# ../input/grapheme-imgs-128x128/Train_141410.png
# ../input/grapheme-imgs-128x128/Train_169968.png
# ../input/grapheme-imgs-128x128/Train_117245.png
# ../input/grapheme-imgs-128x128/Train_157949.png
# ../input/grapheme-imgs-128x128/Train_31932.png
# ../input/grapheme-imgs-128x128/Train_56446.png
# ../input/grapheme-imgs-128x128/Train_64675.png
# ../input/grapheme-imgs-128x128/Train_195693.png
# ../input/grapheme-imgs-128x128/Train_48990.png
# ../input/grapheme-imgs-128x128/Train_129078.png
# ../input/grapheme-imgs-128x128/Train_200075.png
# ../input/grapheme-imgs-128x128/Train_133607.png
# ../input/grapheme-imgs-128x128/Train_106086.png
# ../input/grapheme-imgs-128x128/Train_87240.png
# ../input/grapheme-imgs-128x128/Train_76559.png
# ../input/grapheme-imgs-128x128/Train_159778.png
# ../input/grapheme-imgs-128x128/Train_80171.png
# ../input/grapheme-imgs-128x128/Train_105245.png
# ../input/grapheme-imgs-128x128/Train_14750.png
# ../input/grapheme-imgs-128x128/Train_70485.png
# ../input/grapheme-imgs-128x128/Train_133398.png
# ../input/grapheme-imgs-128x128/Train_162164.png
# ../input/grapheme-imgs-128x128/Train_99913.png
# ../input/grapheme-imgs-128x128/Train_79096.png
# ../input/grapheme-imgs-128x128/Train_104961.png
# ../input/grapheme-imgs-128x128/Train_40001.png
# ../input/grapheme-imgs-128x128/Train_18227.png
# ../input/grapheme-imgs-128x128/Train_56064.png
# ../input/grapheme-imgs-128x128/Train_192331.png
# ../input/grapheme-imgs-128x128/Train_73436.png
# ../input/grapheme-imgs-128x128/Train_99576.png
# ../input/grapheme-imgs-128x128/Train_51537.png
# ../input/grapheme-imgs-128x128/Train_35462.png
# ../input/grapheme-imgs-128x128/Train_167270.png
# ../input/grapheme-imgs-128x128/Train_4349.png
# ../input/grapheme-imgs-128x128/Train_173010.png
# ../input/grapheme-imgs-128x128/Train_39666.png
# ../input/grapheme-imgs-128x128/Train_119874.png
# ../input/grapheme-imgs-128x128/Train_177910.png
# ../input/grapheme-imgs-128x128/Train_3695.png
# ../input/grapheme-imgs-128x128/Train_164876.png
# ../input/grapheme-imgs-128x128/Train_59954.png
# ../input/grapheme-imgs-128x128/Train_121631.png
# ../input/grapheme-imgs-128x128/Train_63904.png
# ../input/grapheme-imgs-128x128/Train_158466.png
# ../input/grapheme-imgs-128x128/Train_179946.png
# ../input/grapheme-imgs-128x128/Train_89731.png
# ../input/grapheme-imgs-128x128/Train_11531.png
# ../input/grapheme-imgs-128x128/Train_104694.png
# ../input/grapheme-imgs-128x128/Train_51508.png
# ../input/grapheme-imgs-128x128/Train_132725.png
# ../input/grapheme-imgs-128x128/Train_50623.png
# ../input/grapheme-imgs-128x128/Train_1401.png
# ../input/grapheme-imgs-128x128/Train_188807.png
# ../input/grapheme-imgs-128x128/Train_11383.png
# ../input/grapheme-imgs-128x128/Train_6733.png
# ../input/grapheme-imgs-128x128/Train_87277.png
# ../input/grapheme-imgs-128x128/Train_171936.png
# ../input/grapheme-imgs-128x128/Train_39379.png
# ../input/grapheme-imgs-128x128/Train_40579.png
# ../input/grapheme-imgs-128x128/Train_117167.png
# ../input/grapheme-imgs-128x128/Train_88676.png
# ../input/grapheme-imgs-128x128/Train_33226.png
# ../input/grapheme-imgs-128x128/Train_112129.png
# ../input/grapheme-imgs-128x128/Train_193680.png
# ../input/grapheme-imgs-128x128/Train_6541.png
# ../input/grapheme-imgs-128x128/Train_159292.png
# ../input/grapheme-imgs-128x128/Train_171676.png
# ../input/grapheme-imgs-128x128/Train_121139.png
# ../input/grapheme-imgs-128x128/Train_179832.png
# ../input/grapheme-imgs-128x128/Train_105534.png
# ../input/grapheme-imgs-128x128/Train_6834.png
# ../input/grapheme-imgs-128x128/Train_183479.png
# ../input/grapheme-imgs-128x128/Train_70867.png
# ../input/grapheme-imgs-128x128/Train_57146.png
# ../input/grapheme-imgs-128x128/Train_149389.png
# ../input/grapheme-imgs-128x128/Train_101871.png
# ../input/grapheme-imgs-128x128/Train_160914.png
# ../input/grapheme-imgs-128x128/Train_155864.png
# ../input/grapheme-imgs-128x128/Train_75430.png
# ../input/grapheme-imgs-128x128/Train_115558.png
# ../input/grapheme-imgs-128x128/Train_30931.png
# ../input/grapheme-imgs-128x128/Train_193622.png
# ../input/grapheme-imgs-128x128/Train_198347.png
# ../input/grapheme-imgs-128x128/Train_21656.png
# ../input/grapheme-imgs-128x128/Train_67879.png
# ../input/grapheme-imgs-128x128/Train_2433.png
# ../input/grapheme-imgs-128x128/Train_91967.png
# ../input/grapheme-imgs-128x128/Train_168127.png
# ../input/grapheme-imgs-128x128/Train_114769.png
# ../input/grapheme-imgs-128x128/Train_177.png
# ../input/grapheme-imgs-128x128/Train_187994.png
# ../input/grapheme-imgs-128x128/Train_147372.png
# ../input/grapheme-imgs-128x128/Train_160481.png
# ../input/grapheme-imgs-128x128/Train_99750.png
# ../input/grapheme-imgs-128x128/Train_180818.png
# ../input/grapheme-imgs-128x128/Train_109033.png
# ../input/grapheme-imgs-128x128/Train_159474.png
# ../input/grapheme-imgs-128x128/Train_39624.png
# ../input/grapheme-imgs-128x128/Train_154793.png
# ../input/grapheme-imgs-128x128/Train_56886.png
# ../input/grapheme-imgs-128x128/Train_20466.png
# ../input/grapheme-imgs-128x128/Train_90796.png
# ../input/grapheme-imgs-128x128/Train_18052.png
# ../input/grapheme-imgs-128x128/Train_55778.png
# ../input/grapheme-imgs-128x128/Train_96018.png
# ../input/grapheme-imgs-128x128/Train_160209.png
# ../input/grapheme-imgs-128x128/Train_97354.png
# ../input/grapheme-imgs-128x128/Train_90947.png
# ../input/grapheme-imgs-128x128/Train_37101.png
# ../input/grapheme-imgs-128x128/Train_2724.png
# ../input/grapheme-imgs-128x128/Train_13673.png
# ../input/grapheme-imgs-128x128/Train_15531.png
# ../input/grapheme-imgs-128x128/Train_92060.png
# ../input/grapheme-imgs-128x128/Train_60386.png
# ../input/grapheme-imgs-128x128/Train_72526.png
# ../input/grapheme-imgs-128x128/Train_81783.png
# ../input/grapheme-imgs-128x128/Train_162962.png
# ../input/grapheme-imgs-128x128/Train_44427.png
# ../input/grapheme-imgs-128x128/Train_152083.png
# ../input/grapheme-imgs-128x128/Train_91444.png
# ../input/grapheme-imgs-128x128/Train_157411.png
# ../input/grapheme-imgs-128x128/Train_159526.png
# ../input/grapheme-imgs-128x128/Train_74979.png
# ../input/grapheme-imgs-128x128/Train_43504.png
# ../input/grapheme-imgs-128x128/Train_53847.png
# ../input/grapheme-imgs-128x128/Train_49270.png
# ../input/grapheme-imgs-128x128/Train_174179.png
# ../input/grapheme-imgs-128x128/Train_188844.png
# ../input/grapheme-imgs-128x128/Train_191557.png
# ../input/grapheme-imgs-128x128/Train_69594.png
# ../input/grapheme-imgs-128x128/Train_190158.png
# ../input/grapheme-imgs-128x128/Train_174964.png
# ../input/grapheme-imgs-128x128/Train_194308.png
# ../input/grapheme-imgs-128x128/Train_77274.png
# ../input/grapheme-imgs-128x128/Train_199735.png
# ../input/grapheme-imgs-128x128/Train_106221.png
# ../input/grapheme-imgs-128x128/Train_199702.png
# ../input/grapheme-imgs-128x128/Train_16089.png
# ../input/grapheme-imgs-128x128/Train_170970.png
# ../input/grapheme-imgs-128x128/Train_189793.png
# ../input/grapheme-imgs-128x128/Train_130948.png
# ../input/grapheme-imgs-128x128/Train_184016.png
# ../input/grapheme-imgs-128x128/Train_115071.png
# ../input/grapheme-imgs-128x128/Train_195958.png
# ../input/grapheme-imgs-128x128/Train_69020.png
# ../input/grapheme-imgs-128x128/Train_159026.png
# ../input/grapheme-imgs-128x128/Train_95319.png
# ../input/grapheme-imgs-128x128/Train_116844.png
# ../input/grapheme-imgs-128x128/Train_134574.png
# ../input/grapheme-imgs-128x128/Train_78247.png
# ../input/grapheme-imgs-128x128/Train_56928.png
# ../input/grapheme-imgs-128x128/Train_138432.png
# ../input/grapheme-imgs-128x128/Train_140772.png
# ../input/grapheme-imgs-128x128/Train_148135.png
# ../input/grapheme-imgs-128x128/Train_45382.png
# ../input/grapheme-imgs-128x128/Train_127279.png
# ../input/grapheme-imgs-128x128/Train_16342.png
# ../input/grapheme-imgs-128x128/Train_4470.png
# ../input/grapheme-imgs-128x128/Train_16596.png
# ../input/grapheme-imgs-128x128/Train_199440.png
# ../input/grapheme-imgs-128x128/Train_179248.png
# ../input/grapheme-imgs-128x128/Train_113307.png
# ../input/grapheme-imgs-128x128/Train_64885.png
# ../input/grapheme-imgs-128x128/Train_158476.png
# ../input/grapheme-imgs-128x128/Train_178528.png
# ../input/grapheme-imgs-128x128/Train_148323.png
# ../input/grapheme-imgs-128x128/Train_60390.png
# ../input/grapheme-imgs-128x128/Train_120397.png
# ../input/grapheme-imgs-128x128/Train_132871.png
# ../input/grapheme-imgs-128x128/Train_138510.png
# ../input/grapheme-imgs-128x128/Train_1236.png
# ../input/grapheme-imgs-128x128/Train_38075.png
# ../input/grapheme-imgs-128x128/Train_94660.png
# ../input/grapheme-imgs-128x128/Train_184163.png
# ../input/grapheme-imgs-128x128/Train_7059.png
# ../input/grapheme-imgs-128x128/Train_140421.png
# ../input/grapheme-imgs-128x128/Train_174512.png
# ../input/grapheme-imgs-128x128/Train_141932.png
# ../input/grapheme-imgs-128x128/Train_30460.png
# ../input/grapheme-imgs-128x128/Train_158666.png
# ../input/grapheme-imgs-128x128/Train_62985.png
# ../input/grapheme-imgs-128x128/Train_7692.png
# ../input/grapheme-imgs-128x128/Train_136378.png
# ../input/grapheme-imgs-128x128/Train_120047.png
# ../input/grapheme-imgs-128x128/Train_194068.png
# ../input/grapheme-imgs-128x128/Train_13275.png
# ../input/grapheme-imgs-128x128/Train_67035.png
# ../input/grapheme-imgs-128x128/Train_197443.png
# ../input/grapheme-imgs-128x128/Train_104611.png
# ../input/grapheme-imgs-128x128/Train_81415.png
# ../input/grapheme-imgs-128x128/Train_151117.png
# ../input/grapheme-imgs-128x128/Train_25692.png
# ../input/grapheme-imgs-128x128/Train_69198.png
# ../input/grapheme-imgs-128x128/Train_141824.png
# ../input/grapheme-imgs-128x128/Train_23042.png
# ../input/grapheme-imgs-128x128/Train_62480.png
# ../input/grapheme-imgs-128x128/Train_128703.png
# ../input/grapheme-imgs-128x128/Train_62392.png
# ../input/grapheme-imgs-128x128/Train_183114.png
# ../input/grapheme-imgs-128x128/Train_85035.png
# ../input/grapheme-imgs-128x128/Train_185859.png
# ../input/grapheme-imgs-128x128/Train_99617.png
# ../input/grapheme-imgs-128x128/Train_46996.png
# ../input/grapheme-imgs-128x128/Train_75020.png
# ../input/grapheme-imgs-128x128/Train_79585.png
# ../input/grapheme-imgs-128x128/Train_156439.png
# ../input/grapheme-imgs-128x128/Train_44007.png
# ../input/grapheme-imgs-128x128/Train_75429.png
# ../input/grapheme-imgs-128x128/Train_112247.png
# ../input/grapheme-imgs-128x128/Train_119398.png
# ../input/grapheme-imgs-128x128/Train_97358.png
# ../input/grapheme-imgs-128x128/Train_49981.png
# ../input/grapheme-imgs-128x128/Train_95871.png
# ../input/grapheme-imgs-128x128/Train_110182.png
# ../input/grapheme-imgs-128x128/Train_40593.png
# ../input/grapheme-imgs-128x128/Train_82795.png
# ../input/grapheme-imgs-128x128/Train_136048.png
# ../input/grapheme-imgs-128x128/Train_150616.png
# ../input/grapheme-imgs-128x128/Train_190448.png
# ../input/grapheme-imgs-128x128/Train_63184.png
# ../input/grapheme-imgs-128x128/Train_166656.png
# ../input/grapheme-imgs-128x128/Train_21202.png
# ../input/grapheme-imgs-128x128/Train_173185.png
# ../input/grapheme-imgs-128x128/Train_194297.png
# ../input/grapheme-imgs-128x128/Train_16188.png
# ../input/grapheme-imgs-128x128/Train_168058.png
# ../input/grapheme-imgs-128x128/Train_44975.png
# ../input/grapheme-imgs-128x128/Train_33737.png
# ../input/grapheme-imgs-128x128/Train_126195.png
# ../input/grapheme-imgs-128x128/Train_144853.png
# ../input/grapheme-imgs-128x128/Train_43719.png
# ../input/grapheme-imgs-128x128/Train_136246.png
# ../input/grapheme-imgs-128x128/Train_26368.png
# ../input/grapheme-imgs-128x128/Train_50157.png
# ../input/grapheme-imgs-128x128/Train_191487.png
# ../input/grapheme-imgs-128x128/Train_80957.png
# ../input/grapheme-imgs-128x128/Train_14755.png
# ../input/grapheme-imgs-128x128/Train_196788.png
# ../input/grapheme-imgs-128x128/Train_10714.png
# ../input/grapheme-imgs-128x128/Train_185563.png
# ../input/grapheme-imgs-128x128/Train_197338.png
# ../input/grapheme-imgs-128x128/Train_43687.png
# ../input/grapheme-imgs-128x128/Train_180026.png
# ../input/grapheme-imgs-128x128/Train_46788.png
# ../input/grapheme-imgs-128x128/Train_190776.png
# ../input/grapheme-imgs-128x128/Train_76823.png
# ../input/grapheme-imgs-128x128/Train_60823.png
# ../input/grapheme-imgs-128x128/Train_101250.png
# ../input/grapheme-imgs-128x128/Train_160639.png
# ../input/grapheme-imgs-128x128/Train_173365.png
# ../input/grapheme-imgs-128x128/Train_111344.png
# ../input/grapheme-imgs-128x128/Train_187746.png
# ../input/grapheme-imgs-128x128/Train_120662.png
# ../input/grapheme-imgs-128x128/Train_49170.png
# ../input/grapheme-imgs-128x128/Train_45197.png
# ../input/grapheme-imgs-128x128/Train_11597.png
# ../input/grapheme-imgs-128x128/Train_13832.png
# ../input/grapheme-imgs-128x128/Train_49069.png
# ../input/grapheme-imgs-128x128/Train_176884.png
# ../input/grapheme-imgs-128x128/Train_154598.png
# ../input/grapheme-imgs-128x128/Train_188344.png
# ../input/grapheme-imgs-128x128/Train_36156.png
# ../input/grapheme-imgs-128x128/Train_67839.png
# ../input/grapheme-imgs-128x128/Train_172475.png
# ../input/grapheme-imgs-128x128/Train_185582.png
# ../input/grapheme-imgs-128x128/Train_144452.png
# ../input/grapheme-imgs-128x128/Train_55485.png
# ../input/grapheme-imgs-128x128/Train_134434.png
# ../input/grapheme-imgs-128x128/Train_177671.png
# ../input/grapheme-imgs-128x128/Train_173085.png
# ../input/grapheme-imgs-128x128/Train_12614.png
# ../input/grapheme-imgs-128x128/Train_58570.png
# ../input/grapheme-imgs-128x128/Train_79978.png
# ../input/grapheme-imgs-128x128/Train_159260.png
# ../input/grapheme-imgs-128x128/Train_177641.png
# ../input/grapheme-imgs-128x128/Train_119610.png
# ../input/grapheme-imgs-128x128/Train_12708.png
# ../input/grapheme-imgs-128x128/Train_191949.png
# ../input/grapheme-imgs-128x128/Train_132764.png
# ../input/grapheme-imgs-128x128/Train_80825.png
# ../input/grapheme-imgs-128x128/Train_500.png
# ../input/grapheme-imgs-128x128/Train_198923.png
# ../input/grapheme-imgs-128x128/Train_60728.png
# ../input/grapheme-imgs-128x128/Train_107145.png
# ../input/grapheme-imgs-128x128/Train_86968.png
# ../input/grapheme-imgs-128x128/Train_2100.png
# ../input/grapheme-imgs-128x128/Train_123440.png
# ../input/grapheme-imgs-128x128/Train_187016.png
# ../input/grapheme-imgs-128x128/Train_18833.png
# ../input/grapheme-imgs-128x128/Train_80651.png
# ../input/grapheme-imgs-128x128/Train_75303.png
# ../input/grapheme-imgs-128x128/Train_14936.png
# ../input/grapheme-imgs-128x128/Train_93956.png
# ../input/grapheme-imgs-128x128/Train_162295.png
# ../input/grapheme-imgs-128x128/Train_173384.png
# ../input/grapheme-imgs-128x128/Train_48041.png
# ../input/grapheme-imgs-128x128/Train_66980.png
# ../input/grapheme-imgs-128x128/Train_107953.png
# ../input/grapheme-imgs-128x128/Train_124270.png
# ../input/grapheme-imgs-128x128/Train_16216.png
# ../input/grapheme-imgs-128x128/Train_39394.png
# ../input/grapheme-imgs-128x128/Train_16820.png
# ../input/grapheme-imgs-128x128/Train_53453.png
# ../input/grapheme-imgs-128x128/Train_176502.png
# ../input/grapheme-imgs-128x128/Train_185334.png
# ../input/grapheme-imgs-128x128/Train_127217.png
# ../input/grapheme-imgs-128x128/Train_62733.png
# ../input/grapheme-imgs-128x128/Train_146218.png
# ../input/grapheme-imgs-128x128/Train_44623.png
# ../input/grapheme-imgs-128x128/Train_32518.png
# ../input/grapheme-imgs-128x128/Train_51839.png
# ../input/grapheme-imgs-128x128/Train_160414.png
# ../input/grapheme-imgs-128x128/Train_129017.png
# ../input/grapheme-imgs-128x128/Train_75730.png
# ../input/grapheme-imgs-128x128/Train_172433.png
# ../input/grapheme-imgs-128x128/Train_122037.png
# ../input/grapheme-imgs-128x128/Train_52991.png
# ../input/grapheme-imgs-128x128/Train_161739.png
# ../input/grapheme-imgs-128x128/Train_189724.png
# ../input/grapheme-imgs-128x128/Train_64745.png
# ../input/grapheme-imgs-128x128/Train_161417.png
# ../input/grapheme-imgs-128x128/Train_63974.png
# ../input/grapheme-imgs-128x128/Train_11446.png
# ../input/grapheme-imgs-128x128/Train_186761.png
# ../input/grapheme-imgs-128x128/Train_126614.png
# ../input/grapheme-imgs-128x128/Train_172851.png
# ../input/grapheme-imgs-128x128/Train_49970.png
# ../input/grapheme-imgs-128x128/Train_111104.png
# ../input/grapheme-imgs-128x128/Train_26234.png
# ../input/grapheme-imgs-128x128/Train_52899.png
# ../input/grapheme-imgs-128x128/Train_192661.png
# ../input/grapheme-imgs-128x128/Train_142155.png
# ../input/grapheme-imgs-128x128/Train_24816.png
# ../input/grapheme-imgs-128x128/Train_58451.png
# ../input/grapheme-imgs-128x128/Train_175349.png
# ../input/grapheme-imgs-128x128/Train_35342.png
# ../input/grapheme-imgs-128x128/Train_121214.png
# ../input/grapheme-imgs-128x128/Train_80550.png
# ../input/grapheme-imgs-128x128/Train_70790.png
# ../input/grapheme-imgs-128x128/Train_129469.png
# ../input/grapheme-imgs-128x128/Train_88316.png
# ../input/grapheme-imgs-128x128/Train_18396.png
# ../input/grapheme-imgs-128x128/Train_196557.png
# ../input/grapheme-imgs-128x128/Train_31688.png
# ../input/grapheme-imgs-128x128/Train_181788.png
# ../input/grapheme-imgs-128x128/Train_173472.png
# ../input/grapheme-imgs-128x128/Train_64516.png
# ../input/grapheme-imgs-128x128/Train_122167.png
# ../input/grapheme-imgs-128x128/Train_118720.png
# ../input/grapheme-imgs-128x128/Train_169772.png
# ../input/grapheme-imgs-128x128/Train_140521.png
# ../input/grapheme-imgs-128x128/Train_125507.png
# ../input/grapheme-imgs-128x128/Train_88217.png
# ../input/grapheme-imgs-128x128/Train_74481.png
# ../input/grapheme-imgs-128x128/Train_191190.png
# ../input/grapheme-imgs-128x128/Train_29596.png
# ../input/grapheme-imgs-128x128/Train_63736.png
# ../input/grapheme-imgs-128x128/Train_83869.png
# ../input/grapheme-imgs-128x128/Train_17001.png
# ../input/grapheme-imgs-128x128/Train_139814.png
# ../input/grapheme-imgs-128x128/Train_31072.png
# ../input/grapheme-imgs-128x128/Train_149505.png
# ../input/grapheme-imgs-128x128/Train_191914.png
# ../input/grapheme-imgs-128x128/Train_77605.png
# ../input/grapheme-imgs-128x128/Train_34054.png
# ../input/grapheme-imgs-128x128/Train_33740.png
# ../input/grapheme-imgs-128x128/Train_134995.png
# ../input/grapheme-imgs-128x128/Train_68378.png
# ../input/grapheme-imgs-128x128/Train_121114.png
# ../input/grapheme-imgs-128x128/Train_161334.png
# ../input/grapheme-imgs-128x128/Train_45298.png
# ../input/grapheme-imgs-128x128/Train_25305.png
# ../input/grapheme-imgs-128x128/Train_47500.png
# ../input/grapheme-imgs-128x128/Train_10692.png
# ../input/grapheme-imgs-128x128/Train_192772.png
# ../input/grapheme-imgs-128x128/Train_52758.png
# ../input/grapheme-imgs-128x128/Train_5796.png
# ../input/grapheme-imgs-128x128/Train_163610.png
# ../input/grapheme-imgs-128x128/Train_23078.png
# ../input/grapheme-imgs-128x128/Train_98795.png
# ../input/grapheme-imgs-128x128/Train_15863.png
# ../input/grapheme-imgs-128x128/Train_111343.png
# ../input/grapheme-imgs-128x128/Train_155800.png
# ../input/grapheme-imgs-128x128/Train_30128.png
# ../input/grapheme-imgs-128x128/Train_92949.png
# ../input/grapheme-imgs-128x128/Train_165130.png
# ../input/grapheme-imgs-128x128/Train_88215.png
# ../input/grapheme-imgs-128x128/Train_70975.png
# ../input/grapheme-imgs-128x128/Train_155233.png
# ../input/grapheme-imgs-128x128/Train_93105.png
# ../input/grapheme-imgs-128x128/Train_142541.png
# ../input/grapheme-imgs-128x128/Train_94996.png
# ../input/grapheme-imgs-128x128/Train_162984.png
# ../input/grapheme-imgs-128x128/Train_38677.png
# ../input/grapheme-imgs-128x128/Train_93364.png
# ../input/grapheme-imgs-128x128/Train_171361.png
# ../input/grapheme-imgs-128x128/Train_2821.png
# ../input/grapheme-imgs-128x128/Train_94258.png
# ../input/grapheme-imgs-128x128/Train_158894.png
# ../input/grapheme-imgs-128x128/Train_178039.png
# ../input/grapheme-imgs-128x128/Train_176273.png
# ../input/grapheme-imgs-128x128/Train_135205.png
# ../input/grapheme-imgs-128x128/Train_39180.png
# ../input/grapheme-imgs-128x128/Train_69173.png
# ../input/grapheme-imgs-128x128/Train_19162.png
# ../input/grapheme-imgs-128x128/Train_124281.png
# ../input/grapheme-imgs-128x128/Train_34588.png
# ../input/grapheme-imgs-128x128/Train_29191.png
# ../input/grapheme-imgs-128x128/Train_32966.png
# ../input/grapheme-imgs-128x128/Train_25685.png
# ../input/grapheme-imgs-128x128/Train_110173.png
# ../input/grapheme-imgs-128x128/Train_155158.png
# ../input/grapheme-imgs-128x128/Train_131430.png
# ../input/grapheme-imgs-128x128/Train_117441.png
# ../input/grapheme-imgs-128x128/Train_196629.png
# ../input/grapheme-imgs-128x128/Train_11124.png
# ../input/grapheme-imgs-128x128/Train_160715.png
# ../input/grapheme-imgs-128x128/Train_113276.png
# ../input/grapheme-imgs-128x128/Train_186407.png
# ../input/grapheme-imgs-128x128/Train_186463.png
# ../input/grapheme-imgs-128x128/Train_111542.png
# ../input/grapheme-imgs-128x128/Train_65902.png
# ../input/grapheme-imgs-128x128/Train_38229.png
# ../input/grapheme-imgs-128x128/Train_161104.png
# ../input/grapheme-imgs-128x128/Train_104566.png
# ../input/grapheme-imgs-128x128/Train_110670.png
# ../input/grapheme-imgs-128x128/Train_70496.png
# ../input/grapheme-imgs-128x128/Train_149414.png
# ../input/grapheme-imgs-128x128/Train_121170.png
# ../input/grapheme-imgs-128x128/Train_59114.png
# ../input/grapheme-imgs-128x128/Train_150318.png
# ../input/grapheme-imgs-128x128/Train_50312.png
# ../input/grapheme-imgs-128x128/Train_131708.png
# ../input/grapheme-imgs-128x128/Train_196644.png
# ../input/grapheme-imgs-128x128/Train_57177.png
# ../input/grapheme-imgs-128x128/Train_151851.png
# ../input/grapheme-imgs-128x128/Train_106188.png
# ../input/grapheme-imgs-128x128/Train_160893.png
# ../input/grapheme-imgs-128x128/Train_133966.png
# ../input/grapheme-imgs-128x128/Train_108587.png
# ../input/grapheme-imgs-128x128/Train_115980.png
# ../input/grapheme-imgs-128x128/Train_106295.png
# ../input/grapheme-imgs-128x128/Train_43288.png
# ../input/grapheme-imgs-128x128/Train_46641.png
# ../input/grapheme-imgs-128x128/Train_22758.png
# ../input/grapheme-imgs-128x128/Train_4413.png
# ../input/grapheme-imgs-128x128/Train_127330.png
# ...
# ../input/grapheme-imgs-128x128/Train_27171.png
# ../input/grapheme-imgs-128x128/Train_189946.png
# ../input/grapheme-imgs-128x128/Train_89276.png
# ../input/grapheme-imgs-128x128/Train_7709.png
# ../input/grapheme-imgs-128x128/Train_27721.png
# ../input/grapheme-imgs-128x128/Train_15312.png
# ../input/grapheme-imgs-128x128/Train_74158.png
# ../input/grapheme-imgs-128x128/Train_90136.png
# ../input/grapheme-imgs-128x128/Train_57424.png
# ../input/grapheme-imgs-128x128/Train_56463.png
# ../input/grapheme-imgs-128x128/Train_89267.png
# ../input/grapheme-imgs-128x128/Train_126919.png
# ../input/grapheme-imgs-128x128/Train_46069.png
# ../input/grapheme-imgs-128x128/Train_183641.png
# ../input/grapheme-imgs-128x128/Train_138902.png
# ../input/grapheme-imgs-128x128/Train_98802.png
# ../input/grapheme-imgs-128x128/Train_158714.png
# ../input/grapheme-imgs-128x128/Train_127613.png
# ../input/grapheme-imgs-128x128/Train_200553.png
# ../input/grapheme-imgs-128x128/Train_151337.png
# ../input/grapheme-imgs-128x128/Train_168478.png
# ../input/grapheme-imgs-128x128/Train_180929.png
# ../input/grapheme-imgs-128x128/Train_178038.png
# ../input/grapheme-imgs-128x128/Train_106705.png
# ../input/grapheme-imgs-128x128/Train_122580.png
# ../input/grapheme-imgs-128x128/Train_131802.png
# ../input/grapheme-imgs-128x128/Train_38902.png
# ../input/grapheme-imgs-128x128/Train_154450.png
# ../input/grapheme-imgs-128x128/Train_97287.png
# ../input/grapheme-imgs-128x128/Train_143426.png
# ../input/grapheme-imgs-128x128/Train_186802.png
# ../input/grapheme-imgs-128x128/Train_101809.png
# ../input/grapheme-imgs-128x128/Train_5500.png
# ../input/grapheme-imgs-128x128/Train_162842.png
# ../input/grapheme-imgs-128x128/Train_18609.png
# ../input/grapheme-imgs-128x128/Train_172113.png
# ../input/grapheme-imgs-128x128/Train_149719.png
# ../input/grapheme-imgs-128x128/Train_142192.png
# ../input/grapheme-imgs-128x128/Train_6664.png
# ../input/grapheme-imgs-128x128/Train_188883.png
# ../input/grapheme-imgs-128x128/Train_88432.png
# ../input/grapheme-imgs-128x128/Train_51120.png
# ../input/grapheme-imgs-128x128/Train_89297.png
# ../input/grapheme-imgs-128x128/Train_10118.png
# ../input/grapheme-imgs-128x128/Train_31181.png
# ../input/grapheme-imgs-128x128/Train_49915.png
# ../input/grapheme-imgs-128x128/Train_192036.png
# ../input/grapheme-imgs-128x128/Train_73445.png
# ../input/grapheme-imgs-128x128/Train_130084.png
# ../input/grapheme-imgs-128x128/Train_11563.png
# ../input/grapheme-imgs-128x128/Train_146514.png
# ../input/grapheme-imgs-128x128/Train_174862.png
# ../input/grapheme-imgs-128x128/Train_174578.png
# ../input/grapheme-imgs-128x128/Train_126015.png
# ../input/grapheme-imgs-128x128/Train_52345.png
# ../input/grapheme-imgs-128x128/Train_165414.png
# ../input/grapheme-imgs-128x128/Train_125108.png
# ../input/grapheme-imgs-128x128/Train_92700.png
# ../input/grapheme-imgs-128x128/Train_158588.png
# ../input/grapheme-imgs-128x128/Train_12755.png
# ../input/grapheme-imgs-128x128/Train_118344.png
# ../input/grapheme-imgs-128x128/Train_187082.png
# ../input/grapheme-imgs-128x128/Train_101232.png
# ../input/grapheme-imgs-128x128/Train_17672.png
# ../input/grapheme-imgs-128x128/Train_116087.png
# ../input/grapheme-imgs-128x128/Train_75238.png
# ../input/grapheme-imgs-128x128/Train_40738.png
# ../input/grapheme-imgs-128x128/Train_182132.png
# ../input/grapheme-imgs-128x128/Train_167145.png
# ../input/grapheme-imgs-128x128/Train_89241.png
# ../input/grapheme-imgs-128x128/Train_82049.png
# ../input/grapheme-imgs-128x128/Train_153757.png
# ../input/grapheme-imgs-128x128/Train_118266.png
# ../input/grapheme-imgs-128x128/Train_88672.png
# ../input/grapheme-imgs-128x128/Train_116798.png
# ../input/grapheme-imgs-128x128/Train_136371.png
# ../input/grapheme-imgs-128x128/Train_106438.png
# ../input/grapheme-imgs-128x128/Train_67404.png
# ../input/grapheme-imgs-128x128/Train_94926.png
# ../input/grapheme-imgs-128x128/Train_104280.png
# ../input/grapheme-imgs-128x128/Train_177240.png
# ../input/grapheme-imgs-128x128/Train_48420.png
# ../input/grapheme-imgs-128x128/Train_171670.png
# ../input/grapheme-imgs-128x128/Train_79792.png
# ../input/grapheme-imgs-128x128/Train_77693.png
# ../input/grapheme-imgs-128x128/Train_8383.png
# ../input/grapheme-imgs-128x128/Train_17733.png
# ../input/grapheme-imgs-128x128/Train_54577.png
# ../input/grapheme-imgs-128x128/Train_130298.png
# ../input/grapheme-imgs-128x128/Train_149203.png
# ../input/grapheme-imgs-128x128/Train_121809.png
# ../input/grapheme-imgs-128x128/Train_11525.png
# ../input/grapheme-imgs-128x128/Train_96101.png
# ../input/grapheme-imgs-128x128/Train_107288.png
# ../input/grapheme-imgs-128x128/Train_28256.png
# ../input/grapheme-imgs-128x128/Train_71826.png
# ../input/grapheme-imgs-128x128/Train_96193.png
# ../input/grapheme-imgs-128x128/Train_107308.png
# ../input/grapheme-imgs-128x128/Train_139151.png
# ../input/grapheme-imgs-128x128/Train_109999.png
# ../input/grapheme-imgs-128x128/Train_145078.png
# ../input/grapheme-imgs-128x128/Train_155546.png
# ../input/grapheme-imgs-128x128/Train_53704.png
# ../input/grapheme-imgs-128x128/Train_147706.png
# ../input/grapheme-imgs-128x128/Train_153686.png
# ../input/grapheme-imgs-128x128/Train_122868.png
# ../input/grapheme-imgs-128x128/Train_101095.png
# ../input/grapheme-imgs-128x128/Train_30537.png
# ../input/grapheme-imgs-128x128/Train_35786.png
# ../input/grapheme-imgs-128x128/Train_5795.png
# ../input/grapheme-imgs-128x128/Train_134552.png
# ../input/grapheme-imgs-128x128/Train_100749.png
# ../input/grapheme-imgs-128x128/Train_104096.png
# ../input/grapheme-imgs-128x128/Train_49451.png
# ../input/grapheme-imgs-128x128/Train_100461.png
# ../input/grapheme-imgs-128x128/Train_16141.png
# ../input/grapheme-imgs-128x128/Train_149112.png
# ../input/grapheme-imgs-128x128/Train_198549.png
# ../input/grapheme-imgs-128x128/Train_25672.png
# ../input/grapheme-imgs-128x128/Train_68715.png
# ../input/grapheme-imgs-128x128/Train_84962.png
# ../input/grapheme-imgs-128x128/Train_65299.png
# ../input/grapheme-imgs-128x128/Train_53264.png
# ../input/grapheme-imgs-128x128/Train_144397.png
# ../input/grapheme-imgs-128x128/Train_80351.png
# ../input/grapheme-imgs-128x128/Train_86743.png
# ../input/grapheme-imgs-128x128/Train_141761.png
# ../input/grapheme-imgs-128x128/Train_194608.png
# ../input/grapheme-imgs-128x128/Train_122178.png
# ../input/grapheme-imgs-128x128/Train_58509.png
# ../input/grapheme-imgs-128x128/Train_170435.png
# ../input/grapheme-imgs-128x128/Train_40669.png
# ../input/grapheme-imgs-128x128/Train_78017.png
# ../input/grapheme-imgs-128x128/Train_186518.png
# ../input/grapheme-imgs-128x128/Train_157939.png
# ../input/grapheme-imgs-128x128/Train_94291.png
# ../input/grapheme-imgs-128x128/Train_13771.png
# ../input/grapheme-imgs-128x128/Train_28632.png
# ../input/grapheme-imgs-128x128/Train_39109.png
# ../input/grapheme-imgs-128x128/Train_185463.png
# ../input/grapheme-imgs-128x128/Train_58908.png
# ../input/grapheme-imgs-128x128/Train_90928.png
# ../input/grapheme-imgs-128x128/Train_96423.png
# ../input/grapheme-imgs-128x128/Train_11022.png
# ../input/grapheme-imgs-128x128/Train_120277.png
# ../input/grapheme-imgs-128x128/Train_175119.png
# ../input/grapheme-imgs-128x128/Train_2648.png
# ../input/grapheme-imgs-128x128/Train_168687.png
# ../input/grapheme-imgs-128x128/Train_122079.png
# ../input/grapheme-imgs-128x128/Train_165290.png
# ../input/grapheme-imgs-128x128/Train_165714.png
# ../input/grapheme-imgs-128x128/Train_103021.png
# ../input/grapheme-imgs-128x128/Train_177957.png
# ../input/grapheme-imgs-128x128/Train_149294.png
# ../input/grapheme-imgs-128x128/Train_177213.png
# ../input/grapheme-imgs-128x128/Train_116486.png
# ../input/grapheme-imgs-128x128/Train_89459.png
# ../input/grapheme-imgs-128x128/Train_90220.png
# ../input/grapheme-imgs-128x128/Train_43200.png
# ../input/grapheme-imgs-128x128/Train_175124.png
# ../input/grapheme-imgs-128x128/Train_5067.png
# ../input/grapheme-imgs-128x128/Train_36236.png
# ../input/grapheme-imgs-128x128/Train_88438.png
# ../input/grapheme-imgs-128x128/Train_63255.png
# ../input/grapheme-imgs-128x128/Train_193681.png
# ../input/grapheme-imgs-128x128/Train_113950.png
# ../input/grapheme-imgs-128x128/Train_135140.png
# ../input/grapheme-imgs-128x128/Train_177797.png
# ../input/grapheme-imgs-128x128/Train_26709.png
# ../input/grapheme-imgs-128x128/Train_77340.png
# ../input/grapheme-imgs-128x128/Train_194702.png
# ../input/grapheme-imgs-128x128/Train_54472.png
# ../input/grapheme-imgs-128x128/Train_76262.png
# ../input/grapheme-imgs-128x128/Train_3485.png
# ../input/grapheme-imgs-128x128/Train_121950.png
# ../input/grapheme-imgs-128x128/Train_123624.png
# ../input/grapheme-imgs-128x128/Train_188712.png
# ../input/grapheme-imgs-128x128/Train_52522.png
# ../input/grapheme-imgs-128x128/Train_159539.png
# ../input/grapheme-imgs-128x128/Train_18523.png
# ../input/grapheme-imgs-128x128/Train_3478.png
# ../input/grapheme-imgs-128x128/Train_26604.png
# ../input/grapheme-imgs-128x128/Train_43405.png
# ../input/grapheme-imgs-128x128/Train_166177.png
# ../input/grapheme-imgs-128x128/Train_81031.png
# ../input/grapheme-imgs-128x128/Train_90531.png
# ../input/grapheme-imgs-128x128/Train_89168.png
# ../input/grapheme-imgs-128x128/Train_107962.png
# ../input/grapheme-imgs-128x128/Train_154242.png
# ../input/grapheme-imgs-128x128/Train_160945.png
# ../input/grapheme-imgs-128x128/Train_102341.png
# ../input/grapheme-imgs-128x128/Train_14453.png
# ../input/grapheme-imgs-128x128/Train_139725.png
# ../input/grapheme-imgs-128x128/Train_159441.png
# ../input/grapheme-imgs-128x128/Train_77553.png
# ../input/grapheme-imgs-128x128/Train_61262.png
# ../input/grapheme-imgs-128x128/Train_124704.png
# ../input/grapheme-imgs-128x128/Train_55436.png
# ../input/grapheme-imgs-128x128/Train_169442.png
# ../input/grapheme-imgs-128x128/Train_24204.png
# ../input/grapheme-imgs-128x128/Train_89764.png
# ../input/grapheme-imgs-128x128/Train_29753.png
# ../input/grapheme-imgs-128x128/Train_107549.png
# ../input/grapheme-imgs-128x128/Train_19213.png
# ../input/grapheme-imgs-128x128/Train_119322.png
# ../input/grapheme-imgs-128x128/Train_60891.png
# ../input/grapheme-imgs-128x128/Train_114859.png
# ../input/grapheme-imgs-128x128/Train_25159.png
# ../input/grapheme-imgs-128x128/Train_140268.png
# ../input/grapheme-imgs-128x128/Train_27154.png
# ../input/grapheme-imgs-128x128/Train_12460.png
# ../input/grapheme-imgs-128x128/Train_76299.png
# ../input/grapheme-imgs-128x128/Train_8749.png
# ../input/grapheme-imgs-128x128/Train_9532.png
# ../input/grapheme-imgs-128x128/Train_79360.png
# ../input/grapheme-imgs-128x128/Train_125450.png
# ../input/grapheme-imgs-128x128/Train_159160.png
# ../input/grapheme-imgs-128x128/Train_48029.png
# ../input/grapheme-imgs-128x128/Train_119148.png
# ../input/grapheme-imgs-128x128/Train_78461.png
# ../input/grapheme-imgs-128x128/Train_37722.png
# ../input/grapheme-imgs-128x128/Train_15464.png
# ../input/grapheme-imgs-128x128/Train_4550.png
# ../input/grapheme-imgs-128x128/Train_125261.png
# ../input/grapheme-imgs-128x128/Train_71491.png
# ../input/grapheme-imgs-128x128/Train_197973.png
# ../input/grapheme-imgs-128x128/Train_151674.png
# ../input/grapheme-imgs-128x128/Train_42034.png
# ../input/grapheme-imgs-128x128/Train_140517.png
# ../input/grapheme-imgs-128x128/Train_103260.png
# ../input/grapheme-imgs-128x128/Train_180125.png
# ../input/grapheme-imgs-128x128/Train_147413.png
# ../input/grapheme-imgs-128x128/Train_91700.png
# ../input/grapheme-imgs-128x128/Train_84868.png
# ../input/grapheme-imgs-128x128/Train_171149.png
# ../input/grapheme-imgs-128x128/Train_15027.png
# ../input/grapheme-imgs-128x128/Train_76931.png
# ../input/grapheme-imgs-128x128/Train_122408.png
# ../input/grapheme-imgs-128x128/Train_170736.png
# ../input/grapheme-imgs-128x128/Train_104711.png
# ../input/grapheme-imgs-128x128/Train_82169.png
# ../input/grapheme-imgs-128x128/Train_52402.png
# ../input/grapheme-imgs-128x128/Train_185335.png
# ../input/grapheme-imgs-128x128/Train_42649.png
# ../input/grapheme-imgs-128x128/Train_178162.png
# ../input/grapheme-imgs-128x128/Train_10281.png
# ../input/grapheme-imgs-128x128/Train_183296.png
# ../input/grapheme-imgs-128x128/Train_103004.png
# ../input/grapheme-imgs-128x128/Train_32141.png
# ../input/grapheme-imgs-128x128/Train_22445.png
# ../input/grapheme-imgs-128x128/Train_38356.png
# ../input/grapheme-imgs-128x128/Train_11550.png
# ../input/grapheme-imgs-128x128/Train_115486.png
# ../input/grapheme-imgs-128x128/Train_148149.png
# ../input/grapheme-imgs-128x128/Train_144083.png
# ../input/grapheme-imgs-128x128/Train_80014.png
# ../input/grapheme-imgs-128x128/Train_142096.png
# ../input/grapheme-imgs-128x128/Train_68505.png
# ../input/grapheme-imgs-128x128/Train_10019.png
# ../input/grapheme-imgs-128x128/Train_107619.png
# ../input/grapheme-imgs-128x128/Train_167169.png
# ../input/grapheme-imgs-128x128/Train_162224.png
# ../input/grapheme-imgs-128x128/Train_162025.png
# ../input/grapheme-imgs-128x128/Train_99414.png
# ../input/grapheme-imgs-128x128/Train_81330.png
# ../input/grapheme-imgs-128x128/Train_70330.png
# ../input/grapheme-imgs-128x128/Train_148887.png
# ../input/grapheme-imgs-128x128/Train_24661.png
# ../input/grapheme-imgs-128x128/Train_110229.png
# ../input/grapheme-imgs-128x128/Train_72973.png
# ../input/grapheme-imgs-128x128/Train_44567.png
# ../input/grapheme-imgs-128x128/Train_58579.png
# ../input/grapheme-imgs-128x128/Train_181609.png
# ../input/grapheme-imgs-128x128/Train_142507.png
# ../input/grapheme-imgs-128x128/Train_171826.png
# ../input/grapheme-imgs-128x128/Train_183631.png
# ../input/grapheme-imgs-128x128/Train_59794.png
# ../input/grapheme-imgs-128x128/Train_29440.png
# ../input/grapheme-imgs-128x128/Train_69225.png
# ../input/grapheme-imgs-128x128/Train_143641.png
# ../input/grapheme-imgs-128x128/Train_4848.png
# ../input/grapheme-imgs-128x128/Train_1653.png
# ../input/grapheme-imgs-128x128/Train_65155.png
# ../input/grapheme-imgs-128x128/Train_124262.png
# ../input/grapheme-imgs-128x128/Train_3209.png
# ../input/grapheme-imgs-128x128/Train_91108.png
# ../input/grapheme-imgs-128x128/Train_164241.png
# ../input/grapheme-imgs-128x128/Train_173398.png
# ../input/grapheme-imgs-128x128/Train_145735.png
# ../input/grapheme-imgs-128x128/Train_118828.png
# ../input/grapheme-imgs-128x128/Train_170213.png
# ../input/grapheme-imgs-128x128/Train_134211.png
# ../input/grapheme-imgs-128x128/Train_94781.png
# ../input/grapheme-imgs-128x128/Train_10317.png
# ../input/grapheme-imgs-128x128/Train_25134.png
# ../input/grapheme-imgs-128x128/Train_100888.png
# ../input/grapheme-imgs-128x128/Train_52815.png
# ../input/grapheme-imgs-128x128/Train_67868.png
# ../input/grapheme-imgs-128x128/Train_60214.png
# ../input/grapheme-imgs-128x128/Train_168906.png
# ../input/grapheme-imgs-128x128/Train_381.png
# ../input/grapheme-imgs-128x128/Train_51417.png
# ../input/grapheme-imgs-128x128/Train_70268.png
# ../input/grapheme-imgs-128x128/Train_156236.png
# ../input/grapheme-imgs-128x128/Train_84784.png
# ../input/grapheme-imgs-128x128/Train_93375.png
# ../input/grapheme-imgs-128x128/Train_112028.png
# ../input/grapheme-imgs-128x128/Train_107135.png
# ../input/grapheme-imgs-128x128/Train_191424.png
# ../input/grapheme-imgs-128x128/Train_157828.png
# ../input/grapheme-imgs-128x128/Train_105426.png
# ../input/grapheme-imgs-128x128/Train_71629.png
# ../input/grapheme-imgs-128x128/Train_8123.png
# ../input/grapheme-imgs-128x128/Train_100646.png
# ../input/grapheme-imgs-128x128/Train_198160.png
# ../input/grapheme-imgs-128x128/Train_192077.png
# ../input/grapheme-imgs-128x128/Train_191554.png
# ../input/grapheme-imgs-128x128/Train_71419.png
# ../input/grapheme-imgs-128x128/Train_176500.png
# ../input/grapheme-imgs-128x128/Train_111867.png
# ../input/grapheme-imgs-128x128/Train_3207.png
# ../input/grapheme-imgs-128x128/Train_27491.png
# ../input/grapheme-imgs-128x128/Train_169646.png
# ../input/grapheme-imgs-128x128/Train_165456.png
# ../input/grapheme-imgs-128x128/Train_139967.png
# ../input/grapheme-imgs-128x128/Train_175946.png
# ../input/grapheme-imgs-128x128/Train_168579.png
# ../input/grapheme-imgs-128x128/Train_59409.png
# ../input/grapheme-imgs-128x128/Train_61963.png
# ../input/grapheme-imgs-128x128/Train_170244.png
# ../input/grapheme-imgs-128x128/Train_116059.png
# ../input/grapheme-imgs-128x128/Train_141424.png
# ../input/grapheme-imgs-128x128/Train_181552.png
# ../input/grapheme-imgs-128x128/Train_7548.png
# ../input/grapheme-imgs-128x128/Train_35484.png
# ../input/grapheme-imgs-128x128/Train_139885.png
# ../input/grapheme-imgs-128x128/Train_112849.png

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
debug=False
submission=False
batch_size=32*4
device='cuda:0'
out='.'
image_size=64*2
arch='pretrained'
model_name='se_resnext50_32x4d'

# %%
datadir = Path('../input/bengaliai-cv19')
featherdir = Path('../input/bengaliaicv19feather')
outdir = Path('./save')

# %%
# Read in the data CSV files
# train = pd.read_csv(datadir/'train.csv')
# test = pd.read_csv(datadir/'test.csv')
# sample_submission = pd.read_csv(datadir/'sample_submission.csv')
# class_map = pd.read_csv(datadir/'class_map.csv')

# %% [markdown]
# # Fast data loading with feather
#
# Refer [Bengali.AI super fast data loading with feather](https://www.kaggle.com/corochann/bengali-ai-super-fast-data-loading-with-feather) and [dataset](https://www.kaggle.com/corochann/bengaliaicv19feather) for detail.<br/>
# Original `parquet` format takes about 60 sec to load 1 data, while `feather` format takes about **2 sec to load 1 data!!!**
#
# ### How to add dataset
#
# When you write kernel, click "+ Add Data" botton on right top.<br/>
# Then inside window pop-up, you can see "Search Datasets" text box on right top.<br/>
# You can type "bengaliai-cv19-feather" to find this dataset and press "Add" botton to add the data.

# %%
import numpy as np
import pandas as pd
import gc


def prepare_image(datadir, featherdir, data_type='train',
                  submission=False, indices=[0, 1, 2, 3]):
    assert data_type in ['train', 'test']
    if submission:
        image_df_list = [pd.read_parquet(datadir / f'{data_type}_image_data_{i}.parquet')
                         for i in indices]
    else:
        image_df_list = [pd.read_feather(featherdir / f'{data_type}_image_data_{i}.feather')
                         for i in indices]

    print('image_df_list', len(image_df_list))
    HEIGHT = 137
    WIDTH = 236
    images = [df.iloc[:, 1:].values.reshape(-1, HEIGHT, WIDTH) for df in image_df_list]
    del image_df_list
    gc.collect()
    images = np.concatenate(images, axis=0)
    return images

# %%
os.listdir(r"../input")

# %%
# %%time

train = pd.read_csv(datadir/'train.csv')
train_labels = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].values
indices = [0] if debug else [0, 1, 2, 3]
train_images = prepare_image(
    datadir, featherdir, data_type='train', submission=False, indices=indices)

# %%
os.listdir("../input/bengaliaicv19feather/")

# %% [markdown]
# <a id="dataset"></a>
# # Dataset

# %%
"""
Referenced `chainer.dataset.DatasetMixin` to work with pytorch Dataset.
"""
import numpy
import six
import torch
from torch.utils.data.dataset import Dataset


class DatasetMixin(Dataset):

    def __init__(self, transform=None):
        self.transform = transform

    def __getitem__(self, index):
        """Returns an example or a sequence of examples."""
        if torch.is_tensor(index):
            index = index.tolist()
        if isinstance(index, slice):
            current, stop, step = index.indices(len(self))
            return [self.get_example_wrapper(i) for i in
                    six.moves.range(current, stop, step)]
        elif isinstance(index, list) or isinstance(index, numpy.ndarray):
            return [self.get_example_wrapper(i) for i in index]
        else:
            return self.get_example_wrapper(index)

    def __len__(self):
        """Returns the number of data points."""
        raise NotImplementedError

    def get_example_wrapper(self, i):
        """Wrapper of `get_example`, to apply `transform` if necessary"""
        example = self.get_example(i)
        if self.transform:
            example = self.transform(example)
        return example

    def get_example(self, i):
        """Returns the i-th example.

        Implementations should override it. It should raise :class:`IndexError`
        if the index is invalid.

        Args:
            i (int): The index of the example.

        Returns:
            The i-th example.

        """
        raise NotImplementedError

# %% [markdown]
# This `DatasetMixin` class can be used to define any custom dataset class in pytorch. We can implement `get_example(self, i)` method to return `i`-th data.
#
# Here I return i-th image `x` and `label`, with scaling image to be value ranges between 0~1.

# %%
import numpy as np


class BengaliAIDataset(DatasetMixin):
    def __init__(self, images, labels=None, transform=None, indices=None):
        super(BengaliAIDataset, self).__init__(transform=transform)
        self.images = images
        self.labels = labels
        if indices is None:
            indices = np.arange(len(images))
        self.indices = indices
        self.train = labels is not None

    def __len__(self):
        """return length of this dataset"""
        return len(self.indices)

    def get_example(self, i):
        """Return i-th data"""
        i = self.indices[i]
        x = self.images[i]
        # Opposite white and black: background will be white and
        # for future Affine transformation
        x = (255 - x).astype(np.float32) / 255.
        x = x.astype(np.double)
        if self.train:
            y = self.labels[i]
            return x, y
        else:
            return x

# %% [markdown]
# Let's see how this `BengaliAIDataset` work

# %% [markdown]
# `train_dataset[i]` returns i-th image array and 3 target labels (graphme_root, vowel_diacritic and consonant_diacritic).

# %%
train_dataset = BengaliAIDataset(train_images, train_labels)

image, label = train_dataset[0]
print('image', image.shape, 'label', label)

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    ax.set_title(f'label: {label}')
plt.tight_layout()
plt.show()
plt.savefig('bengaliai.png')

# %% [markdown]
# <a id="processing"></a>
# # Data augmentation/processing

# %% [markdown]
# For CNN training, data augmentation is important to improve test accuracy (generalization performance). I will show some image preprocessing to increase the data variety.

# %%
"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 4
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    #tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
    #                        translation=(tx, ty))
    tform = AffineTransform(scale=(sx, sy), shear=shear_angle, rotation=rot_angle)
    
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image


from scipy.ndimage.measurements import label

def connected_comp(array):
    
    structure = np.ones((3, 3), dtype=np.int)  # this defines the connection filter
    labeled, ncomponents = label(array, structure)
    
    valid = []
    for i in range(1,ncomponents+1):
        if np.sum(labeled == i)>10:
            valid.append(i)

    new_array = np.zeros(array.shape)
    for i in valid:
        new_array += labeled==i
    return new_array

def pad_with(vector, pad_width, iaxis, kwargs):
    pad_value = kwargs.get('padder', 0)
    vector[:pad_width[0]] = pad_value
    vector[-pad_width[1]:] = pad_value

def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    
    image[image < 20./255.] = 0
    
    is_black = image > threshold
    is_black[:5,:] = 0
    is_black[-5:,:] = 0
    is_black[:,:5] = 0
    is_black[:,-5:] = 0
    #is_black = connected_comp(is_black)
    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    left = np.argmax(is_black_horizontal)
    right = np.argmax(is_black_horizontal[::-1])
    top = np.argmax(is_black_vertical)
    bottom = np.argmax(is_black_vertical[::-1])
    height, width = image.shape
    cropped_image = image[left-5:height - right+5, top-5:width - bottom+5]
    
    lx, ly = height - right - left + 10, width - bottom - top + 10
    l = max(lx,ly)
    #make sure that the aspect ratio is kept in rescaling
    cropped_image = np.pad(cropped_image, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    
    # scaling
    cropped_image = cropped_image*(1/cropped_image.max())
    
    #pad
    cropped_image = np.pad(cropped_image, 8, pad_with)
    
    return cropped_image

def resize(image, size=(128, 128)):
    return cv2.resize(image, size)

# %%
# Erosion
def erosion(img):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, tuple(np.random.randint(1, 3, 2)))
    img = cv2.erode(img, kernel, iterations=1)
    return img

# Dilation
def dilation(img):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, tuple(np.random.randint(1, 3, 2)))
    img = cv2.dilate(img, kernel, iterations=1)
    return img


def get_random_kernel():
    structure = np.random.choice([cv2.MORPH_RECT, cv2.MORPH_ELLIPSE, cv2.MORPH_CROSS])
    kernel = cv2.getStructuringElement(structure, tuple(np.random.randint(1, 3, 2)))
    return kernel

# Opening
def opening(img):
    img = cv2.erode(img, get_random_kernel(), iterations=1)
    img = cv2.dilate(img, get_random_kernel(), iterations=1)
    return img

#Closing
def closing(img):
    img = cv2.dilate(img, get_random_kernel(), iterations=1)
    img = cv2.erode(img, get_random_kernel(), iterations=1)
    return img

# %% [markdown]
# ## Affine transformation for data augmentation
#
# To increase validation score, the number of training data is important. When we can use more number of training data, we can reduce overfitting and validation score becomes high.
#
# "Data augmentation" is a technic to virtually create extra training data, based on the given training data. For this MNIST task, data augmentation can be achieved by utilizing affine transformation.
#
# 1. Rotation AffineTransformation
# 2. Translation
# 3. Scale
# 4. Shear

# %% [markdown]
# When the image is slightly rotated, shifted (transformed) or scaled, the image looks like the same label. We can virtually create another image data from one image in such a way.

# %%
nrow, ncol = 1, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label2 = train_dataset[0]
    ax.imshow(affine_image(image), cmap='Greys')
    ax.set_title(f'label: {label2}')
plt.tight_layout()

# %% [markdown]
# ## crop image
#
# Here I crop image

# %% [markdown]
# ## resize image
#
# We need to resize image after crop, to align image size for CNN batch training.

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label2 = train_dataset[i+30*5]
    ax.imshow(image, cmap='Greys')
    ax.set_title(f'label: {label2}')
plt.tight_layout()

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label2 = train_dataset[i+30*5]
    ax.imshow(resize(crop_char_image(image, threshold=40./255.)), cmap='Greys')
    ax.set_title(f'label: {label2}')
plt.tight_layout()

# %% [markdown]
# Put everything together with `Transform` class. <br>
# [Update] I added **albumentations augmentations** introduced in [Bengali: albumentations data augmentation tutorial](https://www.kaggle.com/corochann/bengali-albumentations-data-augmentation-tutorial).

# %%
import albumentations as A
import numpy as np


def add_gaussian_noise(x, sigma):
    x += np.random.randn(*x.shape) * sigma
    x = np.clip(x, 0., 1.)
    return x


def _evaluate_ratio(ratio):
    if ratio <= 0.:
        return False
    return np.random.uniform() < ratio


def apply_aug(aug, image):
    return aug(image=image)['image']


# class Transform:
#     def __init__(self, affine=True, crop=True, size=(64, 64),
#                  normalize=True, train=True, threshold=40.,
#                  sigma=-1., blur_ratio=0., noise_ratio=0., cutout_ratio=0.,
#                  grid_distortion_ratio=0., elastic_distortion_ratio=0., random_brightness_ratio=0.,
#                  piece_affine_ratio=0., ssr_ratio=0.):
#         self.affine = affine
#         self.crop = crop
#         self.size = size
#         self.normalize = normalize
#         self.train = train
#         self.threshold = threshold / 255.
#         self.sigma = sigma / 255.

#         self.blur_ratio = blur_ratio
#         self.noise_ratio = noise_ratio
#         self.cutout_ratio = cutout_ratio
#         self.grid_distortion_ratio = grid_distortion_ratio
#         self.elastic_distortion_ratio = elastic_distortion_ratio
#         self.random_brightness_ratio = random_brightness_ratio
#         self.piece_affine_ratio = piece_affine_ratio
#         self.ssr_ratio = ssr_ratio

#     def __call__(self, example):
        
        
#         if self.train:
#             x, y = example
#         else:
#             x = example
            
#         # --- Augmentation ---
#         if self.affine:
#             x = affine_image(x)

            
#         # --- Train/Test common preprocessing ---
#         if self.crop:
#             x = crop_char_image(x, threshold=self.threshold)
#         if self.size is not None:
#             x = resize(x, size=self.size)
#         #if self.sigma > 0.:
#         #    x = add_gaussian_noise(x, sigma=self.sigma)

        
#         #plt.imshow(x)
#         #plt.show()
        
#         # albumentations...
#         x = x.astype(np.float32)
#         assert x.ndim == 2
        
#         # 1. blur
#         if _evaluate_ratio(self.blur_ratio):
#             r = np.random.uniform()
#             if r < 0.25:
#                 x = apply_aug(A.Blur(p=1.0), x)
#             elif r < 0.5:
#                 x = apply_aug(A.MedianBlur(blur_limit=5, p=1.0), x)
#             elif r < 0.75:
#                 x = apply_aug(A.GaussianBlur(p=1.0), x)
#             else:
#                 x = apply_aug(A.MotionBlur(p=1.0), x)
                

#         if _evaluate_ratio(self.noise_ratio):
#             r = np.random.uniform()
#             if r < 0.50:
#                 x = apply_aug(A.GaussNoise(var_limit=5. / 255., p=1.0), x)
#             else:
#                 x = apply_aug(A.MultiplicativeNoise(p=1.0), x)

#         if _evaluate_ratio(self.cutout_ratio):
#             # A.Cutout(num_holes=2,  max_h_size=2, max_w_size=2, p=1.0)  # Deprecated...
#             x = apply_aug(A.Cutout(max_h_size=8, max_w_size=8, p=1.0), x)
#             #x = apply_aug(A.CoarseDropout(max_holes=8, max_height=8, max_width=8, p=1.0), x)

#         if _evaluate_ratio(self.grid_distortion_ratio):
#             x = apply_aug(A.GridDistortion(p=1.0), x)

#         if _evaluate_ratio(self.elastic_distortion_ratio):
#             x = apply_aug(A.ElasticTransform(
#                 sigma=50, alpha=1, alpha_affine=10, p=1.0), x)

#         if _evaluate_ratio(self.random_brightness_ratio):
#             # A.RandomBrightness(p=1.0)  # Deprecated...
#             # A.RandomContrast(p=1.0)    # Deprecated...
#             x = apply_aug(A.RandomBrightnessContrast(p=1.0), x)

#         if _evaluate_ratio(self.piece_affine_ratio):
#             x = apply_aug(A.IAAPiecewiseAffine(p=1.0), x)

#         if _evaluate_ratio(self.ssr_ratio):
#             x = apply_aug(A.ShiftScaleRotate(
#                 shift_limit=0.0625,
#                 scale_limit=0.1,
#                 rotate_limit=30,
#                 p=1.0), x)
        
# #         # 난수생성
# #         const = np.random.rand(1)[0]
        
#         # Erosion, dilation
# #         if const<0.5:
# #             x = erosion(x)
# #         else:
# #             x = dilation(x)
        
        
        
# #         if const<0.15:
# #             x = erosion(x)
# #         elif const<0.3:
# #             x = dilation(x)
# #         elif const<0.45:
# #             x = opening(x)
# #         elif const<0.6:
# #             x = closing(x)
        
# #         plt.imshow(x)
# #         plt.show()

        
#         #if self.normalize:
#         #    x = (x.astype(np.double) - 0.0692) / 0.2051
#         if x.ndim == 2:
#             x = x[None, :, :]
#         x = x.astype(np.double)
#         if self.train:
#             y = y.astype(np.int64)
#             return x, y
#         else:
#             return x
        
#         # normalize by its max val
#         x = x * (255./x.max())
        
        
class Transform:
    def __init__(self, affine=True, crop=True, size=(64, 64),
                 normalize=True, train=True, threshold=40.,
                 sigma=-1., blur_ratio=0., noise_ratio=0., cutout_ratio=0.,
                 grid_distortion_ratio=0., elastic_distortion_ratio=0., random_brightness_ratio=0.,
                 piece_affine_ratio=0., ssr_ratio=0.):
        self.affine = affine
        self.crop = crop
        self.size = size
        self.normalize = normalize
        self.train = train
        self.threshold = threshold / 255.
        self.sigma = sigma / 255.

        self.blur_ratio = blur_ratio
        self.noise_ratio = noise_ratio
        self.cutout_ratio = cutout_ratio
        self.grid_distortion_ratio = grid_distortion_ratio
        self.elastic_distortion_ratio = elastic_distortion_ratio
        self.random_brightness_ratio = random_brightness_ratio
        self.piece_affine_ratio = piece_affine_ratio
        self.ssr_ratio = ssr_ratio

    def __call__(self, example):
        if self.train:
            x, y = example
        else:
            x = example
                    
        # remove noise
        # x [x<28./255.] = 0
        
        # --- Augmentation ---
        if self.affine:
            x = affine_image(x)

        # --- Train/Test common preprocessing ---
        if self.crop:
            x = crop_char_image(x, threshold=self.threshold)
        if self.size is not None:
            x = resize(x, size=self.size)
        if self.sigma > 0.:
            x = add_gaussian_noise(x, sigma=self.sigma)

        # albumentations...
        x = x.astype(np.float32)
        assert x.ndim == 2
        # 1. blur
        if _evaluate_ratio(self.blur_ratio):
            r = np.random.uniform()
            if r < 0.25:
                x = apply_aug(A.Blur(p=1.0), x)
            elif r < 0.5:
                x = apply_aug(A.MedianBlur(blur_limit=5, p=1.0), x)
            elif r < 0.75:
                x = apply_aug(A.GaussianBlur(p=1.0), x)
            else:
                x = apply_aug(A.MotionBlur(p=1.0), x)

        if _evaluate_ratio(self.noise_ratio):
            r = np.random.uniform()
            if r < 0.50:
                x = apply_aug(A.GaussNoise(var_limit=5. / 255., p=1.0), x)
            else:
                x = apply_aug(A.MultiplicativeNoise(p=1.0), x)

        if _evaluate_ratio(self.cutout_ratio):
            # A.Cutout(num_holes=2,  max_h_size=2, max_w_size=2, p=1.0)  # Deprecated...
            x = apply_aug(A.CoarseDropout(max_holes=8, max_height=8, max_width=8, p=1.0), x)

        if _evaluate_ratio(self.grid_distortion_ratio):
            x = apply_aug(A.GridDistortion(p=1.0), x)

        if _evaluate_ratio(self.elastic_distortion_ratio):
            x = apply_aug(A.ElasticTransform(
                sigma=50, alpha=1, alpha_affine=10, p=1.0), x)

        if _evaluate_ratio(self.random_brightness_ratio):
            # A.RandomBrightness(p=1.0)  # Deprecated...
            # A.RandomContrast(p=1.0)    # Deprecated...
            x = apply_aug(A.RandomBrightnessContrast(p=1.0), x)

        if _evaluate_ratio(self.piece_affine_ratio):
            x = apply_aug(A.IAAPiecewiseAffine(p=1.0), x)

        if _evaluate_ratio(self.ssr_ratio):
            x = apply_aug(A.ShiftScaleRotate(
                shift_limit=0.0625,
                scale_limit=0.1,
                rotate_limit=30,
                p=1.0), x)

        #if self.normalize:
        #    x = (x.astype(np.float32) - 0.0692) / 0.2051
        # normalize by its max val
        # x = x * (255./x.max())
        
        if x.ndim == 2:
            x = x[None, :, :]
        x = x.astype(np.float32)
        if self.train:
            y = y.astype(np.int64)
            return x, y
        else:
            return x

# %%
# train_transform = Transform(
#     size=(image_size, image_size), threshold=20.,
#     sigma=-1., blur_ratio=0.1, noise_ratio=0, cutout_ratio=0.2,
#     grid_distortion_ratio=0.2, random_brightness_ratio=0.2,
#     piece_affine_ratio=0.2, ssr_ratio=0.2)
# train_dataset = BengaliAIDataset(train_images, train_labels,
#                                  transform=train_transform)

# for i in range(10):
#     train_dataset[0]

# %%
train_transform = Transform(
    size=(image_size, image_size), threshold=40.,
    sigma=-1., blur_ratio=0.2, noise_ratio=0.2, cutout_ratio=0.2,
    grid_distortion_ratio=0.2, random_brightness_ratio=0.2,
    piece_affine_ratio=0.2, ssr_ratio=0.2)
# transform = Transform(size=(image_size, image_size)
train_dataset = BengaliAIDataset(train_images, train_labels,
                                 transform=train_transform)

# %% [markdown]
# ### Let's final check the processed images, which will be trained by the model.

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label = train_dataset[i]
    ax.imshow(image[0], cmap='Greys')
    ax.set_title(f'label: {label}')
plt.tight_layout()

# %% [markdown]
# <a id="model"></a>
# # pytorch model & define classifier

# %%
import torch


def residual_add(lhs, rhs):
    lhs_ch, rhs_ch = lhs.shape[1], rhs.shape[1]
    if lhs_ch < rhs_ch:
        out = lhs + rhs[:, :lhs_ch]
    elif lhs_ch > rhs_ch:
        out = torch.cat([lhs[:, :rhs_ch] + rhs, lhs[:, rhs_ch:]], dim=1)
    else:
        out = lhs + rhs
    return out

# %%
from typing import List

import torch
from torch import nn
from torch.nn.parameter import Parameter


class LazyLoadModule(nn.Module):
    """Lazy buffer/parameter loading using load_state_dict_pre_hook

    Define all buffer/parameter in `_lazy_buffer_keys`/`_lazy_parameter_keys` and
    save buffer with `register_buffer`/`register_parameter`
    method, which can be outside of __init__ method.
    Then this module can load any shape of Tensor during de-serializing.

    Note that default value of lazy buffer is torch.Tensor([]), while lazy parameter is None.
    """
    _lazy_buffer_keys: List[str] = []     # It needs to be override to register lazy buffer
    _lazy_parameter_keys: List[str] = []  # It needs to be override to register lazy parameter

    def __init__(self):
        super(LazyLoadModule, self).__init__()
        for k in self._lazy_buffer_keys:
            self.register_buffer(k, torch.tensor([]))
        for k in self._lazy_parameter_keys:
            self.register_parameter(k, None)
        self._register_load_state_dict_pre_hook(self._hook)

    def _hook(self, state_dict, prefix, local_metadata, strict, missing_keys,
             unexpected_keys, error_msgs):
        for key in self._lazy_buffer_keys:
            self.register_buffer(key, state_dict[prefix + key])

        for key in self._lazy_parameter_keys:
            self.register_parameter(key, Parameter(state_dict[prefix + key]))

# %%
import math
import torch
from torch.nn import init
from torch.nn.parameter import Parameter
import torch.nn.functional as F


class LazyLinear(LazyLoadModule):
    """Linear module with lazy input inference

    `in_features` can be `None`, and it is determined at the first time of forward step dynamically.
    """

    __constants__ = ['bias', 'in_features', 'out_features']
    _lazy_parameter_keys = ['weight']

    def __init__(self, in_features, out_features, bias=True):
        super(LazyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        if bias:
            self.bias = Parameter(torch.Tensor(out_features))
        else:
            self.register_parameter('bias', None)

        if in_features is not None:
            self.weight = Parameter(torch.Tensor(out_features, in_features))
            self.reset_parameters()

    def reset_parameters(self):
        init.kaiming_uniform_(self.weight, a=math.sqrt(5))
        if self.bias is not None:
            fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
            bound = 1 / math.sqrt(fan_in)
            init.uniform_(self.bias, -bound, bound)

    def forward(self, input):
        if self.weight is None:
            self.in_features = input.shape[-1]
            self.weight = Parameter(torch.Tensor(self.out_features, self.in_features))
            self.reset_parameters()

            # Need to send lazy defined parameter to device...
            self.to(input.device)
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None
        )

# %%
from torch import nn
import torch.nn.functional as F


class LinearBlock(nn.Module):

    def __init__(self, in_features, out_features, bias=True,
                 use_bn=True, activation=F.relu, dropout_ratio=-1, residual=False,):
        super(LinearBlock, self).__init__()
        if in_features is None:
            self.linear = LazyLinear(in_features, out_features, bias=bias)
        else:
            self.linear = nn.Linear(in_features, out_features, bias=bias)
        if use_bn:
            self.bn = nn.BatchNorm1d(out_features)
        if dropout_ratio > 0.:
            self.dropout = nn.Dropout(p=dropout_ratio)
        else:
            self.dropout = None
        self.activation = activation
        self.use_bn = use_bn
        self.dropout_ratio = dropout_ratio
        self.residual = residual

    def __call__(self, x):
        h = self.linear(x)
        if self.use_bn:
            h = self.bn(h)
        if self.activation is not None:
            h = self.activation(h)
        if self.residual:
            h = residual_add(h, x)
        if self.dropout_ratio > 0:
            h = self.dropout(h)
        return h

# %%
import pretrainedmodels
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Sequential


class PretrainedCNN(nn.Module):
    def __init__(self, model_name='se_resnext101_32x4d',
                 in_channels=1, out_dim=10, use_bn=True,
                 pretrained='imagenet'):
        super(PretrainedCNN, self).__init__()
        self.conv0 = nn.Conv2d(
            in_channels, 3, kernel_size=3, stride=1, padding=1, bias=True)
        self.base_model = pretrainedmodels.__dict__[model_name](pretrained=pretrained)
        activation = F.leaky_relu
        self.do_pooling = True
        if self.do_pooling:
            inch = self.base_model.last_linear.in_features
        else:
            inch = None
        hdim = 512
        lin1 = LinearBlock(inch, hdim, use_bn=use_bn, activation=activation, residual=False)
        lin2 = LinearBlock(hdim, out_dim, use_bn=use_bn, activation=None, residual=False)
        self.lin_layers = Sequential(lin1, lin2)

    def forward(self, x):
        
        h = self.conv0(x)
        h = self.base_model.features(h)
        
        if self.do_pooling:
            h = torch.sum(h, dim=(-1, -2))
        else:
            # [128, 2048, 4, 4] when input is (128, 128)
            bs, ch, height, width = h.shape
            h = h.view(bs, ch*height*width)
        for layer in self.lin_layers:
            h = layer(h)
            
        return h

# %% [markdown]
# ## Classifier

# %%
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2
def cutmix(data, targets1, targets2, targets3, alpha):
    indices = torch.randperm(data.size(0))
    shuffled_data = data[indices]
    shuffled_targets1 = targets1[indices]
    shuffled_targets2 = targets2[indices]
    shuffled_targets3 = targets3[indices]

    lam = np.random.beta(alpha, alpha)
    while lam > 0.999:
        lam = np.random.beta(alpha, alpha)
    bbx1, bby1, bbx2, bby2 = rand_bbox(data.size(), lam)
    
#     print(lam)
#     print(data.shape)
#     print(indices)
#     print(bbx1, bbx2, bby1, bby2)
    
    data[:, :, bbx1:bbx2, bby1:bby2] = data[indices, :, bbx1:bbx2, bby1:bby2]
    # adjust lambda to exactly match pixel ratio
    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (data.size()[-1] * data.size()[-2]))

    targets = [targets1, shuffled_targets1, targets2, shuffled_targets2, targets3, shuffled_targets3, lam]
    return data, targets

def mixup(data, targets1, targets2, targets3, alpha):
    indices = torch.randperm(data.size(0))
    shuffled_data = data[indices]
    shuffled_targets1 = targets1[indices]
    shuffled_targets2 = targets2[indices]
    shuffled_targets3 = targets3[indices]

    lam = np.random.beta(alpha, alpha)
    data = data * lam + shuffled_data * (1 - lam)
    targets = [targets1, shuffled_targets1, targets2, shuffled_targets2, targets3, shuffled_targets3, lam]

    return data, targets


def cutmix_criterion(preds1,preds2,preds3, targets):
    targets1, targets2,targets3, targets4,targets5, targets6, lam = targets[0], targets[1], targets[2], targets[3], targets[4], targets[5], targets[6]
    criterion = nn.CrossEntropyLoss(reduction='mean')
    return lam * criterion(preds1, targets1) + (1 - lam) * criterion(preds1, targets2) + lam * criterion(preds2, targets3) + (1 - lam) * criterion(preds2, targets4) + lam * criterion(preds3, targets5) + (1 - lam) * criterion(preds3, targets6)

def mixup_criterion(preds1,preds2,preds3, targets):
    targets1, targets2,targets3, targets4,targets5, targets6, lam = targets[0], targets[1], targets[2], targets[3], targets[4], targets[5], targets[6]
    criterion = nn.CrossEntropyLoss(reduction='mean')
    return lam * criterion(preds1, targets1) + (1 - lam) * criterion(preds1, targets2) + lam * criterion(preds2, targets3) + (1 - lam) * criterion(preds2, targets4) + lam * criterion(preds3, targets5) + (1 - lam) * criterion(preds3, targets6)

# %%
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm


def accuracy(y, t):
    pred_label = torch.argmax(y, dim=1)
    count = pred_label.shape[0]
    correct = (pred_label == t).sum().type(torch.double)
    acc = correct / count
    return acc


class BengaliClassifier(nn.Module):
    def __init__(self, predictor, n_grapheme=168, n_vowel=11, n_consonant=7):
        super(BengaliClassifier, self).__init__()
        self.n_grapheme = n_grapheme
        self.n_vowel = n_vowel
        self.n_consonant = n_consonant
        self.n_total_class = self.n_grapheme + self.n_vowel + self.n_consonant
        self.predictor = predictor.float()
        
        self.metrics_keys = [
            'loss', 'loss_grapheme', 'loss_vowel', 'loss_consonant',
            'acc_grapheme', 'acc_vowel', 'acc_consonant']
        
    def forward(self, x, y=None):
        
        const = np.random.randint(6)
        
        if const<2:        
            # mixup
            data, targets = mixup(x, y[:,0], y[:,1], y[:,2], 0.4)
            x = data
        elif const<4:        
            # cutmix
            data, targets = cutmix(x, y[:,0], y[:,1], y[:,2], 0.4)
            x = data
            
        #plt.imshow(x[0,0].cpu().numpy())
        #plt.show()
            
        pred = self.predictor(x)
        
        if isinstance(pred, tuple):
            assert len(pred) == 3
            preds = pred
        else:
            assert pred.shape[1] == self.n_total_class
            preds = torch.split(pred, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
            
        if const<4:
            # cutmix or mixup
            targets1, targets2, targets3, targets4,targets5, targets6, lam = targets[0], targets[1], targets[2], targets[3], targets[4], targets[5], targets[6]        
            preds1, preds2, preds3 = preds[0], preds[1], preds[2]
            lam = float(lam)
            loss_grapheme = lam * F.cross_entropy(preds1, targets1) + (1 - lam) * F.cross_entropy(preds1, targets2) 
            loss_vowel = lam * F.cross_entropy(preds2, targets3) + (1 - lam) * F.cross_entropy(preds2, targets4)
            loss_consonant = lam * F.cross_entropy(preds3, targets5) + (1 - lam) * F.cross_entropy(preds3, targets6)
            loss = 2*loss_grapheme + loss_vowel + loss_consonant
        else:
            loss_grapheme = F.cross_entropy(preds[0], y[:, 0])
            loss_vowel = F.cross_entropy(preds[1], y[:, 1])
            loss_consonant = F.cross_entropy(preds[2], y[:, 2])
            loss = 2*loss_grapheme + loss_vowel + loss_consonant
            
        metrics = {
            'loss': loss.item(),
            'loss_grapheme': loss_grapheme.item(),
            'loss_vowel': loss_vowel.item(),
            'loss_consonant': loss_consonant.item(),
            'acc_grapheme': accuracy(preds[0], y[:, 0]),
            'acc_vowel': accuracy(preds[1], y[:, 1]),
            'acc_consonant': accuracy(preds[2], y[:, 2]),
        }
        
        return loss, metrics, pred
    
    
    
    def forward_val(self, x, y=None):

        pred = self.predictor(x)
        
        if isinstance(pred, tuple):
            assert len(pred) == 3
            preds = pred
        else:
            assert pred.shape[1] == self.n_total_class
            preds = torch.split(pred, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        
        loss_grapheme = F.cross_entropy(preds[0], y[:, 0])
        loss_vowel = F.cross_entropy(preds[1], y[:, 1])
        loss_consonant = F.cross_entropy(preds[2], y[:, 2])
        loss = 2*loss_grapheme + loss_vowel + loss_consonant
        metrics = {
            'loss': loss.item(),
            'loss_grapheme': loss_grapheme.item(),
            'loss_vowel': loss_vowel.item(),
            'loss_consonant': loss_consonant.item(),
            'acc_grapheme': accuracy(preds[0], y[:, 0]),
            'acc_vowel': accuracy(preds[1], y[:, 1]),
            'acc_consonant': accuracy(preds[2], y[:, 2]),
        }
        
        return loss, metrics, pred
    

    def calc(self, data_loader):
        device: torch.device = next(self.parameters()).device
        self.eval()
        output_list = []
        with torch.no_grad():
            for batch in tqdm(data_loader):
                # TODO: support general preprocessing.
                # If `data` is not `Data` instance, `to` method is not supported!
                batch = batch.to(device)
                pred = self.predictor(batch)
                
                output_list.append(pred)
        output = torch.cat(output_list, dim=0)
        preds = torch.split(output, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        return preds

    def predict_proba(self, data_loader):
        preds = self.calc(data_loader)
        return [F.softmax(p, dim=1) for p in preds]

    def predict(self, data_loader):
        preds = self.calc(data_loader)
        pred_labels = [torch.argmax(p, dim=1) for p in preds]
        return pred_labels

# %% [markdown]
# <a id="train"></a>
# # Training code

# %% [markdown]
# ## prepare data

# %%
# import numpy as np
# import pandas as pd
# import iterstrat
# #!pip install iterative-stratification


# #get data
# nfold = 5
# seed = 12

# train_df = copy.copy(train)
# train_df['id'] = train_df['image_id'].apply(lambda x: int(x.split('_')[1]))

# X, y = train_df[['id', 'grapheme_root', 'vowel_diacritic', 'consonant_diacritic']]\
# .values[:,0], train_df.values[:,1:]

# train_df['fold'] = np.nan

# #split data
# from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# mskf = MultilabelStratifiedKFold(n_splits=nfold, random_state=seed)
# for i, (_, test_index) in enumerate(mskf.split(X, y)):
#     train_df.iloc[test_index, -1] = i
    
# train_df['fold'] = train_df['fold'].astype('int')

# %%
# iterative-stratification

import copy
import numpy as np
import pandas as pd
import iterstrat
#!pip install iterative-stratification

#get data
nfold = 5
seed = 12

train_df = copy.copy(train)
train_df['id'] = train_df['image_id'].apply(lambda x: int(x.split('_')[1]))

X, y = train_df[['id', 'grapheme_root', 'vowel_diacritic', 'consonant_diacritic']]\
.values[:,0], train_df.values[:,1:]

train_df['fold'] = np.nan

#split data
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
mskf = MultilabelStratifiedKFold(n_splits=nfold, random_state=seed)
for i, (_, test_index) in enumerate(mskf.split(X, y)):
    train_df.iloc[test_index, -1] = i
    
train_df['fold'] = train_df['fold'].astype('int')

#------------------------------

n_dataset = len(train_images)
train_data_size = 200 if debug else int(n_dataset * 0.8)
valid_data_size = 100 if debug else int(n_dataset - train_data_size)

#perm = np.random.RandomState(777).permutation(n_dataset)
#print('perm', perm)
train_dataset = BengaliAIDataset(
    train_images, train_labels, transform=train_transform,
    indices = np.array(list(train_df[train_df['fold']!=0].index)))
    #    indices=perm[:train_data_size])
valid_dataset = BengaliAIDataset(
    train_images, train_labels, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
    indices = np.array(list(train_df[train_df['fold']==0].index)))
#    indices=perm[train_data_size:train_data_size+valid_data_size])
print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))

# --- Model ---
device = torch.device(device)
n_grapheme = 168
n_vowel = 11
n_consonant = 7
n_total = n_grapheme + n_vowel + n_consonant
print('n_total', n_total)
# Set pretrained='imagenet' to download imagenet pretrained model...
predictor = PretrainedCNN(in_channels=1, out_dim=n_total, model_name=model_name, pretrained=None)
print('predictor', type(predictor))

# %%
# #load weights
# predictor.load_state_dict(torch.load(r"/home/dohee/Documents/Bengali/code/save/model_000030.pt"))
# predictor.train()

classifier = BengaliClassifier(predictor).to(device)

# %% [markdown]
# ## Ignite utility
#
# pytorch-ignite utility class for training

# %%
import json
from logging import getLogger
import numpy

def save_json(filepath, params):
    with open(filepath, 'w') as f:
        json.dump(params, f, indent=4)

import os
from logging import getLogger
from time import perf_counter

import pandas as pd
import torch
# from chainer_chemistry.utils import save_json

from ignite.engine.engine import Engine, Events
from ignite.metrics import Average


class DictOutputTransform:
    def __init__(self, key, index=0):
        self.key = key
        self.index = index

    def __call__(self, x):
        if self.index >= 0:
            x = x[self.index]
        return x[self.key]


def create_trainer(classifier, optimizer, device):
    classifier.to(device)    
    def update_fn(engine, batch):
        classifier.train()
        optimizer.zero_grad()

        # batch = [elem.to(device) for elem in batch]
        x, y = [elem.to(device) for elem in batch]
        x = x.float()
        
#         # mixup
#         data, targets = mixup(x, y[:,0], y[:,1], y[:,2], 0.4)
#         #print(data.shape)
#         print(len(targets))
#         print(targets[0].shape)
#         print(y.shape)
        
#         print(targets)
#         print(y)

        
        loss, metrics, pred_y = classifier(x, y)
        
#         print(pred_y.shape)
#         print(pred_y)
#         print("---------------")
        
        loss.backward()
        optimizer.step()
        return metrics, pred_y, y
    
    
    trainer = Engine(update_fn)
    
    for key in classifier.metrics_keys:
        Average(output_transform=DictOutputTransform(key)).attach(trainer, key)
        
    return trainer


def create_evaluator(classifier, device):
    classifier.to(device)
    def update_fn(engine, batch):
        classifier.eval()
        with torch.no_grad():
            # batch = [elem.to(device) for elem in batch]
            x, y = [elem.to(device) for elem in batch]
            x = x.float()
            _, metrics, pred_y = classifier.forward_val(x, y)
            return metrics, pred_y, y
    evaluator = Engine(update_fn)
    for key in classifier.metrics_keys:
        Average(output_transform=DictOutputTransform(key)).attach(evaluator, key)
    return evaluator


class LogReport:
    def __init__(self, evaluator=None, dirpath=None, logger=None):
        self.evaluator = evaluator
        self.dirpath = str(dirpath) if dirpath is not None else None
        self.logger = logger or getLogger(__name__)

        self.reported_dict = {}  # To handle additional parameter to monitor
        self.history = []
        self.start_time = perf_counter()

    def report(self, key, value):
        self.reported_dict[key] = value

    def __call__(self, engine):
        elapsed_time = perf_counter() - self.start_time
        elem = {'epoch': engine.state.epoch,
                'iteration': engine.state.iteration}
        elem.update({f'train/{key}': value
                     for key, value in engine.state.metrics.items()})
        if self.evaluator is not None:
            elem.update({f'valid/{key}': value
                         for key, value in self.evaluator.state.metrics.items()})
        elem.update(self.reported_dict)
        elem['elapsed_time'] = elapsed_time
        
        ####
        print(elem)
        
        self.history.append(elem)
        if self.dirpath:
            save_json(os.path.join(self.dirpath, 'log.json'), self.history)
            self.get_dataframe().to_csv(os.path.join(self.dirpath, 'log.csv'), index=False)

        # --- print ---
        msg = ''
        for key, value in elem.items():
            if key in ['iteration']:
                # skip printing some parameters...
                continue
            elif isinstance(value, int):
                msg += f'{key} {value: >6d} '
            else:
                msg += f'{key} {value: 8f} '
#         self.logger.warning(msg)
        print(msg)

        # --- Reset ---
        self.reported_dict = {}

    def get_dataframe(self):
        df = pd.DataFrame(self.history)
        return df


class SpeedCheckHandler:
    def __init__(self, iteration_interval=10, logger=None):
        self.iteration_interval = iteration_interval
        self.logger = logger or getLogger(__name__)
        self.prev_time = perf_counter()

    def __call__(self, engine: Engine):
        if engine.state.iteration % self.iteration_interval == 0:
            cur_time = perf_counter()
            spd = self.iteration_interval / (cur_time - self.prev_time)
            self.logger.warning(f'{spd} iter/sec')
            # reset
            self.prev_time = cur_time

    def attach(self, engine: Engine):
        engine.add_event_handler(Events.ITERATION_COMPLETED, self)


class ModelSnapshotHandler:
    def __init__(self, model, filepath=r'./save/model_{count:06}.pt',
                 interval=10, logger=None):
        self.model = model
        self.filepath: str = str(filepath)
        self.interval = interval
        self.logger = logger or getLogger(__name__)
        self.count = 0

    def __call__(self, engine: Engine):
        self.count += 1
        if self.count % self.interval == 0:
            filepath = self.filepath.format(count=self.count)
            torch.save(self.model.state_dict(), filepath)
            print("saving model epoch:", self.count)
            
            #self.logger.warning(f'save model to {filepath}...')


import warnings

import torch

from ignite.metrics.metric import Metric


class EpochMetric(Metric):
    """Class for metrics that should be computed on the entire output history of a model.
    Model's output and targets are restricted to be of shape `(batch_size, n_classes)`. Output
    datatype should be `float32`. Target datatype should be `long`.

    .. warning::

        Current implementation stores all input data (output and target) in as tensors before computing a metric.
        This can potentially lead to a memory error if the input data is larger than available RAM.


    - `update` must receive output of the form `(y_pred, y)`.

    If target shape is `(batch_size, n_classes)` and `n_classes > 1` than it should be binary: e.g. `[[0, 1, 0, 1], ]`.

    Args:
        compute_fn (callable): a callable with the signature (`torch.tensor`, `torch.tensor`) takes as the input
            `predictions` and `targets` and returns a scalar.
        output_transform (callable, optional): a callable that is used to transform the
            :class:`~ignite.engine.Engine`'s `process_function`'s output into the
            form expected by the metric. This can be useful if, for example, you have a multi-output model and
            you want to compute the metric with respect to one of the outputs.

    """

    def __init__(self, compute_fn, output_transform=lambda x: x):

        if not callable(compute_fn):
            raise TypeError("Argument compute_fn should be callable.")

        super(EpochMetric, self).__init__(output_transform=output_transform)
        self.compute_fn = compute_fn

    def reset(self):
        self._predictions = torch.tensor([], dtype=torch.float)
        self._targets = torch.tensor([], dtype=torch.long)

    def update(self, output):
        y_pred, y = output
        self._predictions = torch.cat([self._predictions, y_pred], dim=0)
        self._targets = torch.cat([self._targets, y], dim=0)

        # Check once the signature and execution of compute_fn
        if self._predictions.shape == y_pred.shape:
            try:
                self.compute_fn(self._predictions, self._targets)
            except Exception as e:
                warnings.warn("Probably, there can be a problem with `compute_fn`:\n {}.".format(e),
                              RuntimeWarning)

    def compute(self):
        return self.compute_fn(self._predictions, self._targets)


import numpy as np
import sklearn.metrics
import torch


def macro_recall(pred_y, y, n_grapheme=168, n_vowel=11, n_consonant=7):
    pred_y = torch.split(pred_y, [n_grapheme, n_vowel, n_consonant], dim=1)
    pred_labels = [torch.argmax(py, dim=1).cpu().numpy() for py in pred_y]

    y = y.cpu().numpy()
    # pred_y = [p.cpu().numpy() for p in pred_y]

    recall_grapheme = sklearn.metrics.recall_score(pred_labels[0], y[:, 0], average='macro')
    recall_vowel = sklearn.metrics.recall_score(pred_labels[1], y[:, 1], average='macro')
    recall_consonant = sklearn.metrics.recall_score(pred_labels[2], y[:, 2], average='macro')
    scores = [recall_grapheme, recall_vowel, recall_consonant]
    final_score = np.average(scores, weights=[2, 1, 1])
    # print(f'recall: grapheme {recall_grapheme}, vowel {recall_vowel}, consonant {recall_consonant}, '
    #       f'total {final_score}, y {y.shape}')
    return final_score


def calc_macro_recall(solution, submission):
    # solution df, submission df
    scores = []
    for component in ['grapheme_root', 'consonant_diacritic', 'vowel_diacritic']:
        y_true_subset = solution[solution[component] == component]['target'].values
        y_pred_subset = submission[submission[component] == component]['target'].values
        scores.append(sklearn.metrics.recall_score(
            y_true_subset, y_pred_subset, average='macro'))
    final_score = np.average(scores, weights=[2, 1, 1])
    return final_score

# %%
# def create_trainer(classifier, optimizer, device):
#     classifier.to(device)    
#     def update_fn(engine, batch):
#         classifier.train()
#         optimizer.zero_grad()

#         # batch = [elem.to(device) for elem in batch]
#         x, y = [elem.to(device) for elem in batch]        
#         x = x.float()
        
#         print(x.shape)
#         print(y.shape)
        
#         loss, metrics, pred_y = classifier(x, y)

# %%
# from ignite.handlers import ModelCheckpoint

# checkpoint_every = 10

# dirname = r"./save"
# engine_checkpoint = ModelCheckpoint(
#     dirname=dirname,
#     'my_model',
#     save_interval=checkpoint_every,
#     create_dir = True)

# %%
import argparse
from distutils.util import strtobool
import os

import torch
from ignite.contrib.handlers import ProgressBar
from ignite.engine import Events
from numpy.random.mtrand import RandomState
from torch.utils.data.dataloader import DataLoader

# --- Training setting ---

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)


#optimizer = torch.optim.Adam(classifier.parameters(), lr=0.001)

# AdamW
optimizer = torch.optim.AdamW(classifier.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.7, patience=5, min_lr=1e-10)

trainer = create_trainer(classifier, optimizer, device)
def output_transform(output):
    metric, pred_y, y = output
    return pred_y.cpu(), y.cpu()
EpochMetric(
    compute_fn=macro_recall,
    output_transform=output_transform
).attach(trainer, 'recall')

pbar = ProgressBar()
pbar.attach(trainer, metric_names='all')

evaluator = create_evaluator(classifier, device)
EpochMetric(
    compute_fn=macro_recall,
    output_transform=output_transform
).attach(evaluator, 'recall')

def run_evaluator(engine):
    evaluator.run(valid_loader)

def schedule_lr(engine):
    # metrics = evaluator.state.metrics
    metrics = engine.state.metrics
    avg_mae = metrics['loss']

    # --- update lr ---
    lr = scheduler.optimizer.param_groups[0]['lr']
    scheduler.step(avg_mae)
    log_report.report('lr', lr)

trainer.add_event_handler(Events.EPOCH_COMPLETED, run_evaluator)
trainer.add_event_handler(Events.EPOCH_COMPLETED, schedule_lr)
log_report = LogReport(evaluator, outdir)
trainer.add_event_handler(Events.EPOCH_COMPLETED, log_report)
trainer.add_event_handler(
    Events.EPOCH_COMPLETED,
    ModelSnapshotHandler(predictor))
    #ModelSnapshotHandler(predictor, filepath=outdir / 'predictor.pt'))
#trainer.add_event_handler(Events.EPOCH_COMPLETED, engine_checkpoint, {'mymodel':classifier})

# %%
trainer.run(train_loader, max_epochs=100)

# %%
train_history = log_report.get_dataframe()
train_history.to_csv(outdir / 'log.csv', index=False)

train_history
# Out:
#     epoch  iteration  train/loss  train/loss_grapheme  train/loss_vowel  \
# 0       1       1256    6.234926             2.192784          0.985815
# 1       2       2512    4.448632             1.586387          0.736391
# 2       3       3768    4.107210             1.482734          0.685554
# 3       4       5024    3.793065             1.370314          0.639941
# 4       5       6280    3.869330             1.399219          0.654586
# ..    ...        ...         ...                  ...               ...
# 85     86     108016    2.123764             0.734787          0.394098
# 86     87     109272    2.000731             0.688227          0.376302
# 87     88     110528    2.257645             0.780354          0.420467
# 88     89     111784    2.223693             0.767448          0.415222
# 89     90     113040    2.097279             0.722690          0.393610
#
#     train/loss_consonant  train/acc_grapheme  train/acc_vowel  \
# 0               0.863544            0.470355         0.646671
# 1               0.539466            0.575680         0.706229
# 2               0.456189            0.586951         0.710552
# 3               0.412496            0.601898         0.715167
# 4               0.416306            0.580078         0.697508
# ..                   ...                 ...              ...
# 85              0.260092            0.693789         0.766508
# 86              0.247975            0.702292         0.763952
# 87              0.276471            0.669860         0.742579
# 88              0.273573            0.689192         0.757862
# 89              0.258289            0.688862         0.754261
#
#     train/acc_consonant  train/recall  valid/loss  valid/loss_grapheme  \
# 0              0.749832      0.514117    1.508354             0.474868
# 1              0.802486      0.646372    1.204920             0.405421
# 2              0.807014      0.662502    0.946451             0.316430
# 3              0.809147      0.670662    0.886762             0.291939
# 4              0.797653      0.649351    0.875025             0.285379
# ..                  ...           ...         ...                  ...
# 85             0.843657      0.732827    0.421940             0.147208
# 86             0.844633      0.734393    0.394362             0.146056
# 87             0.827870      0.709063    0.433073             0.153282
# 88             0.837984      0.725219    0.407212             0.145843
# 89             0.836553      0.722976    0.449369             0.155203
#
#     valid/loss_vowel  valid/loss_consonant  valid/acc_grapheme  \
# 0           0.279991              0.278627            0.902106
# 1           0.205907              0.188171            0.915236
# 2           0.177754              0.135836            0.927012
# 3           0.168276              0.134608            0.935356
# 4           0.174417              0.129851            0.941286
# ..               ...                   ...                 ...
# 85          0.069670              0.057854            0.968453
# 86          0.052941              0.049309            0.967657
# 87          0.067915              0.058593            0.968099
# 88          0.059830              0.055697            0.968130
# 89          0.076067              0.062896            0.967433
#
#     valid/acc_vowel  valid/acc_consonant  valid/recall        lr  \
# 0          0.968895             0.964365      0.932753  0.001000
# 1          0.973579             0.973491      0.942308  0.001000
# 2          0.978605             0.977851      0.953756  0.001000
# 3          0.977814             0.978373      0.954776  0.001000
# 4          0.980283             0.979866      0.958303  0.001000
# ..              ...                  ...           ...       ...
# 85         0.992027             0.990490      0.977049  0.000168
# 86         0.992157             0.990620      0.975864  0.000168
# 87         0.992132             0.990465      0.977530  0.000168
# 88         0.992182             0.990365      0.976119  0.000168
# 89         0.991877             0.990365      0.976487  0.000168
#
#      elapsed_time
# 0     1940.058363
# 1     3870.802208
# 2     5799.581470
# 3     7732.342645
# 4     9663.269271
# ..            ...
# 85  165360.546501
# 86  167256.196159
# 87  169155.247539
# 88  171045.766246
# 89  172946.207080
#
# [90 rows x 20 columns]

# %% [markdown]
# <a id="pred"></a>
# # Prediction
#
# Please refer **[Bengali: SEResNeXt prediction with pytorch](https://www.kaggle.com/corochann/bengali-seresnext-prediction-with-pytorch)** for the prediction with trained model and submission for this competition!!!

# %%
# --- Model ---
device = torch.device(device)
n_grapheme = 168
n_vowel = 11
n_consonant = 7
n_total = n_grapheme + n_vowel + n_consonant
print('n_total', n_total)

# %%
def build_predictor(arch, out_dim, model_name=None):
    if arch == 'pretrained':
        predictor = PretrainedCNN(in_channels=1, out_dim=out_dim, model_name=model_name)
    else:
        raise ValueError("[ERROR] Unexpected value arch={}".format(arch))
    return predictor


def build_classifier(arch, load_model_path, n_total, model_name='', device='cuda:0'):
    if isinstance(device, str):
        device = torch.device(device)
    predictor = build_predictor(arch, out_dim=n_total, model_name=model_name)
    print('predictor', type(predictor))
    classifier = BengaliClassifier(predictor)
    if load_model_path:
        predictor.load_state_dict(torch.load(load_model_path))
    else:
        print("[WARNING] Unexpected value load_model_path={}"
              .format(load_model_path))
    classifier.to(device)
    return classifier

# %%
def predict_core(test_images, image_size, threshold,
                 arch, n_total, model_name, load_model_path, batch_size=512, device='cuda:0', **kwargs):
    classifier = build_classifier(arch, load_model_path, n_total, model_name, device=device)
    

    r"""
    ###############
    n_dataset = len(test_images)
    train_data_size = 200 if debug else int(n_dataset * 0.9)
    valid_data_size = 100 if debug else int(n_dataset - train_data_size)
    
    perm = np.random.RandomState(777).permutation(n_dataset)
    print('perm', perm)
    train_dataset = BengaliAIDataset(
        train_images, train_labels, transform=Transform(size=(image_size, image_size)),
        indices=perm[:train_data_size])
    valid_dataset = BengaliAIDataset(
        train_images, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
        )
    print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))
    test_dataset = valid_dataset
    """
    
    test_dataset = BengaliAIDataset(
       test_images, None,
       transform=Transform(affine=False, crop=True, size=(image_size, image_size),
                           threshold=threshold, train=False))
    print('test_dataset', len(test_dataset))
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    test_pred_proba = classifier.predict_proba(test_loader)
    return test_pred_proba

# %%
from torch import nn
import torch.nn.functional as F


class LinearBlock(nn.Module):

    def __init__(self, in_features, out_features, bias=True,
                 use_bn=True, activation=F.relu, dropout_ratio=-1, residual=False,):
        super(LinearBlock, self).__init__()
        if in_features is None:
            self.linear = LazyLinear(in_features, out_features, bias=bias)
        else:
            self.linear = nn.Linear(in_features, out_features, bias=bias)
        if use_bn:
            self.bn = nn.BatchNorm1d(out_features)
        if dropout_ratio > 0.:
            self.dropout = nn.Dropout(p=dropout_ratio)
        else:
            self.dropout = None
        self.activation = activation
        self.use_bn = use_bn
        self.dropout_ratio = dropout_ratio
        self.residual = residual

    def __call__(self, x):
        h = self.linear(x)
        if self.use_bn:
            h = self.bn(h)
        if self.activation is not None:
            h = self.activation(h)
        if self.residual:
            h = residual_add(h, x)
        if self.dropout_ratio > 0:
            h = self.dropout(h)
        return h

# %%
import pretrainedmodels
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Sequential

class PretrainedCNN(nn.Module):
    def __init__(self, model_name='se_resnext50_32x4d',
                 in_channels=1, out_dim=10, use_bn=True,
                 pretrained=None):
        super(PretrainedCNN, self).__init__()
        self.conv0 = nn.Conv2d(
            in_channels, 3, kernel_size=3, stride=1, padding=1, bias=True)
        self.base_model = pretrainedmodels.__dict__[model_name](pretrained=pretrained)
        activation = F.leaky_relu
        self.do_pooling = True
        if self.do_pooling:
            inch = self.base_model.last_linear.in_features
        else:
            inch = None
        hdim = 512
        lin1 = LinearBlock(inch, hdim, use_bn=use_bn, activation=activation, residual=False)
        lin2 = LinearBlock(hdim, out_dim, use_bn=use_bn, activation=None, residual=False)
        self.lin_layers = Sequential(lin1, lin2)

    def forward(self, x):
        h = self.conv0(x)
        h = self.base_model.features(h)

        if self.do_pooling:
            h = torch.sum(h, dim=(-1, -2))
        else:
            # [128, 2048, 4, 4] when input is (128, 128)
            bs, ch, height, width = h.shape
            h = h.view(bs, ch*height*width)
        for layer in self.lin_layers:
            h = layer(h)
        return h

# %%
import torch
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm


def accuracy(y, t):
    pred_label = torch.argmax(y, dim=1)
    count = pred_label.shape[0]
    correct = (pred_label == t).sum().type(torch.float32)
    acc = correct / count
    return acc


class BengaliClassifier(nn.Module):
    def __init__(self, predictor, n_grapheme=168, n_vowel=11, n_consonant=7):
        super(BengaliClassifier, self).__init__()
        self.n_grapheme = n_grapheme
        self.n_vowel = n_vowel
        self.n_consonant = n_consonant
        self.n_total_class = self.n_grapheme + self.n_vowel + self.n_consonant
        self.predictor = predictor

        self.metrics_keys = [
            'loss', 'loss_grapheme', 'loss_vowel', 'loss_consonant',
            'acc_grapheme', 'acc_vowel', 'acc_consonant']

    def forward(self, x, y=None):
        
        pred = self.predictor(x)
        if isinstance(pred, tuple):
            assert len(pred) == 3
            preds = pred
        else:
            assert pred.shape[1] == self.n_total_class
            preds = torch.split(pred, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        loss_grapheme = F.cross_entropy(preds[0], y[:, 0])
        loss_vowel = F.cross_entropy(preds[1], y[:, 1])
        loss_consonant = F.cross_entropy(preds[2], y[:, 2])
        loss = loss_grapheme + loss_vowel + loss_consonant
        metrics = {
            'loss': loss.item(),
            'loss_grapheme': loss_grapheme.item(),
            'loss_vowel': loss_vowel.item(),
            'loss_consonant': loss_consonant.item(),
            'acc_grapheme': accuracy(preds[0], y[:, 0]),
            'acc_vowel': accuracy(preds[1], y[:, 1]),
            'acc_consonant': accuracy(preds[2], y[:, 2]),
        }
        return loss, metrics, pred

    def calc(self, data_loader):
        device: torch.device = next(self.parameters()).device
        self.eval()
        output_list = []
        with torch.no_grad():
            for batch in tqdm(data_loader):
                # TODO: support general preprocessing.
                # If `data` is not `Data` instance, `to` method is not supported!
                batch = batch.to(device)
                pred = self.predictor(batch)
                output_list.append(pred)
        output = torch.cat(output_list, dim=0)
        preds = torch.split(output, [self.n_grapheme, self.n_vowel, self.n_consonant], dim=1)
        return preds

    def predict_proba(self, data_loader):
        preds = self.calc(data_loader)
        return [F.softmax(p, dim=1) for p in preds]

    def predict(self, data_loader):
        preds = self.calc(data_loader)
        pred_labels = [torch.argmax(p, dim=1) for p in preds]
        return pred_labels

# %%
import numpy as np


class BengaliAIDataset(DatasetMixin):
    def __init__(self, images, labels=None, transform=None, indices=None):
        super(BengaliAIDataset, self).__init__(transform=transform)
        self.images = images
        self.labels = labels
        if indices is None:
            indices = np.arange(len(images))
        self.indices = indices
        self.train = labels is not None

    def __len__(self):
        """return length of this dataset"""
        return len(self.indices)

    def get_example(self, i):
        """Return i-th data"""
        i = self.indices[i]
        x = self.images[i]
        # Opposite white and black: background will be white (1.0) and
        # for future Affine transformation
        x = (255 - x).astype(np.float32) / 255.
        if self.train:
            y = self.labels[i]
            return x, y
        else:
            return x

# %%
import numpy as np


def add_gaussian_noise(x, sigma):
    x += np.random.randn(*x.shape) * sigma
    x = np.clip(x, 0., 1.)
    return x


class Transform:
    def __init__(self, affine=True, crop=True, size=(64, 64),
                 normalize=True, train=True, threshold=20.,
                 sigma=-1.):
        self.affine = affine
        self.crop = crop
        self.size = size
        self.normalize = normalize
        self.train = train
        self.threshold = threshold / 255.
        self.sigma = sigma / 255.

    def __call__(self, example):
        if self.train:
            x, y = example
        else:
            x = example
        # --- Augmentation ---
        if self.affine:
            x = affine_image(x)

        # --- Train/Test common preprocessing ---
        if self.crop:
            x = crop_char_image(x, threshold=self.threshold)
        if self.size is not None:
            x = resize(x, size=self.size)
        if self.sigma > 0.:
            x = add_gaussian_noise(x, sigma=self.sigma)
        if self.normalize:
            x = (x.astype(np.float32) - 0.0692) / 0.2051
        if x.ndim == 2:
            x = x[None, :, :]
        x = x.astype(np.float32)
        if self.train:
            y = y.astype(np.int64)
            return x, y
        else:
            return x

# %%
"""
From https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700
"""
import cv2
from skimage.transform import AffineTransform, warp
import numpy as np


def affine_image(img):
    """

    Args:
        img: (h, w) or (1, h, w)

    Returns:
        img: (h, w)
    """
    # ch, h, w = img.shape
    # img = img / 255.
    if img.ndim == 3:
        img = img[0]

    # --- scale ---
    min_scale = 0.8
    max_scale = 1.2
    sx = np.random.uniform(min_scale, max_scale)
    sy = np.random.uniform(min_scale, max_scale)

    # --- rotation ---
    max_rot_angle = 7
    rot_angle = np.random.uniform(-max_rot_angle, max_rot_angle) * np.pi / 180.

    # --- shear ---
    max_shear_angle = 10
    shear_angle = np.random.uniform(-max_shear_angle, max_shear_angle) * np.pi / 180.

    # --- translation ---
    max_translation = 4
    tx = np.random.randint(-max_translation, max_translation)
    ty = np.random.randint(-max_translation, max_translation)

    tform = AffineTransform(scale=(sx, sy), rotation=rot_angle, shear=shear_angle,
                            translation=(tx, ty))
    transformed_image = warp(img, tform)
    assert transformed_image.ndim == 2
    return transformed_image


from scipy.ndimage.measurements import label

def connected_comp(array):
    
    structure = np.ones((3, 3), dtype=np.int)  # this defines the connection filter
    labeled, ncomponents = label(array, structure)
    
    valid = []
    for i in range(1,ncomponents+1):
        if np.sum(labeled == i)>10:
            valid.append(i)

    new_array = np.zeros(array.shape)
    for i in valid:
        new_array += labeled==i
    return new_array

def crop_char_image(image, threshold=5./255.):
    assert image.ndim == 2
    is_black = image > threshold
    is_black[:2,:] = 0
    is_black[-2:,:] = 0
    is_black[:,:2] = 0
    is_black[:,-2:] = 0
    is_black = connected_comp(is_black)

    is_black_vertical = np.sum(is_black, axis=0) > 0
    is_black_horizontal = np.sum(is_black, axis=1) > 0
    
    left = np.argmax(is_black_horizontal)-2
    right = np.argmax(is_black_horizontal[::-1])+2
    top = np.argmax(is_black_vertical)+2
    bottom = np.argmax(is_black_vertical[::-1])-2
    height, width = image.shape
    cropped_image = image[left:height - right, top:width - bottom]
    return cropped_image


def resize(image, size=(128, 128)):
    return cv2.resize(image, size)

# %%
# perm = np.random.RandomState(777).permutation(n_dataset)
# print('perm', perm)
# train_dataset = BengaliAIDataset(
#     train_images, train_labels, transform=Transform(size=(image_size, image_size)),
#     indices=perm[:train_data_size])
# valid_dataset = BengaliAIDataset(
#     train_images, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
#     )
# print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))

# %%
# n_dataset = len(train_images)
# train_data_size = 200 if debug else int(n_dataset * 0.9)
# valid_data_size = 100 if debug else int(n_dataset - train_data_size)

# perm = np.random.RandomState(777).permutation(n_dataset)
# print('perm', perm)
# train_dataset = BengaliAIDataset(
#     train_images, train_labels, transform=Transform(size=(image_size, image_size)),
#     indices=perm[:train_data_size])
# valid_dataset = BengaliAIDataset(
#     train_images, train_labels, transform=Transform(affine=False, crop=True, size=(image_size, image_size)),
#     indices=perm[train_data_size:train_data_size+valid_data_size])
# print('train_dataset', len(train_dataset), 'valid_dataset', len(valid_dataset))

# # --- Model ---
# device = torch.device(device)
# n_grapheme = 168
# n_vowel = 11
# n_consonant = 7
# n_total = n_grapheme + n_vowel + n_consonant
# print('n_total', n_total)
# # Set pretrained='imagenet' to download imagenet pretrained model...
# predictor = PretrainedCNN(in_channels=1, out_dim=n_total, model_name=model_name, pretrained=None)
# print('predictor', type(predictor))

# classifier = BengaliClassifier(predictor).to(device)

# %%
perm_dict = {}
perm_dict[1] = perm[train_data_size:train_data_size+valid_data_size][perm[train_data_size:train_data_size+valid_data_size]<50210]
perm_dict[2] = perm[train_data_size:train_data_size+valid_data_size][np.logical_and(50210<=perm[train_data_size:train_data_size+valid_data_size], perm[train_data_size:train_data_size+valid_data_size]<50210*2)]-50210
perm_dict[3] = perm[train_data_size:train_data_size+valid_data_size][np.logical_and(50210*2<=perm[train_data_size:train_data_size+valid_data_size], perm[train_data_size:train_data_size+valid_data_size]<50210*3)]-50210*2
perm_dict[4] = perm[train_data_size:train_data_size+valid_data_size][np.logical_and(50210*3<=perm[train_data_size:train_data_size+valid_data_size], perm[train_data_size:train_data_size+valid_data_size]<50210*4)]-50210*3

# %%
from torch.utils.data.dataloader import DataLoader
from chainer_chemistry.utils import save_json, load_json


# --- Prediction ---
traindir = '../input/bengaliaicv19-trainedmodels/'
data_type = 'train'
test_preds_list = []

for i in range(4):
    # --- prepare data ---
    indices = [i]
    test_images = prepare_image(
        datadir, featherdir, data_type=data_type, submission=submission, indices=indices)
    
    test_images = test_images[perm_dict[i+1]]
    n_dataset = len(test_images)
    print(f'n_dataset={n_dataset}')
    # print(f'i={i}, n_dataset={n_dataset}')
    # test_data_size = 200 if debug else int(n_dataset * 0.9)

    model_preds_list = []
    for j in range(1):
        # --- Depends on train configuration ---
        train_args_dict = load_json(os.path.join('./', f'args_{j}.json'))
        train_args_dict.update({
            'load_model_path': os.path.join('./', f'predictor_{j}.pt'),
            'device': device,
            'batch_size': batch_size,
            'debug': debug,
        })
        print(f'j {j} updated train_args_dict {train_args_dict}')
        test_preds = predict_core(
                test_images=test_images, n_total=n_total,
                **train_args_dict)

        model_preds_list.append(test_preds)

    # --- ensemble ---
    proba0 = torch.mean(torch.stack([test_preds[0] for test_preds in model_preds_list], dim=0), dim=0)
    proba1 = torch.mean(torch.stack([test_preds[1] for test_preds in model_preds_list], dim=0), dim=0)
    proba2 = torch.mean(torch.stack([test_preds[2] for test_preds in model_preds_list], dim=0), dim=0)
    p0 = torch.argmax(proba0, dim=1).cpu().numpy()
    p1 = torch.argmax(proba1, dim=1).cpu().numpy()
    p2 = torch.argmax(proba2, dim=1).cpu().numpy()
    print('p0', p0.shape, 'p1', p1.shape, 'p2', p2.shape)

    test_preds_list.append([p0, p1, p2])
    if debug:
        break
    #del test_images
    gc.collect()

# %%
# Validation Prediction

# %%
p0 = np.concatenate([test_preds[0] for test_preds in test_preds_list], axis=0)
p1 = np.concatenate([test_preds[1] for test_preds in test_preds_list], axis=0)
p2 = np.concatenate([test_preds[2] for test_preds in test_preds_list], axis=0)
print('concat:', 'p0', p0.shape, 'p1', p1.shape, 'p2', p2.shape)

row_id = []
target = []
for i in tqdm(range(len(p0))):
    
    j=np.copy(i)
    target += [p0[i], p1[i], p2[i]]
    
    if i<5066:
        i = perm_dict[1][i]
    elif i<5066+4990:
        i = perm_dict[2][i-5066]+50210
    elif i<5066+4990+5033:
        i = perm_dict[3][i-(5066+4990)]+50210*2
    elif i<5066+4990+5033+4995:
        i = perm_dict[4][i-(5066+4990+5033)]+50210*3
    else:
        print("index error")
        
    row_id += [f'Train_{i}_grapheme_root', f'Train_{i}_vowel_diacritic',
               f'Train_{i}_consonant_diacritic']
    
#submission_df = pd.DataFrame({'row_id': row_id, 'target': target})
#submission_df.to_csv('submission.csv', index=False)

# %%
pd.DataFrame({'row_id': row_id, 'target': target})
predict_df = pd.DataFrame({'row_id': row_id, 'target': target})
predict_label = np.array(predict_df['target'])
predict_label

# %%
true_df = train[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].iloc[np.concatenate([perm_dict[1],perm_dict[2]+50210,perm_dict[3]+2*50210,perm_dict[4]+3*50210],axis=0),:]
true_label = true_df.values.reshape(1,-1)[0]
true_label

# %%
(predict_label==true_label).sum()/true_label.shape[0]

# %%
predict_df['row_id']

# %% [markdown]
# # grapheme

# %%
# 한 종류만 보기
combined_df = predict_df[predict_df['row_id'].map(lambda x: x.split('_')[-2]=='grapheme')]
# 인덱스 초기화
combined_df = combined_df.reset_index(drop=True)
# 'true_label' 추가
combined_df['true_label']=pd.Series(true_df.values.reshape(1,-1)[0][list(predict_df['row_id'].map(lambda x: x.split('_')[-2]=='grapheme'))])
combined_df.rename(columns = {'target': 'prediction'}, inplace = True)
print("정답률:", np.sum(combined_df['prediction']==combined_df['true_label'])/combined_df.shape[0])

# %% [markdown]
# # vowel

# %%
# 한 종류만 보기
combined_df = predict_df[predict_df['row_id'].map(lambda x: x.split('_')[-2]=='vowel')]
# 인덱스 초기화
combined_df = combined_df.reset_index(drop=True)
# 'true_label' 추가
combined_df['true_label']=pd.Series(true_df.values.reshape(1,-1)[0][list(predict_df['row_id'].map(lambda x: x.split('_')[-2]=='vowel'))])
combined_df.rename(columns = {'target': 'prediction'}, inplace = True)
print("정답률:", np.sum(combined_df['prediction']==combined_df['true_label'])/combined_df.shape[0])

# %% [markdown]
# # consonant

# %%
# 한 종류만 보기
combined_df = predict_df[predict_df['row_id'].map(lambda x: x.split('_')[-2]=='consonant')]
# 인덱스 초기화
combined_df = combined_df.reset_index(drop=True)
# 'true_label' 추가
combined_df['true_label']=pd.Series(true_df.values.reshape(1,-1)[0][list(predict_df['row_id'].map(lambda x: x.split('_')[-2]=='consonant'))])
combined_df.rename(columns = {'target': 'prediction'}, inplace = True)
print("정답률:", np.sum(combined_df['prediction']==combined_df['true_label'])/combined_df.shape[0])

# %% [markdown]
# # 예측, 정답 데이터프레임

# %%
combined_df['correct']= combined_df['prediction']==combined_df['true_label']
# 인덱스 바꿔주기
#combined_df.index = pd.Index(combined_df['row_id'].map(lambda x:x.split('_')[-3]).astype(np.int64))
combined_df.index = list(combined_df['row_id'].map(lambda x:x.split('_')[-3]).astype(np.int64))

# %% [markdown]
# # 라벨별 정확도

# %%
allcount_dict = dict(combined_df['true_label'].value_counts())
tcount_dict = dict(combined_df[combined_df['correct']==True]['true_label'].value_counts())

acc_dict = {}
for i in allcount_dict.keys():
    acc_dict[i] = tcount_dict[i]/allcount_dict[i]
acc_dict = {k: v for k, v in sorted(acc_dict.items(), key=lambda item: item[1])}
acc_dict

# %% [markdown]
# # 라벨별로 참, 거짓 이미지 확인

# %%
label = 61

subset_df = combined_df[combined_df['true_label']==label]

n_fig = 10
f_index = subset_df[subset_df['correct']==False].index[:n_fig]
t_index = subset_df[subset_df['correct']==True].index[:n_fig]

nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = t_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()


nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = f_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()

# %%
label = 84

subset_df = combined_df[combined_df['true_label']==label]

n_fig = 10
f_index = subset_df[subset_df['correct']==False].index[:n_fig]
t_index = subset_df[subset_df['correct']==True].index[:n_fig]

nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = t_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()


nrow, ncol = 3, 3

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    i = f_index[i]
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    #ax.set_title(f'label: {label}')
    ax.set_title("true: " + str(combined_df.loc[i]['true_label'])+", prediction:" + str(combined_df.loc[i]['prediction'])+"\n"+str(label))
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(22, 6))
plt.title('Label Count')
sns.countplot(x="grapheme_root",data=train)

# %%
plt.imshow(train_dataset[0][0])

# %%
nrow, ncol = 5, 6

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in tqdm(enumerate(axes)):
    image, label = train_dataset[i]
    ax.imshow(image, cmap='Greys')
    ax.set_title(f'label: {label}')
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="ref"></a>
# # Reference and further reading
#
# #### Kernel
#
# **[Bangali.AI super fast data loading with feather](https://www.kaggle.com/corochann/bangali-ai-super-fast-data-loading-with-feather)**<br>
# Simple example of how use feather format data to load data faster.
#
# **[Bengali: albumentations data augmentation tutorial](https://www.kaggle.com/corochann/bengali-albumentations-data-augmentation-tutorial)**<br>
# Tutorial for Data augmentations with albumentations library.
#
# **[Bengali: SEResNeXt prediction with pytorch](https://www.kaggle.com/corochann/bengali-seresnext-prediction-with-pytorch)**<br>
# **Prediction code of this kernel's trained model, please check this too!**
#
# **[Deep learning - CNN with Chainer: LB 0.99700](https://www.kaggle.com/corochann/deep-learning-cnn-with-chainer-lb-0-99700)**<br>
# Data augmentation idea is based on this kernel, which achieves quite high accuracy on MNIST task.
#
# #### Dataset
# **[bengaliai-cv19-feather](https://www.kaggle.com/corochann/bengaliaicv19feather)**<br>
# Feather format dataset
#
# **[bengaliaicv19_seresnext101_32x4d](https://www.kaggle.com/corochann/bengaliaicv19-seresnext101-32x4d)**<br>
# **Trained model weight with this kernel(v1)**
#
# **[bengaliaicv19_trainedmodels](https://www.kaggle.com/corochann/bengaliaicv19-trainedmodels)**<br>
# **Trained model weight with this kernel(v2~)**
#
# #### Library
# **https://github.com/pytorch/ignite**
#
# Used for training code abstraction. The advantage of abstracting the code is that we can re-use implemented handler class for other training, other competition.<br>
# You don't need to write code for saving models, logging training loss/metric, show progressbar etc.
#
# **https://github.com/Cadene/pretrained-models.pytorch**
#
# Many pretrained models are supported by this library, and we can switch to use them easily.
# Other model may perform better in this competition.
#
# **https://github.com/albumentations-team/albumentations**
#
# fast image augmentation library and easy to use wrapper around other libraries https://arxiv.org/abs/1809.06839<br>
# I could not show all the methods, you can find more methods in the library, check yourself!

# %% [markdown]
# <h3 style="color:red">If this kernel helps you, please upvote to keep me motivated :)<br>Thanks!</h3>
